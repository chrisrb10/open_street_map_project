# %% [markdown]
# #  OSM PROJECT NOTES

# %% [markdown]
# Area Chosen:
# London Borough of Richmond upon Thames + environs
# ```
# (node(51.2598, -0.5466, 51.4942, -0.1497);<;);out meta;
# ```
# Ouput 'interpreter' file is 262MB.
# Renamed 'swlondon.osm'

# %% [markdown]
# Audit Street Types on swlondon_sample:
#
# Approach: 3
# Ave: 2
# Avenue: 152
# Billet: 1
# Boltons: 2
# Boulevard: 1
# Bridge: 2
# Broadway: 17
# Castelnau: 8
# Causeway: 1
# Centre: 10
# Chase: 2
# Close: 79
# Common: 1
# Copse: 3
# Court: 6
# Crescent: 16
# Crossway: 1
# Cutting: 1
# Danesfield: 3
# Deep: 2
# Drive: 37
# East: 1
# Elms: 1
# Embankment: 3
# Estate: 2
# Fields: 3
# Gardens: 76
# Glade: 2
# Green: 11
# Grove: 21
# Heath: 1
# Heathside: 1
# Heights: 1
# Hill: 67
# Hillcrest: 9
# Horseshoe: 1
# House: 2
# Lane: 106
# Lawns: 1
# Lodge: 1
# Mall: 8
# Mansions: 1
# Meadows: 1
# Meadway: 1
# Mews: 7
# Moorings: 1
# North: 1
# Parade: 9
# Park: 5
# Parkside: 1
# Pier: 1
# Place: 45
# Quadrant: 3
# Rd: 2
# Ridgeway: 1
# Rise: 4
# Road: 1092
# Side: 5
# South: 5
# Square: 24
# Street: 158
# Summerstown: 1
# Sweep: 5
# Terrace: 11
# Verralls: 1
# View: 1
# Villas: 1
# Walk: 8
# Walton: 2
# Way: 36
# West: 38
# Wharf: 1
# Wood: 2
# Woodside: 5

# %% [markdown]
# Audit Street Types on swlondon:
#
# (LHR): 1
# 11: 1
# 1EG: 1
# 218: 1
# 24: 1
# 9: 1
# Airport: 2
# Apartments: 1
# Approach: 26
# Ave: 10
# Avenue: 1533
# Avenuen: 1
# Bank: 9
# Basin: 1
# Billet: 2
# Boltons: 29
# Boulevard: 8
# Bridge: 30
# Broadway: 149
# Buildings: 1
# Byeways: 1
# Bypass: 1
# Castelnau: 66
# Causeway: 4
# Centre: 80
# Chase: 9
# Chelsea: 1
# Close: 855
# Common: 20
# Copse: 13
# Corner: 1
# Cottages: 4
# Court: 71
# Crescent: 158
# Croft: 1
# Cross: 1
# Crossway: 12
# Cutting: 4
# Danesfield: 36
# Deep: 4
# Downs: 2
# Downside: 1
# Draycott: 1
# Drive: 456
# East: 24
# Elmers: 2
# Elms: 16
# Embankment: 22
# End: 1
# Estate: 20
# Farm: 1
# Fields: 15
# Foleys: 1
# Frogmore: 1
# Gardens: 759
# Gate: 8
# Glade: 17
# Green: 114
# Grove: 267
# Hall: 1
# Heath: 11
# Heathside: 5
# Heights: 5
# Hill: 614
# Hillcrest: 101
# Horseshoe: 2
# House: 16
# Hurstbourne: 4
# Hythe: 2
# Island: 3
# Lane: 1124
# lane: 1
# Lanes: 1
# Lawns: 3
# Lodge: 4
# Mall: 60
# Mansions: 3
# Market: 5
# Mead: 1
# Meadows: 6
# Meadway: 3
# Mews: 90
# Mills: 1
# Moorings: 6
# North: 9
# Parade: 72
# Park: 46
# park: 1
# Parkshot: 2
# Parkside: 3
# Path: 9
# Pier: 1
# Place: 397
# Pleasant: 1
# Quadrant: 40
# Quay: 2
# Rd: 11
# Rd): 1
# Reach: 2
# Retreat: 7
# Ride: 3
# Ridge: 2
# Ridgeway: 6
# Ridgway: 7
# Rise: 73
# Riverbank: 1
# Riverside: 7
# ROAD: 1
# road: 1
# Road: 10965
# Row: 18
# Services: 1
# Sheen: 2
# Shortlands: 4
# Shotfield: 1
# Side: 42
# South: 34
# Square: 285
# St: 1
# Stables: 2
# Station: 1
# Stepgates: 3
# street: 1
# Street: 1510
# Streets: 2
# Strreet: 1
# Summerstown: 2
# Sweep: 40
# Terrace: 152
# Thameside: 1
# Town: 1
# Towpath: 1
# Triangle: 1
# Vale: 4
# Verralls: 5
# View: 6
# Villas: 9
# Vineyard: 2
# Walk: 61
# Walton: 27
# Way: 352
# West: 326
# Wharf: 2
# Whitton: 1
# Willowbank: 1
# Wimbledon: 1
# Wood: 10
# Woodside: 64
# Yeldham: 1

# %% [markdown]
# Element types count on swlondon_sample:
#
# ```
# Final n=  349227
#
# {'node': 110088, 'nd': 144243, 'member': 11102, 'tag': 65884, 'relation': 411, 'way': 17498, 'osm': 1}
#
# ```

# %% [markdown]
# Element types count on swlondon:
#
# ```
# Final n=  3475775
#
# {'node': 1100871, 'member': 99686, 'nd': 1437122, 'tag': 658995, 'note': 1, 'meta': 1, 'relation': 4117, 'way': 174981, 'osm': 1}
# ```

# %% [markdown]
# ###  Tag Types

# %% [markdown]
# Running 'Tag Types' count - the dominant 'other' type is naptan:*
#
# Which looks to relate to the National Public Transport Access Nodes dataset
#
# https://wiki.openstreetmap.org/wiki/NaPTAN
#
# The 'other' type trigger looks mainly caused by the capital letter after the :
# ```
# found other: naptan:CommonName
# ```
#
# except
# ```
# naptan:verified
# found lower_colon: naptan:verified
# ```
#
# which don't have capitals

# %% [markdown]
# Run Tag types count on swlondon_sample.osm:
#
# ```{'lower': 51558, 'lower_colon': 10918, 'other': 3408, 'problemchars': 0}```

# %% [markdown]
# Run Tag types count on swlondon.osm:
#
# ```{'lower': 517185, 'lower_colon': 107419, 'other': 34391, 'problemchars': 0}```

# %% [markdown]
# **Naptan tags**
#
# As naptan: tags as so numerous, i have created a separate tag type (naptan) to count them.
#
# REGEX:
# ```
# naptan = re.compile(r'^(naptan:|Naptan:)[a-zA-Z]*$')
# ```
#
# A check of the list confirms correct extraction of only naptan tags
#
# output from rerun on swlondon.osm:
# ```
# {'lower': 517185,
#  'lower_colon': 100165,
#  'naptan': 39975,
#  'other': 1670,
#  'problemchars': 0}
#  ```
#
#  Also changed 'lower_colon' REGEX to that in final shaping code -
#
#  from:
#  ```
#  (r'^([a-z]|_)*:([a-z]|_)*$')
#  ```
#  which was causing problems as classifying values with two colons  text:text:text
#
#  to
#  ```
#  (r'^([a-z]|_)+:([a-z]|_)+')
#  ```
#
#  which changed results to:
#
#  ```
#  {'lower': 517185,
#  'lower_colon': 100765,
#  'naptan': 39975,
#  'other': 1070,
#  'problemchars': 0}
#  ```

# %% [markdown]
# ### Exploring Users

# %% [markdown]
# Count users on swlondon_sample.osm:
#
# n = 1287
#
# Count users on swlondon.osm:
#
# n= 2128

# %% [markdown]
# ## Auditing Street Names

# %% [markdown]
# For swlondon_sample.osm.
#
# Using
# ```
# expected = ['Approach','Avenue','Bank','Boulevard','Bridge','Broadway','Buildings','Causeway',
#             'Chase','Close','Common','Copse','Corner','Cottages','Court','Crescent','Croft',
#            'Crossway','Cutting','Deep','Drive','Gardens','Green','Grove','Heath','Hill','Heights','Lane','Mall',
#            'Meadows','Mews','Parade','Park','Place','Quadrant','Quay', 'Rise','Road','Row',
#            'Square','Street','Terrace','Villas','Walk','Way','West']
#            ```
#
# Ouput is:
# ```
# {'Ave': set(['Baywillow Ave', 'Quintin Ave']),
#  'Billet': set(['Crooked Billet']),
#  'Boltons': set(['The Boltons']),
#  'Castelnau': set(['Castelnau']),
#  'Centre': set(['Southside Shopping Centre', 'The Swan Centre']),
#  'Danesfield': set(['Danesfield']),
#  'Elms': set(['The Elms']),
#  'Embankment': set(['Embankment', 'Putney Embankment', 'The Embankment']),
#  'Estate': set(['Kingsnympton Park Estate']),
#  'Fields': set(['Manor Fields']),
#  'Glade': set(['Oakfield Glade']),
#  'Hillcrest': set(['Hillcrest']),
#  'Horseshoe': set(['The Horseshoe']),
#  'House': set(['Argyll House', 'Tudor House']),
#  'Lawns': set(['The Lawns']),
#  'Lodge': set(['Arlington Lodge']),
#  'Mansions': set(['Elmfield Mansions']),
#  'Meadway': set(['Meadway']),
#  'Moorings': set(['The Moorings']),
#  'North': set(['Ockham Road North']),
#  'Parkside': set(['Parkside']),
#  'Pier': set(['St Helena Pier']),
#  'Rd': set(["St John's Rd", 'Warwick Rd']),
#  'Ridgeway': set(['Ridgeway']),
#  'Side': set(['Clapham Common North Side', 'Clapham Common West Side']),
#  'South': set(['Stanhope Mews South']),
#  'Summerstown': set(['25 Summerstown']),
#  'Sweep': set(['Lavender Sweep']),
#  'Verralls': set(['Verralls']),
#  'View': set(['Cricket View']),
#  'Walton': set(['The Heart of Walton']),
#  'Wharf': set(['Bridges Wharf']),
#  'Wood': set(['High Street Colliers Wood']),
#  'Woodside': set(['Woodside'])}
#  ```

# %% [markdown]
# For swlondon.osm.
#
# Using
# ```
# expected = ['Approach','Avenue','Bank','Boulevard','Bridge','Broadway','Buildings','Causeway',
#             'Chase','Close','Common','Copse','Corner','Cottages','Court','Crescent','Croft',
#            'Crossway','Cutting','Deep','Drive','Gardens','Green','Grove','Heath','Hill','Heights','Lane','Mall',
#            'Meadows','Mews','Parade','Park','Place','Quadrant','Quay', 'Rise','Road','Row',
#            'Square','Street','Terrace','Villas','Walk','Way','West']
#            ```
#
# Ouput is:
# ```
# {'11': set(['11']),
#  '1EG': set(['Rectory Grove Hampton TW12 1EG']),
#  '218': set(['218']),
#  '24': set(['24']),
#  'Airport': set(['Heathrow Airport']),
#  'Apartments': set(['Metropolis Apartments']),
#  'Ave': set(['Baywillow Ave', 'Quintin Ave']),
#  'Avenuen': set(['Kingston Avenuen']),
#  'Basin': set(['Sury Basin']),
#  'Billet': set(['Crooked Billet']),
#  'Boltons': set(['The Boltons']),
#  'Byeways': set(['Byeways']),
#  'Bypass': set(['Kingston Bypass']),
#  'Castelnau': set(['Castelnau']),
#  'Centre': set(['Southside Shopping Centre',
#                 'Swan Centre',
#                 'The Ashley Centre',
#                 'The Swan Centre']),
#  'Chelsea': set(['Fulham Road, Chelsea']),
#  'Cross': set(['Fulham Cross']),
#  'Danesfield': set(['Danesfield']),
#  'Downs': set(['The Downs']),
#  'Downside': set(['Downside']),
#  'Draycott': set(['Draycott']),
#  'East': set(['Commonside East',
#               'Sloane Court East',
#               'Staines Road East',
#               'Upper Green East']),
#  'Elmers': set(['Avenue Elmers']),
#  'Elms': set(['The Elms']),
#  'Embankment': set(['Chelsea Embankment',
#                     'Embankment',
#                     'Putney Embankment',
#                     'The Embankment']),
#  'End': set(['Bychurch End']),
#  'Estate': set(['Kingsnympton Park Estate', 'Twickenham Industrial Estate']),
#  'Farm': set(['Gosden Hill Farm']),
#  'Fields': set(['Manor Fields']),
#  'Foleys': set(['High Foleys']),
#  'Frogmore': set(['Frogmore']),
#  'Gate': set(['Eaton Gate', 'Palace Gate', "Queen's Gate"]),
#  'Glade': set(['Oakfield Glade']),
#  'Hall': set(["Bishop's Hall"]),
#  'Heathside': set(['Heathside']),
#  'Hillcrest': set(['Hillcrest']),
#  'Horseshoe': set(['The Horseshoe']),
#  'House': set(['Argyll House', 'Tudor House']),
#  'Hurstbourne': set(['Hurstbourne']),
#  'Hythe': set(['The Hythe']),
#  'Island': set(['Eel Pie Island', 'Sunbury Lock Island', "Tagg's Island"]),
#  'LHR)': set(['Sheffield Rd, Heathrow Airport (LHR)']),
#  'Lanes': set(['Green Lanes']),
#  'Lawns': set(['The Lawns']),
#  'Lodge': set(['Arlington Lodge', 'Horbury Lodge', 'The Lodge']),
#  'Mansions': set(['Elmfield Mansions']),
#  'Market': set(['Temple Market']),
#  'Mead': set(['Heath Mead']),
#  'Meadway': set(['Meadway']),
#  'Mills': set(['Soho Mills']),
#  'Moorings': set(['The Moorings']),
#  'North': set(['Fox Lane North',
#                'Fullers Way North',
#                'Hook Rise North',
#                'Manor Drive North',
#                'Manor Road North',
#                'Ockham Road North',
#                'Woodstock Lane North']),
#  'Parkshot': set(['Parkshot']),
#  'Parkside': set(['Parkside']),
#  'Path': set(['Church Path', 'High Path', 'Kew Meadow Path', 'The Path']),
#  'Pier': set(['St Helena Pier']),
#  'Pleasant': set(['Point Pleasant']),
#  'ROAD': set(['WALTON ROAD']),
#  'Rd': set(['Cobham Rd',
#             'Ewell Rd',
#             'Kew Bridge Rd',
#             'Spur Rd',
#             "St John's Rd",
#             'Warwick Rd']),
#  'Rd)': set(['Beacon Rd (Entrance Sanctuary Rd)']),
#  'Reach': set(['River Reach']),
#  'Retreat': set(['The Retreat']),
#  'Ride': set(['Ladderstile Ride']),
#  'Ridge': set(['Ruxley Ridge']),
#  'Ridgeway': set(['Ridgeway']),
#  'Ridgway': set(['Ridgway']),
#  'Riverbank': set(['Riverbank']),
#  'Riverside': set(['Riverside']),
#  'Services': set(['Cobham Services']),
#  'Sheen': set(['West Temple Sheen']),
#  'Shortlands': set(['Shortlands']),
#  'Shotfield': set(['Shotfield']),
#  'Side': set(['Clapham Common North Side',
#               'Clapham Common West Side',
#               'North Side',
#               'Railway Side',
#               'Wimbledon Park Side']),
#  'South': set(['Chiswick Lane South',
#                'Fairfield South',
#                'London Road South',
#                'Longdown Lane South',
#                'Poplar Road South',
#                'Stanhope Mews South',
#                'Woodstock Lane South']),
#  'St': set(['Eden St']),
#  'Stables': set(['Crescent Stables']),
#  'Station': set(['Richmond Station']),
#  'Stepgates': set(['Stepgates']),
#  'Streets': set(['Between Streets']),
#  'Strreet': set(['Ebury Strreet']),
#  'Summerstown': set(['25 Summerstown', 'Summerstown']),
#  'Sweep': set(['Lavender Sweep']),
#  'Thameside': set(['Thameside']),
#  'Town': set(['Row Town']),
#  'Towpath': set(['Towpath']),
#  'Triangle': set(['The Triangle']),
#  'Vale': set(['Kingston Vale', 'Roehampton Vale', 'The Vale']),
#  'Verralls': set(['Verralls']),
#  'View': set(['Cricket View']),
#  'Vineyard': set(['The Vineyard']),
#  'Walton': set(['The Heart of Walton']),
#  'Wharf': set(['Bridges Wharf']),
#  'Whitton': set(['High Street Whitton']),
#  'Willowbank': set(['Willowbank']),
#  'Wimbledon': set(['Wimbledon']),
#  'Wood': set(['High Street Colliers Wood']),
#  'Woodside': set(['Woodside']),
#  'Yeldham': set(['Yeldham']),
#  'lane': set(['Town lane']),
#  'park': set(['Langdon park']),
#  'road': set(['Kings road']),
#  'street': set(['sydney street'])}
#  ```

# %% [markdown]
# As result of above, ad the following to 'expected':
#
# Centre, East, Embankment, North, South, Vale
#
#
# **NOTE** - investigate proper spelling (one word or two) for:
#  'Side': set(['Clapham Common North Side',
#               'Clapham Common West Side',
#               'North Side',
#               'Railway Side',
#               'Wimbledon Park Side'])

# %% [markdown]
# Re-run For swlondon.osm.
#
# Using
# ```
# expected = ['Approach','Avenue','Bank','Boulevard','Bridge','Broadway','Buildings','Causeway','Centre',
#             'Chase','Close','Common','Copse','Corner','Cottages','Court','Crescent','Croft',
#            'Crossway','Cutting','Deep','Drive','East', 'Embankment','Gardens','Green','Grove','Heath','Hill',
#             'Heights','Lane','Mall','Meadows','Mews','North','Parade','Park','Place','Quadrant','Quay',
#             'Rise','Road','Row', 'South','Square','Street','Terrace','Vale','Villas','Walk','Way','West']
#            ```
#
# Ouput is:
# ```
# {'11': set(['11']),
#  '1EG': set(['Rectory Grove Hampton TW12 1EG']),
#  '218': set(['218']),
#  '24': set(['24']),
#  'Airport': set(['Heathrow Airport']),
#  'Apartments': set(['Metropolis Apartments']),
#  'Ave': set(['Baywillow Ave', 'Quintin Ave']),
#  'Avenuen': set(['Kingston Avenuen']),
#  'Basin': set(['Sury Basin']),
#  'Billet': set(['Crooked Billet']),
#  'Boltons': set(['The Boltons']),
#  'Byeways': set(['Byeways']),
#  'Bypass': set(['Kingston Bypass']),
#  'Castelnau': set(['Castelnau']),
#  'Chelsea': set(['Fulham Road, Chelsea']),
#  'Cross': set(['Fulham Cross']),
#  'Danesfield': set(['Danesfield']),
#  'Downs': set(['The Downs']),
#  'Downside': set(['Downside']),
#  'Draycott': set(['Draycott']),
#  'Elmers': set(['Avenue Elmers']),
#  'Elms': set(['The Elms']),
#  'End': set(['Bychurch End']),
#  'Estate': set(['Kingsnympton Park Estate', 'Twickenham Industrial Estate']),
#  'Farm': set(['Gosden Hill Farm']),
#  'Fields': set(['Manor Fields']),
#  'Foleys': set(['High Foleys']),
#  'Frogmore': set(['Frogmore']),
#  'Gate': set(['Eaton Gate', 'Palace Gate', "Queen's Gate"]),
#  'Glade': set(['Oakfield Glade']),
#  'Hall': set(["Bishop's Hall"]),
#  'Heathside': set(['Heathside']),
#  'Hillcrest': set(['Hillcrest']),
#  'Horseshoe': set(['The Horseshoe']),
#  'House': set(['Argyll House', 'Tudor House']),
#  'Hurstbourne': set(['Hurstbourne']),
#  'Hythe': set(['The Hythe']),
#  'Island': set(['Eel Pie Island', 'Sunbury Lock Island', "Tagg's Island"]),
#  'LHR)': set(['Sheffield Rd, Heathrow Airport (LHR)']),
#  'Lanes': set(['Green Lanes']),
#  'Lawns': set(['The Lawns']),
#  'Lodge': set(['Arlington Lodge', 'Horbury Lodge', 'The Lodge']),
#  'Mansions': set(['Elmfield Mansions']),
#  'Market': set(['Temple Market']),
#  'Mead': set(['Heath Mead']),
#  'Meadway': set(['Meadway']),
#  'Mills': set(['Soho Mills']),
#  'Moorings': set(['The Moorings']),
#  'Parkshot': set(['Parkshot']),
#  'Parkside': set(['Parkside']),
#  'Path': set(['Church Path', 'High Path', 'Kew Meadow Path', 'The Path']),
#  'Pier': set(['St Helena Pier']),
#  'Pleasant': set(['Point Pleasant']),
#  'ROAD': set(['WALTON ROAD']),
#  'Rd': set(['Cobham Rd',
#             'Ewell Rd',
#             'Kew Bridge Rd',
#             'Spur Rd',
#             "St John's Rd",
#             'Warwick Rd']),
#  'Rd)': set(['Beacon Rd (Entrance Sanctuary Rd)']),
#  'Reach': set(['River Reach']),
#  'Retreat': set(['The Retreat']),
#  'Ride': set(['Ladderstile Ride']),
#  'Ridge': set(['Ruxley Ridge']),
#  'Ridgeway': set(['Ridgeway']),
#  'Ridgway': set(['Ridgway']),
#  'Riverbank': set(['Riverbank']),
#  'Riverside': set(['Riverside']),
#  'Services': set(['Cobham Services']),
#  'Sheen': set(['West Temple Sheen']),
#  'Shortlands': set(['Shortlands']),
#  'Shotfield': set(['Shotfield']),
#  'Side': set(['Clapham Common North Side',
#               'Clapham Common West Side',
#               'North Side',
#               'Railway Side',
#               'Wimbledon Park Side']),
#  'St': set(['Eden St']),
#  'Stables': set(['Crescent Stables']),
#  'Station': set(['Richmond Station']),
#  'Stepgates': set(['Stepgates']),
#  'Streets': set(['Between Streets']),
#  'Strreet': set(['Ebury Strreet']),
#  'Summerstown': set(['25 Summerstown', 'Summerstown']),
#  'Sweep': set(['Lavender Sweep']),
#  'Thameside': set(['Thameside']),
#  'Town': set(['Row Town']),
#  'Towpath': set(['Towpath']),
#  'Triangle': set(['The Triangle']),
#  'Verralls': set(['Verralls']),
#  'View': set(['Cricket View']),
#  'Vineyard': set(['The Vineyard']),
#  'Walton': set(['The Heart of Walton']),
#  'Wharf': set(['Bridges Wharf']),
#  'Whitton': set(['High Street Whitton']),
#  'Willowbank': set(['Willowbank']),
#  'Wimbledon': set(['Wimbledon']),
#  'Wood': set(['High Street Colliers Wood']),
#  'Woodside': set(['Woodside']),
#  'Yeldham': set(['Yeldham']),
#  'lane': set(['Town lane']),
#  'park': set(['Langdon park']),
#  'road': set(['Kings road']),
#  'street': set(['sydney street'])}
#  ```

# %% [markdown]
# A mapping can fix most typo and inconcistent shortening / spelling errors:
#
# ```
# mapping = { 'St': 'Street',
#             'St.': 'Street',
#             'Strreet': 'Street',
#             'street': 'Street',
#             'Rd.':'Road',
#             'Rd' : 'Road',
#             'ROAD':'Road',
#             'road':'Road',
#             'Ave':'Avenue',
#             'Avenuen':'Avenue',
#             'lane': 'Lane',
#             'park':'Park'
#             }
#             ```
#
# There remain a number of names in a 'problem set':
#
# ```
# problem_street_names = ['11', '218','24', 'Rectory Grove Hampton TW12 1EG','Fulham Road, Chelsea',
#                         'Sheffield Rd, Heathrow Airport (LHR)','Beacon Rd (Entrance Sanctuary Rd)',
#                         'Wimbledon']
#                         ```
#
#
# With investigation, I have decided to fix some:
#
# ```
# change_list_mapping = { 'Rectory Grove Hampton TW12 1EG': 'Rectory Grove',
#                         'Sheffield Rd, Heathrow Airport (LHR)': 'Sheffield Road',
#                         'Beacon Rd (Entrance Sanctuary Rd)': 'Beacon Road',
#                         'Wimbledon' : 'Wimbledon Hill Road'}
#                         ```
#
# And then drop the others (very poor quality tag - for retail business usually):
# ```
# drop_list = ['11', '218','24']
# ```
#
# So final 'prposed fix list' is:
#
# ```
# ('218', '=>', 'DROP TAG')
# ("St John's Rd", '=>', "St John's Road")
# ('Spur Rd', '=>', 'Spur Road')
# ('Cobham Rd', '=>', 'Cobham Road')
# ('Warwick Rd', '=>', 'Warwick Road')
# ('Ewell Rd', '=>', 'Ewell Road')
# ('Kew Bridge Rd', '=>', 'Kew Bridge Road')
# ('24', '=>', 'DROP TAG')
# ('WALTON ROAD', '=>', 'Walton Road')
# ('Rectory Grove Hampton TW12 1EG', '=>', 'Rectory Grove')
# ('Kingston Avenuen', '=>', 'Kingston Avenue')
# ('sydney street', '=>', 'Sydney Street')
# ('Beacon Rd (Entrance Sanctuary Rd)', '=>', 'Beacon Road')
# ('Sheffield Rd, Heathrow Airport (LHR)', '=>', 'Sheffield Road')
# ('Kings road', '=>', 'Kings Road')
# ('Langdon park', '=>', 'Langdon Park')
# ('Eden St', '=>', 'Eden Street')
# ('Ebury Strreet', '=>', 'Ebury Street')
# ('11', '=>', 'DROP TAG')
# ('Quintin Ave', '=>', 'Quintin Avenue')
# ('Baywillow Ave', '=>', 'Baywillow Avenue')
# ('Wimbledon', '=>', 'Wimbledon Hill Road')
# ('Town lane', '=>', 'Town Lane')
# ```

# %% [markdown]
# ### A look at tag 'k' values and attribs:
#
# A look at tag 'k' values for swlondon.osm
#
# Problems with lanes: types?
#
# nb - Width is a key  https://wiki.openstreetmap.org/wiki/Key:width#Legally_restricted_width
#
# lanes: https://wiki.openstreetmap.org/wiki/Key:lanes
#
#
#
# ```
#  ('bus:lanes:backward', 1),
#  ('bus:lanes:forward', 3),
#
#  ('motorcycle:lanes:forward', 1),
#
#   ('psv:lanes', 13),
#  ('psv:lanes:backward', 1),
#  ('psv:lanes:forward', 2),
#
#  ```
#  ** NOTE - width, parking, change might be okay**
#
#  https://wiki.openstreetmap.org/wiki/Key:change
#
#  https://wiki.openstreetmap.org/wiki/Key:parking:lane
#
#  https://wiki.openstreetmap.org/wiki/Key:width
#
#  ```
#    ('change:lanes', 30),
#  ('change:lanes:backward', 7),
#  ('change:lanes:forward', 7)
#
#  ('width:lanes:backward', 6),
#  ('width:lanes:forward'
#
#   ('parking:lane', 25),
#  ('parking:lane:both', 6),
#  ('parking:lane:left', 1),
#
#
#
# vs.
#
#  ('lanes', 4121),
#  ('lanes:backward', 36),
#  ('lanes:bus', 4),
#  ('lanes:bus:forward', 5),
#  ('lanes:forward', 37),
#  ('lanes:left', 11),
#  ('lanes:psv', 12),
#  ('lanes:psv:backward', 4),
#  ('lanes:psv:backward:right', 1),
#  ('lanes:psv:forward', 4),
#  ('lanes:psv:right', 1),
#  ('lanes:right', 2)
#
# ```
#
#
# Also took a look at any tag k = 'type' occurances, to see if overwriting higher level 'types' in the element. Can't see any.

# %% [markdown]
# #####  naptan:
#
# looks to relate to the National Public Transport Access Nodes dataset
#
# https://wiki.openstreetmap.org/wiki/NaPTAN
#
# The 'other' type trigger looks mainly caused by the capital letter after the :
# ```
# found other: naptan:CommonName
# ```
#
# except
# ```
# naptan:verified
# found lower_colon: naptan:verified
# ```
#
# should make a separate handling class (like lower_colon) for specifically naptan tags

# %% [markdown]
# ### Postcode Data
#
# Postcode data appears in pretty good shape.
#
# An audit of addr:postcode (as 'k') 'v' fields for swlondon.osm returned result below - all of which are valid and correctly formatted UK postcode outgroups (the part of the postcode before the space) within the study area.
#
# A more detailed read of all the sets of ingroups associated with these outgroups (not pasted here) shows all postcodes appear to be either valide full postcodes:
# (e.g. TW11 9BS), or accceptable shortenings (e.g. TW11 9).
#
# ONE EXCEPTION seen - 'SW19 4ll;SW19'
# ```
# found a postcode format error: SW19 4LL;SW19 4LW
# ```
# discard second part - only use first postcode for tag when cleaning for csv.
#
#
# ```
# 86 postcode outgroups in data
#
# [('CR4', 44),
#  ('CR5', 4),
#  ('GU21', 7),
#  ('GU22', 12),
#  ('GU23', 142),
#  ('GU4', 6),
#  ('KT1', 90),
#  ('KT10', 35),
#  ('KT11', 43),
#  ('KT12', 31),
#  ('KT13', 149),
#  ('KT14', 9),
#  ('KT15', 20),
#  ('KT16', 83),
#  ('KT17', 22),
#  ('KT18', 13),
#  ('KT19', 284),
#  ('KT2', 76),
#  ('KT20', 18),
#  ('KT21', 29),
#  ('KT22', 75),
#  ('KT23', 7),
#  ('KT24', 11),
#  ('KT3', 64),
#  ('KT4', 21),
#  ('KT5', 6),
#  ('KT6', 97),
#  ('KT7', 6),
#  ('KT8', 29),
#  ('KT9', 25),
#  ('RH1', 2),
#  ('RH2', 1),
#  ('RH4', 1),
#  ('RH5', 1),
#  ('SL3', 2),
#  ('SM1', 54),
#  ('SM2', 21),
#  ('SM3', 12),
#  ('SM4', 29),
#  ('SM5', 15),
#  ('SM6', 28),
#  ('SM7', 11),
#  ('SW10', 28),
#  ('SW11', 693),
#  ('SW12', 50),
#  ('SW13', 141),
#  ('SW14', 220),
#  ('SW15', 221),
#  ('SW17', 103),
#  ('SW18', 186),
#  ('SW19', 501),
#  ('SW1W', 19),
#  ('SW1X', 2),
#  ('SW20', 805),
#  ('SW3', 167),
#  ('SW4', 12),
#  ('SW5', 73),
#  ('SW6', 158),
#  ('SW7', 25),
#  ('SW8', 16),
#  ('TW1', 186),
#  ('TW10', 467),
#  ('TW11', 77),
#  ('TW12', 137),
#  ('TW13', 13),
#  ('TW14', 37),
#  ('TW15', 20),
#  ('TW16', 11),
#  ('TW17', 8),
#  ('TW18', 26),
#  ('TW19', 9),
#  ('TW2', 153),
#  ('TW20', 10),
#  ('TW3', 8),
#  ('TW4', 5),
#  ('TW5', 14),
#  ('TW6', 14),
#  ('TW7', 28),
#  ('TW8', 46),
#  ('TW9', 299),
#  ('UB3', 2),
#  ('UB7', 6),
#  ('W14', 11),
#  ('W4', 33),
#  ('W5', 1),
#  ('W6', 29)]
#  ```

# %% [markdown]
# ###  NOTE of cleans required for csv writing:
#
# street names
#
# postcode cleanup (only 1!)
#
# ? lanes: vs.  bus:lanes ?

# %% [markdown]
# ## PROCESSING

# %% [markdown]
# Processed and cleaned - output of all cleans made:
#
# ```
# ('CLEAN STREET NAME:', 'WALTON ROAD', '=>', 'Walton Road')
# ('CLEAN STREET NAME:', 'Rectory Grove Hampton TW12 1EG', '=>', 'Rectory Grove')
# ('CLEAN STREET NAME:', 'Cobham Rd', '=>', 'Cobham Road')
# ('CLEAN STREET NAME:', 'Langdon park', '=>', 'Langdon Park')
# ('CLEAN STREET NAME:', "St John's Rd", '=>', "St John's Road")
# ('CLEAN STREET NAME:', 'sydney street', '=>', 'Sydney Street')
# ('CLEAN STREET NAME:', 'Town lane', '=>', 'Town Lane')
# ('CLEAN STREET NAME:', 'Eden St', '=>', 'Eden Street')
# ('CLEAN STREET NAME:', '218', '=>', 'DROP TAG')
# DROPPING TAG FROM: 3936254366
# ('CLEAN STREET NAME:', 'Spur Rd', '=>', 'Spur Road')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Baywillow Ave', '=>', 'Baywillow Avenue')
# ('CLEAN STREET NAME:', 'Ewell Rd', '=>', 'Ewell Road')
# ('CLEAN STREET NAME:', 'Ebury Strreet', '=>', 'Ebury Street')
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# ('CLEAN STREET NAME:', 'Sheffield Rd, Heathrow Airport (LHR)', '=>', 'Sheffield Road')
# ('CLEAN STREET NAME:', 'Kingston Avenuen', '=>', 'Kingston Avenue')
# ('CLEAN STREET NAME:', '11', '=>', 'DROP TAG')
# DROPPING TAG FROM: 30427523
# ('CLEAN STREET NAME:', 'Warwick Rd', '=>', 'Warwick Road')
# ('CLEAN STREET NAME:', 'Warwick Rd', '=>', 'Warwick Road')
# ('CLEAN STREET NAME:', 'Warwick Rd', '=>', 'Warwick Road')
# ('CLEAN STREET NAME:', 'Warwick Rd', '=>', 'Warwick Road')
# ('CLEAN STREET NAME:', 'Warwick Rd', '=>', 'Warwick Road')
# ('CLEAN STREET NAME:', 'Warwick Rd', '=>', 'Warwick Road')
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# ('CLEAN STREET NAME:', 'Quintin Ave', '=>', 'Quintin Avenue')
# ('CLEAN STREET NAME:', 'Quintin Ave', '=>', 'Quintin Avenue')
# FOUND A PROBLEM TAG TYPE: bus:lanes:forward
# CHANGED TO: lanes:bus:forward
# FOUND A PROBLEM TAG TYPE: bus:lanes:forward
# CHANGED TO: lanes:bus:forward
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes:backward
# CHANGED TO: lanes:psv:backward
# FOUND A PROBLEM TAG TYPE: psv:lanes
# CHANGED TO: lanes:psv
# FOUND A PROBLEM TAG TYPE: psv:lanes:forward
# CHANGED TO: lanes:psv:forward
# ('CLEAN STREET NAME:', 'Beacon Rd (Entrance Sanctuary Rd)', '=>', 'Beacon Road')
# ('CLEAN STREET NAME:', 'Kings road', '=>', 'Kings Road')
# ('CLEAN STREET NAME:', '24', '=>', 'DROP TAG')
# DROPPING TAG FROM: 244995917
# FOUND A PROBLEM TAG TYPE: bus:lanes:backward
# CHANGED TO: lanes:bus:backward
# ('CLEAN STREET NAME:', 'Kew Bridge Rd', '=>', 'Kew Bridge Road')
# FOUND A PROBLEM TAG TYPE: motorcycle:lanes:forward
# CHANGED TO: lanes:motorcycle:forward
# FOUND A PROBLEM TAG TYPE: psv:lanes:forward
# CHANGED TO: lanes:psv:forward
# FOUND A PROBLEM TAG TYPE: bus:lanes:forward
# CHANGED TO: lanes:bus:forward
# CLEANING A POSTCODE: SW19 4LL;SW19 4LW
# NEW POSTCODE: SW19 4LL
# ('CLEAN STREET NAME:', 'Wimbledon', '=>', 'Wimbledon Hill Road')
# ```
