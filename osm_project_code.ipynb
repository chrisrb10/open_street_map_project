# %% [markdown]
# # OSM PROJECT CODE

# %%
# import required modules & functions

import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

# %% [markdown]
# #### Create sample file on k=10 (1 in 10) element sampling

# %%
# To create a (reduced size) sample file. CODE from Udacity

import xml.etree.cElementTree as ET  

OSM_FILE = "swlondon.osm"  
SAMPLE_FILE = "swlondon_sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
# An initial audit of street types, to see what types of names are present.

#osm_file = open("swlondon_sample.osm", "r")
osm_file = open("swlondon.osm", "r")

street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    #print street_name
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        street_types[street_type] += 1

def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print ("%s: %d" % (k, v) )

def is_street_name(elem):
    
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")

def audit():
    #n = 0
    for event, elem in ET.iterparse(osm_file):
        #if n>20: break
        if is_street_name(elem):
            #n+=1
            audit_street_type(street_types, elem.attrib['v'])    
    print_sorted_dict(street_types)    

if __name__ == '__main__':
    audit()
# Out:
# Approach: 3
# Ave: 2
# Avenue: 152
# Billet: 1
# Boltons: 2
# Boulevard: 1
# Bridge: 2
# Broadway: 17
# Castelnau: 8
# Causeway: 1
# Centre: 10
# Chase: 2
# Close: 79
# Common: 1
# Copse: 3
# Court: 6
# Crescent: 16
# Crossway: 1
# Cutting: 1
# Danesfield: 3
# Deep: 2
# Drive: 37
# East: 1
# Elms: 1
# Embankment: 3
# Estate: 2
# Fields: 3
# Gardens: 76
# Glade: 2
# Green: 11
# Grove: 21
# Heath: 1
# Heathside: 1
# Heights: 1
# Hill: 67
# Hillcrest: 9
# Horseshoe: 1
# House: 2
# Lane: 106
# Lawns: 1
# Lodge: 1
# Mall: 8
# Mansions: 1
# Meadows: 1
# Meadway: 1
# Mews: 7
# Moorings: 1
# North: 1
# Parade: 9
# Park: 5
# Parkside: 1
# Pier: 1
# Place: 45
# Quadrant: 3
# Rd: 2
# Ridgeway: 1
# Rise: 4
# Road: 1092
# Side: 5
# South: 5
# Square: 24
# Street: 158
# Summerstown: 1
# Sweep: 5
# Terrace: 11
# Verralls: 1
# View: 1
# Villas: 1
# Walk: 8
# Walton: 2
# Way: 36
# West: 38
# Wharf: 1
# Wood: 2
# Woodside: 5

# %%
# Does a count of element types in osm data file

#OSM_FILE = 'swlondon_sample.osm' 
OSM_FILE = 'swlondon.osm'

# NOTE use n count and break to test script on short sequences before running on full file


tag_types = {}
context = ET.iterparse(OSM_FILE, events=('end',))
#_, root = next(context)
n = 0
for event, elem in context:
    n+=1
    #if n>2000: break
    #print (event, elem)
    if event == 'end': 
        tag_types[elem.tag] = tag_types.get(elem.tag,0)+1

            
print 'Final n= ',n,'\n\n',tag_types
# Out:
# Final n=  3475775
#
# {'node': 1100871, 'member': 99686, 'nd': 1437122, 'tag': 658995, 'note': 1, 'meta': 1, 'relation': 4117, 'way': 174981, 'osm': 1}

# %% [markdown]
# #### Tag Types
#
# Check the"k" value for each "<tag>" and see if there are any potential problems.
#
# Udacity provided  3 regular expressions to check for certain patterns
# in the tags.
# (As in the quiz earlier, we would like to change the data
# model and expand the "addr:street" type of keys to a dictionary like this:
# {"address": {"street": "Some value"}})
#
# So, we have to see if we have such tags, and if we have any tags with
# problematic characters.

# %%
OSM_FILE = 'swlondon_sample.osm' 
#OSM_FILE = 'swlondon.osm'

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)+:([a-z]|_)+')        #(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'\"\?%#$@\,\. \t\r\n]')

naptan = re.compile(r'^(naptan:|Naptan:)[a-zA-Z]*$')


# NOTE use n count and break to test script on short sequences before running on full file


def key_type(element, keys):
    n=0
    #print (element, keys)
    #print ('before tag test',element.attrib)
    if element.tag == "tag":
        if naptan.search(element.attrib['k']):
            keys['naptan'] +=1
            #print 'found naptan:', element.attrib['k']
            
        elif lower.search(element.attrib['k']):
            #print 'found lower:', element.attrib['k']
            keys['lower'] +=1
            
        elif lower_colon.search(element.attrib['k']):
            #print 'found lower_colon:', element.attrib['k']
            keys['lower_colon'] +=1
            
        elif problemchars.search(element.attrib['k']):
            #print 'found problemchars:', element.attrib['k']
            keys['problemchars'] +=1
        else:
            #print 'found other:', element.attrib['k'].lower()
            keys['other']+=1
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0, 'naptan':0}
    n=0
    for _, element in ET.iterparse(filename):
        n+=1
        #if n>20000: break
        #print (n, _, element)
        keys = key_type(element, keys)

    return keys



if __name__ == "__main__":
    keys = process_map(OSM_FILE)
    pprint.pprint(keys)
# Out:
# {'lower': 51558,
#  'lower_colon': 10251,
#  'naptan': 3971,
#  'other': 104,
#  'problemchars': 0}

# %%
#Exploring Users

#OSM_FILE = 'swlondon_sample.osm' 
OSM_FILE = 'swlondon.osm'


def get_user(element):
    if 'uid' in element.attrib.keys():
        #print n, 'has uid', element.attrib['uid']
        return element.attrib['uid']
    else:
        #print n, 'no uid attrib', element.tag, element.attrib
        return None

# NOTE use n count and break to test script on short sequences before running on full file

def process_map(filename):
    users = set()
    n=0
    for _, element in ET.iterparse(filename):
        n+=1
        #if n>20000: break
        element_uid = get_user(element)
        # only add to users set if there is a UID value
        if element_uid:
            users.add(element_uid)


    print len(users), '\n'
    #pprint.pprint(users)

    return (users)






if __name__ == "__main__":
    #test()
    process_map(OSM_FILE)
# Out:
# 2128

# %% [markdown]
# (LHR): 1
# 11: 1
# 1EG: 1
# 218: 1
# 24: 1
# 9: 1
# Airport: 2
# Apartments: 1
# Approach: 26
# Ave: 10
# Avenue: 1533
# Avenuen: 1
# Bank: 9
# Basin: 1
# Billet: 2
# Boltons: 29
# Boulevard: 8
# Bridge: 30
# Broadway: 149
# Buildings: 1
# Byeways: 1
# Bypass: 1
# Castelnau: 66
# Causeway: 4
# Centre: 80
# Chase: 9
# Chelsea: 1
# Close: 855
# Common: 20
# Copse: 13
# Corner: 1
# Cottages: 4
# Court: 71
# Crescent: 158
# Croft: 1
# Cross: 1
# Crossway: 12
# Cutting: 4
# Danesfield: 36
# Deep: 4
# Downs: 2
# Downside: 1
# Draycott: 1
# Drive: 456
# East: 24
# Elmers: 2
# Elms: 16
# Embankment: 22
# End: 1
# Estate: 20
# Farm: 1
# Fields: 15
# Foleys: 1
# Frogmore: 1
# Gardens: 759
# Gate: 8
# Glade: 17
# Green: 114
# Grove: 267
# Hall: 1
# Heath: 11
# Heathside: 5
# Heights: 5
# Hill: 614
# Hillcrest: 101
# Horseshoe: 2
# House: 16
# Hurstbourne: 4
# Hythe: 2
# Island: 3
# Lane: 1124
# lane: 1
# Lanes: 1
# Lawns: 3
# Lodge: 4
# Mall: 60
# Mansions: 3
# Market: 5
# Mead: 1
# Meadows: 6
# Meadway: 3
# Mews: 90
# Mills: 1
# Moorings: 6
# North: 9
# Parade: 72
# Park: 46
# park: 1
# Parkshot: 2
# Parkside: 3
# Path: 9
# Pier: 1
# Place: 397
# Pleasant: 1
# Quadrant: 40
# Quay: 2
# Rd: 11
# Rd): 1
# Reach: 2
# Retreat: 7
# Ride: 3
# Ridge: 2
# Ridgeway: 6
# Ridgway: 7
# Rise: 73
# Riverbank: 1
# Riverside: 7
# ROAD: 1
# road: 1
# Road: 10965
# Row: 18
# Services: 1
# Sheen: 2
# Shortlands: 4
# Shotfield: 1
# Side: 42
# South: 34
# Square: 285
# St: 1
# Stables: 2
# Station: 1
# Stepgates: 3
# street: 1
# Street: 1510
# Streets: 2
# Strreet: 1
# Summerstown: 2
# Sweep: 40
# Terrace: 152
# Thameside: 1
# Town: 1
# Towpath: 1
# Triangle: 1
# Vale: 4
# Verralls: 5
# View: 6
# Villas: 9
# Vineyard: 2
# Walk: 61
# Walton: 27
# Way: 352
# West: 326
# Wharf: 2
# Whitton: 1
# Willowbank: 1
# Wimbledon: 1
# Wood: 10
# Woodside: 64
# Yeldham: 1

# %%
# Auditing Street Names


#OSM_FILE = 'swlondon_sample.osm' 
OSM_FILE = 'swlondon.osm'

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ['Approach','Avenue','Bank','Boulevard','Bridge','Broadway','Buildings','Causeway','Centre',
            'Chase','Close','Common','Copse','Corner','Cottages','Court','Crescent','Croft',
           'Crossway','Cutting','Deep','Drive','East', 'Embankment','Gardens','Green','Grove','Heath','Hill',
            'Heights','Lane','Mall','Meadows','Mews','North','Path','Parade','Park','Place','Quadrant','Quay',
            'Rise','Road','Row', 'South','Square','Street','Terrace','Vale','Villas','Walk','Way','West']



# UPDATE THIS VARIABLE
mapping = { 'St': 'Street',
            'St.': 'Street',
            'Strreet': 'Street',
            'street': 'Street',
            'Rd.':'Road',
            'Rd' : 'Road',
            'ROAD':'Road',
            'road':'Road',
            'Ave':'Avenue',
            'Avenuen':'Avenue',
            'lane': 'Lane',
            'park':'Park'           
            } # etc. to be updated


problem_street_names = ['11', '218','24', 'Rectory Grove Hampton TW12 1EG','Fulham Road, Chelsea',
                        'Sheffield Rd, Heathrow Airport (LHR)','Beacon Rd (Entrance Sanctuary Rd)',
                        'Wimbledon']
    
change_list_mapping = { 'Rectory Grove Hampton TW12 1EG': 'Rectory Grove',
                        'Sheffield Rd, Heathrow Airport (LHR)': 'Sheffield Road',
                        'Beacon Rd (Entrance Sanctuary Rd)': 'Beacon Road',
                        'Wimbledon' : 'Wimbledon Hill Road'}


drop_list = ['11', '218','24']
    
    

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def is_problem_name(street_name, problems):
    return (street_name in problems)

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    n=0
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        n+=1
        #if n>20000: break
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter('tag'):
                if is_street_name(tag):
                    # Used code below to examine 'problem' street names in detail
                    #if is_problem_name(tag.attrib['v'], problem_street_names):

                        #print '\n',elem.tag
                        #for tag in elem.iter():
                            #print tag.attrib
                            #continue
                        #continue
                    
                    audit_street_type(street_types, tag.attrib['v'])
                    
                    
    osm_file.close()
    return street_types


def update_name(name, mapping):
    #print (name.split()[-1])
    if name in drop_list:
        return 'DROP TAG'
    if name in change_list_mapping:
        name = change_list_mapping[name]
        return name
    name_list = name.split()
    try:
        name_list[-1] = mapping[name_list[-1]]
        name_list[0] = name_list[0].title()
        return ' '.join(name_list)
    except:
        return name


def propose_name(st_types):
    #st_types = audit(OSM_FILE)
    #assert len(st_types) == 3
    #pprint.pprint(dict(st_types))
    for st_type, ways in st_types.items():
        for name in ways:
            better_name = update_name(name, mapping)
            if better_name != name:
                print (name, "=>", better_name)
            #if name == "West Lexington St.":
            #    assert better_name == "West Lexington Street"
            #if name == "Baldwin Rd.":
            #    assert better_name == "Baldwin Road"


if __name__ == '__main__':
    #test()
    st_types = audit(OSM_FILE)
    propose_name(st_types)
    print '\n\n'
    #pprint.pprint(dict(st_types))
# Out:
# ('218', '=>', 'DROP TAG')
# ("St John's Rd", '=>', "St John's Road")
# ('Spur Rd', '=>', 'Spur Road')
# ('Cobham Rd', '=>', 'Cobham Road')
# ('Warwick Rd', '=>', 'Warwick Road')
# ('Ewell Rd', '=>', 'Ewell Road')
# ('Kew Bridge Rd', '=>', 'Kew Bridge Road')
# ('24', '=>', 'DROP TAG')
# ('WALTON ROAD', '=>', 'Walton Road')
# ('Rectory Grove Hampton TW12 1EG', '=>', 'Rectory Grove')
# ('Kingston Avenuen', '=>', 'Kingston Avenue')
# ('sydney street', '=>', 'Sydney Street')
# ('Beacon Rd (Entrance Sanctuary Rd)', '=>', 'Beacon Road')
# ('Sheffield Rd, Heathrow Airport (LHR)', '=>', 'Sheffield Road')
# ('Kings road', '=>', 'Kings Road')
# ('Langdon park', '=>', 'Langdon Park')
# ('Eden St', '=>', 'Eden Street')
# ('Ebury Strreet', '=>', 'Ebury Street')
# ('11', '=>', 'DROP TAG')
# ('Quintin Ave', '=>', 'Quintin Avenue')
# ('Baywillow Ave', '=>', 'Baywillow Avenue')
# ('Wimbledon', '=>', 'Wimbledon Hill Road')
# ('Town lane', '=>', 'Town Lane')

# %% [markdown]
# **NOTE all problem names now either have fix, or will drop**
#
#
# Street names still to fix (working list)
# ```
# '11': set(['11']), - ignore / drop
#  '1EG': set(['Rectory Grove Hampton TW12 1EG']), -- CHANGE to Rectory Grove
#  '218': set(['218']) - ignore / drop
#  '24': set(['24']) - ignore / drop
#
# 'Chelsea': set(['Fulham Road, Chelsea']) -- CHANGE to Fulham Road
#
# 'LHR)': set(['Sheffield Rd, Heathrow Airport (LHR)']), -- CHANGE to Sheffield Road
#
# 'Rd)': set(['Beacon Rd (Entrance Sanctuary Rd)']), -- CHANGE to Beacon Road
#
# REMOVED FROM PROBLEM LIST 'Ridgway': set(['Ridgway']), -- to 'The Ridgway' _ Correct sp?
#
# REMOVED FROM PROBLEM LIST'Station': set(['Richmond Station']), - leave -platform address
#
# REMOVED FROM PROBLEM LIST 'Walton': set(['The Heart of Walton']), -- leave - shopping centre
#
# REMOVED FROM PROBLEM LIST'Whitton': set(['High Street Whitton']), Correct!
#
# 'Wimbledon': set(['Wimbledon']), - CHANGE to Wimbledon Hill Road
# ```

# %% [markdown]
# #### Counting tag k: attribs
#
# a look at all the 'k' attribs in tags to look for problems.

# %%
#OSM_FILE = 'swlondon_sample.osm' 
OSM_FILE = 'swlondon.osm'


def process_map(filename):
    tag_ks = defaultdict(int)
    n=0
    for _, element in ET.iterparse(filename):
        n+=1
        #if n>20000: break
        #print (n, _, element)
        if element.tag == "tag":
            tag_ks[element.attrib['k']] += 1


    return tag_ks


if __name__ == "__main__":
    tag_keys = process_map(OSM_FILE)
    pprint.pprint(sorted(tag_keys.items() , key=lambda x: x[1], reverse=True))
# Out:
# [('highway', 78659),
#  ('building', 77127),
#  ('name', 59270),
#  ('source', 39911),
#  ('created_by', 30980),
#  ('addr:housenumber', 25247),
#  ('addr:street', 21598),
#  ('lit', 15215),
#  ('amenity', 13599),
#  ('maxspeed', 13555),
#  ('source:name', 11109),
#  ('surface', 10187),
#  ('ref', 9130),
#  ('oneway', 9026),
#  ('barrier', 8903),
#  ('natural', 8163),
#  ('naptan:verified', 7254),
#  ('landuse', 6987),
#  ('foot', 6895),
#  ('addr:postcode', 6864),
#  ('addr:city', 6008),
#  ('access', 5775),
#  ('operator', 5603),
#  ('service', 5484),
#  ('naptan:AtcoCode', 5467),
#  ('bicycle', 5356),
#  ('naptan:CommonName', 5326),
#  ('naptan:Bearing', 5323),
#  ('shop', 5048),
#  ('naptan:Indicator', 4412),
#  ('building:levels', 4294),
#  ('leisure', 4150),
#  ('type', 4127),
#  ('lanes', 4121),
#  ('naptan:Street', 3935),
#  ('layer', 3266),
#  ('sidewalk', 3162),
#  ('railway', 2931),
#  ('crossing', 2781),
#  ('local_ref', 2554),
#  ('footway', 2447),
#  ('bridge', 2442),
#  ('naptan:StopAreaType', 2127),
#  ('naptan:StopAreaCode', 2127),
#  ('website', 2117),
#  ('addr:country', 2115),
#  ('site', 2112),
#  ('note', 2090),
#  ('cycleway', 2053),
#  ('gauge', 1961),
#  ('electrified', 1909),
#  ('source:ref', 1896),
#  ('voltage', 1874),
#  ('source:maxspeed', 1870),
#  ('fhrs:id', 1858),
#  ('frequency', 1835),
#  ('addr:housename', 1830),
#  ('naptan:Landmark', 1819),
#  ('naptan:NaptanCode', 1817),
#  ('segregated', 1776),
#  ('sport', 1593),
#  ('waterway', 1580),
#  ('phone', 1381),
#  ('designation', 1366),
#  ('leaf_type', 1334),
#  ('aeroway', 1288),
#  ('horse', 1265),
#  ('kerb', 1244),
#  ('usage', 1201),
#  ('motor_vehicle', 1200),
#  ('sloped_curb', 1198),
#  ('addr:suburb', 1130),
#  ('source:addr', 1112),
#  ('lcn', 1088),
#  ('cuisine', 1054),
#  ('postal_code', 1009),
#  ('wheelchair', 1000),
#  ('network', 966),
#  ('opening_hours', 958),
#  ('area', 948),
#  ('traffic_calming', 925),
#  ('crossing_ref', 858),
#  ('tunnel', 848),
#  ('junction', 840),
#  ('capacity', 838),
#  ('power', 754),
#  ('addr:district', 724),
#  ('addr:subdistrict', 722),
#  ('alt_name', 643),
#  ('passenger_lines', 634),
#  ('route', 628),
#  ('religion', 602),
#  ('tourism', 590),
#  ('survey:date', 588),
#  ('entrance', 579),
#  ('highways_england:area', 573),
#  ('level', 562),
#  ('man_made', 555),
#  ('description', 550),
#  ('addr:interpolation', 533),
#  ('direction', 530),
#  ('parking', 522),
#  ('wikipedia', 510),
#  ('maxspeed:type', 495),
#  ('building:material', 472),
#  ('building:colour', 471),
#  ('covered', 460),
#  ('denomination', 459),
#  ('restriction', 452),
#  ('office', 451),
#  ('place', 451),
#  ('public_transport', 451),
#  ('fixme', 420),
#  ('tracks', 408),
#  ('fee', 392),
#  ('post_box:type', 385),
#  ('shelter', 380),
#  ('roof:shape', 355),
#  ('royal_cypher', 354),
#  ('line', 333),
#  ('wheelchair:description', 324),
#  ('roof:levels', 318),
#  ('ref:edubase', 317),
#  ('track_detail', 312),
#  ('tracktype', 304),
#  ('passenger', 295),
#  ('roof:colour', 293),
#  ('carriageway_ref', 268),
#  ('traffic_signals:direction', 264),
#  ('boat', 259),
#  ('bicycle_parking', 259),
#  ('public_transport:version', 225),
#  ('wikidata', 221),
#  ('historic', 221),
#  ('boundary', 212),
#  ('dominant_taxon', 209),
#  ('collection_times', 209),
#  ('emergency', 208),
#  ('toilets', 206),
#  ('incline', 206),
#  ('heath', 205),
#  ('roof:orientation', 199),
#  ('turn:lanes', 197),
#  ('width', 197),
#  ('naptan:PlusbusZoneRef', 196),
#  ('toilets:access', 194),
#  ('cycleway:est_width', 190),
#  ('bus', 189),
#  ('motorcar', 187),
#  ('golf', 187),
#  ('to', 178),
#  ('from', 175),
#  ('admin_level', 175),
#  ('maxspeed:variable', 173),
#  ('active_traffic_management', 166),
#  ('contact:website', 164),
#  ('not:name', 160),
#  ('branch', 156),
#  ('addr:flats', 154),
#  ('old_name', 148),
#  ('supervised', 147),
#  ('noexit', 143),
#  ('naptan:BusStopType', 142),
#  ('water', 142),
#  ('tactile_paving', 141),
#  ('building:part', 140),
#  ('park_ride', 137),
#  ('indoor', 136),
#  ('atm', 135),
#  ('motorboat', 134),
#  ('email', 132),
#  ('cycleway:right', 130),
#  ('is_in', 128),
#  ('source:addr:postcode', 128),
#  ('source:designation', 127),
#  ('maxweight', 127),
#  ('cycleway:left', 127),
#  ('embankment', 125),
#  ('contact:phone', 124),
#  ('cutting', 124),
#  ('toilets:wheelchair', 122),
#  ('information', 121),
#  ('oneway:bicycle', 119),
#  ('start_date', 117),
#  ('FIXME', 116),
#  ('sign_information', 112),
#  ('source:geometry', 111),
#  ('lcn_ref', 110),
#  ('maxheight', 109),
#  ('fence_type', 107),
#  ('takeaway', 103),
#  ('abutters', 101),
#  ('tidal', 101),
#  ('backrest', 100),
#  ('name:en', 97),
#  ('clopin:route', 97),
#  ('clopin:note', 96),
#  ('smoking', 96),
#  ('clopin:id', 96),
#  ('outdoor_seating', 89),
#  ('bench', 89),
#  ('complete', 87),
#  ('subway', 83),
#  ('leaf_cycle', 83),
#  ('towpath', 83),
#  ('material', 82),
#  ('height', 82),
#  ('brand', 82),
#  ('est_width', 81),
#  ('train', 80),
#  ('loading_gauge', 80),
#  ('internet_access', 79),
#  ('airside', 79),
#  ('house', 78),
#  ('source:track', 76),
#  ('status', 76),
#  ('psv', 75),
#  ('vending', 75),
#  ('disused:aeroway', 74),
#  ('species', 72),
#  ('source:postcode', 71),
#  ('maxwidth', 69),
#  ('booth', 68),
#  ('uk_postcode_centroid', 68),
#  ('operator:wikidata', 68),
#  ('image', 67),
#  ('dispensing', 65),
#  ('hgv', 64),
#  ('proposed:active_traffic_management', 64),
#  ('addr:unit', 63),
#  ('ncn_ref', 62),
#  ('motorcycle', 62),
#  ('tube', 62),
#  ('old_ref', 61),
#  ('craft', 61),
#  ('disused', 60),
#  ('isced:level', 56),
#  ('url', 56),
#  ('food', 55),
#  ('highway_1', 54),
#  ('smoothness', 53),
#  ('aeroway:gate:type', 53),
#  ('source:building', 53),
#  ('source_ref', 50),
#  ('ref:gss', 49),
#  ('name:ru', 49),
#  ('construction', 49),
#  ('alt_ref', 48),
#  ('cables', 48),
#  ('trail_visibility', 47),
#  ('decade_built', 45),
#  ('attraction', 45),
#  ('traffic_signals', 45),
#  ('substation', 44),
#  ('collection_plate', 44),
#  ('note:retag', 43),
#  ('route_master', 43),
#  ('uri', 42),
#  ('cycleway:right:width', 41),
#  ('source:access', 41),
#  ('recycling:paper', 40),
#  ('SOURCE1', 40),
#  ('PHABFEANOT', 40),
#  ('S1CAPTDATE', 40),
#  ('S1HABCLASS', 40),
#  ('SOURCE2', 40),
#  ('SOURCE1TXT', 40),
#  ('S1HABTYPE', 40),
#  ('CREATEDATE', 40),
#  ('PRIHAB', 40),
#  ('BROADHAB', 40),
#  ('service_times', 40),
#  ('NBNPRIHAB', 40),
#  ('PRIHABTXT', 40),
#  ('HABDEFVER', 40),
#  ('SOURCE3', 40),
#  ('colour', 40),
#  ('INCID', 40),
#  ('S1HABID', 40),
#  ('INTERPQUAL', 40),
#  ('destination', 40),
#  ('CREATEDBY', 40),
#  ('PRIDET', 40),
#  ('S1BOUNDARY', 40),
#  ('tower:type', 38),
#  ('disused:amenity', 38),
#  ('building:start_date', 38),
#  ('cycleway:left:width', 37),
#  ('lanes:forward', 37),
#  ('turn:lanes:forward', 36),
#  ('building:min_level', 36),
#  ('lanes:backward', 36),
#  ('post_box:apertures', 36),
#  ('step_count', 36),
#  ('loc_ref', 36),
#  ('real_ale', 35),
#  ('roof:material', 35),
#  ('recycling:cans', 35),
#  ('lightsource', 35),
#  ('source:lcn', 33),
#  ('healthcare', 32),
#  ('wifi', 32),
#  ('source:bicycle', 31),
#  ('drive_through', 31),
#  ('bus_stop', 30),
#  ('right:district', 30),
#  ('stile', 30),
#  ('change:lanes', 30),
#  ('prow_ref', 30),
#  ('recycling:clothes', 29),
#  ('recycling:glass', 29),
#  ('addr:place', 29),
#  ('designated', 29),
#  ('left:district', 29),
#  ('construction_contract_name', 29),
#  ('history', 28),
#  ('hiking', 27),
#  ('lock', 27),
#  ('generator:source', 27),
#  ('generator:output:electricity', 27),
#  ('short_name', 27),
#  ('seats', 27),
#  ('fire_hydrant:type', 27),
#  ('brewery', 26),
#  ('fax', 25),
#  ('source:addr:housenumber', 25),
#  ('physically_present', 25),
#  ('parking:lane', 25),
#  ('route_ref', 25),
#  ('oneway:foot', 25),
#  ('delivery', 25),
#  ('source:ons_code', 24),
#  ('use', 24),
#  ('male', 24),
#  ('state', 24),
#  ('source:highway', 24),
#  ('generator:method', 24),
#  ('payment:coins', 24),
#  ('council_name', 24),
#  ('ons_code', 24),
#  ('car', 23),
#  ('turn:lanes:backward', 23),
#  ('addr:floor', 23),
#  ('lock_name', 23),
#  ('ele', 23),
#  ('path', 22),
#  ('shelter_type', 22),
#  ('railway:traffic_mode', 22),
#  ('source_ref:ref', 22),
#  ('taxi', 22),
#  ('artwork_type', 22),
#  ('recycling_type', 22),
#  ('clothes', 21),
#  ('noname', 21),
#  ('post_box:design', 21),
#  ('roadside_pavement', 21),
#  ('disused:name', 21),
#  ('railway:track_ref', 20),
#  ('ref:stanox', 20),
#  ('golf:course', 20),
#  ('ncn', 20),
#  ('postcode', 20),
#  ('surveillance', 20),
#  ('destination:lanes', 20),
#  ('golf:par', 19),
#  ('roller_coaster', 19),
#  ('source_ref:name', 19),
#  ('fire_hydrant:position', 19),
#  ('fhrs:local_authority_id', 19),
#  ('fire_hydrant:diameter', 19),
#  ('right:county', 18),
#  ('private', 18),
#  ('name:fr', 18),
#  ('abandoned:highway', 18),
#  ('recycling:cardboard', 18),
#  ('par', 18),
#  ('internet_access:fee', 18),
#  ('fhrs:authority', 18),
#  ('bridge:name', 18),
#  ('memorial', 18),
#  ('left:county', 18),
#  ('_ID_', 17),
#  ('ISO3166-2', 17),
#  ('recycling:plastic_bottles', 17),
#  ('local', 17),
#  ('board_type', 17),
#  ('gated', 17),
#  ('denotation', 17),
#  ('mooring', 16),
#  ('club', 16),
#  ('conveying', 16),
#  ('content', 16),
#  ('bridge_ref', 16),
#  ('elevator', 16),
#  ('is_in:district', 16),
#  ('social_facility', 16),
#  ('contact:email', 16),
#  ('vway:highway', 16),
#  ('social_facility:for', 16),
#  ('wires', 16),
#  ('location', 16),
#  ('female', 16),
#  ('stars', 16),
#  ('loc_name', 15),
#  ('disused:shop', 15),
#  ('flickr', 15),
#  ('except', 15),
#  ('payment:bitcoin', 15),
#  ('int_ref', 14),
#  ('tram', 14),
#  ('note:name', 14),
#  ('source:ref:gss', 14),
#  ('signed:name', 14),
#  ('cyclestreets_id', 14),
#  ('lcn_ref_1', 14),
#  ('traffic', 14),
#  ('name:de', 14),
#  ('addr:apartment', 14),
#  ('recycling:glass_bottles', 14),
#  ('contact:google_plus', 13),
#  ('source:bridge', 13),
#  ('naptan:AltStreet', 13),
#  ('capacity:disabled', 13),
#  ('naptan:AltCommonName', 13),
#  ('dog', 13),
#  ('fhrs:rating', 13),
#  ('abandoned:ref', 13),
#  ('advertising', 13),
#  ('display', 13),
#  ('psv:lanes', 13),
#  ('seamark:type', 12),
#  ('contact:facebook', 12),
#  ('name:zh', 12),
#  ('school', 12),
#  ('addr:flat', 12),
#  ('map_size', 12),
#  ('maxspeed:conditional', 12),
#  ('id', 12),
#  ('steps', 12),
#  ('lanes:psv', 12),
#  ('floating', 12),
#  ('surveillance:type', 11),
#  ('vehicle', 11),
#  ('building:flats', 11),
#  ('payment:telephone_cards', 11),
#  ('wikimedia_commons', 11),
#  ('odbl', 11),
#  ('brand:wikidata', 11),
#  ('lanes:left', 11),
#  ('rooms', 11),
#  ('button_operated', 11),
#  ('source:cycleway', 11),
#  ('lock_ref', 11),
#  ('proposed:maxspeed', 11),
#  ('source:motor_vehicle', 10),
#  ('name:pl', 10),
#  ('disused:highway', 10),
#  ('recycling:newspaper', 10),
#  ('artist_name', 10),
#  ('seamark:bridge:category', 10),
#  ('traffic_signals:sound', 10),
#  ('towards', 10),
#  ('ford', 10),
#  ('grassland', 10),
#  ('payment:credit_cards', 10),
#  ('source:pkey', 10),
#  ('building:use', 10),
#  ('ramp', 10),
#  ('recycling:plastic', 10),
#  ('seamark:name', 10),
#  ('maintenance', 10),
#  ('source:maxweight', 10),
#  ('via', 10),
#  ('destination:ref', 10),
#  ('name:uk', 9),
#  ('source:destination', 9),
#  ('seamark:bridge:clearance_height', 9),
#  ('post_box:manufacturer', 9),
#  ('generator:output:hot_water', 9),
#  ('source:horse', 9),
#  ('historic:highway', 9),
#  ('tunnel:name', 9),
#  ('wetland', 9),
#  ('circuits', 9),
#  ('council_style', 9),
#  ('recycling:magazines', 8),
#  ('crop', 8),
#  ('access:conditional', 8),
#  ('contact:twitter', 8),
#  ('building:roof:shape', 8),
#  ('beauty', 8),
#  ('telecom', 8),
#  ('industrial', 8),
#  ('oneway:bus', 8),
#  ('map_type', 8),
#  ('second_hand', 8),
#  ('support', 8),
#  ('source:ref:lau:1', 8),
#  ('paved', 8),
#  ('disused:railway', 8),
#  ('healthcare:speciality', 8),
#  ('trade', 8),
#  ('name:es', 8),
#  ('fuel:diesel', 8),
#  ('surveillance:zone', 8),
#  ('source:old_name', 8),
#  ('fuel:octane_95', 8),
#  ('cycle_network', 8),
#  ('passenger_information_display', 8),
#  ('authority', 8),
#  ('source:oneway', 8),
#  ('ref:lau:1', 8),
#  ('source:alt_name', 7),
#  ('military', 7),
#  ('handrail', 7),
#  ('opening_date', 7),
#  ('colour:text', 7),
#  ('placement:backward', 7),
#  ('inscription', 7),
#  ('colour:arrow', 7),
#  ('camera:mount', 7),
#  ('lastcheck', 7),
#  ('fhrs:confidence_management', 7),
#  ('length', 7),
#  ('aerialway', 7),
#  ('name:he', 7),
#  ('fhrs:hygiene', 7),
#  ('mkgmap:flare-check', 7),
#  ('name:lt', 7),
#  ('addr:flatnumber', 7),
#  ('int_name', 7),
#  ('note:lcn', 7),
#  ('pitch:count', 7),
#  ('change:lanes:backward', 7),
#  ('recycling:batteries', 7),
#  ('flood_prone', 7),
#  ('change:lanes:forward', 7),
#  ('colour:back', 7),
#  ('waste', 7),
#  ('fhrs:structural', 7),
#  ('customers', 7),
#  ('layby', 7),
#  ('source:prow_ref', 7),
#  ('maxweight:conditional', 7),
#  ('historic:aeroway', 7),
#  ('access:note', 7),
#  ('orienteering', 7),
#  ('source:ncn', 7),
#  ('fhrs:rating_date', 7),
#  ('diaper', 7),
#  ('crossing:barrier', 6),
#  ('cycleway:oneside', 6),
#  ('notes', 6),
#  ('area:highway', 6),
#  ('lawyer', 6),
#  ('FIXME:nsl', 6),
#  ('organic', 6),
#  ('wheelchair_toilet', 6),
#  ('gender', 6),
#  ('parking:lane:both', 6),
#  ('population', 6),
#  ('intermittent', 6),
#  ('name:it', 6),
#  ('recycling:scrap_metal', 6),
#  ('cycleway:oneside:width', 6),
#  ('placement', 6),
#  ('payment:debit_cards', 6),
#  ('bridge:alt_name', 6),
#  ('bridge_name', 6),
#  ('recycling:cartons', 6),
#  ('opening_hours:kitchen', 6),
#  ('toilets:disposal', 6),
#  ('amenity:disused', 6),
#  ('fhrs:inspectiondate', 6),
#  ('platforms', 6),
#  ('traffic_signals:vibration', 6),
#  ('memorial:type', 6),
#  ('width:lanes:forward', 6),
#  ('heritage', 6),
#  ('courts', 6),
#  ('deaf:description:en', 6),
#  ('width:lanes:backward', 6),
#  ('maxstay', 6),
#  ('source:ncn_ref', 5),
#  ('name:gl', 5),
#  ('exit_to', 5),
#  ('randomjunk_bot', 5),
#  ('phone2', 5),
#  ('diet:vegetarian', 5),
#  ('source:width', 5),
#  ('lanes:bus:forward', 5),
#  ('recycling:green_waste', 5),
#  ('recycling:shoes', 5),
#  ('disabled', 5),
#  ('abandoned:sport', 5),
#  ('curve_geometry', 5),
#  ('old_amenity', 5),
#  ('owner', 5),
#  ('priority', 5),
#  ('camera:type', 5),
#  ('crossing:light', 5),
#  ('wood', 5),
#  ('maxspeed:proposed', 5),
#  ('ramp:bicycle', 5),
#  ('abandoned', 5),
#  ('demolished:building', 5),
#  ('beer_garden', 5),
#  ('payment:american_express', 5),
#  ('name:be', 5),
#  ('maxheight:note', 5),
#  ('community_centre:for', 5),
#  ('historic:place', 5),
#  ('bicycle:lanes:forward', 4),
#  ('max_age', 4),
#  ('historic:amenity', 4),
#  ('facebook', 4),
#  ('cargo', 4),
#  ('political_division', 4),
#  ('note:opening_hours', 4),
#  ('address', 4),
#  ('icao', 4),
#  ('source:lanes', 4),
#  ('watch:80n', 4),
#  ('locked', 4),
#  ('speed_camera_type', 4),
#  ('species:en', 4),
#  ('lanes:psv:backward', 4),
#  ('wetap:status', 4),
#  ('meat', 4),
#  ('width_est', 4),
#  ('water_slide', 4),
#  ('underground', 4),
#  ('addr:state', 4),
#  ('tents', 4),
#  ('fish', 4),
#  ('lanes:psv:forward', 4),
#  ('access:lanes:forward', 4),
#  ('resource', 4),
#  ('levels', 4),
#  ('naptan:Notes', 4),
#  ('addr:full', 4),
#  ('freight', 4),
#  ('capacity:parent', 4),
#  ('name:hu', 4),
#  ('recycling:waste', 4),
#  ('lanes:bus', 4),
#  ('genus', 4),
#  ('recycling:plastic_packaging', 4),
#  ('listed_status', 4),
#  ('level_crossing', 4),
#  ('source:opening_hours', 4),
#  ('sutton:render', 4),
#  ('building_supplies', 4),
#  ('addr:town', 4),
#  ('animal_boarding', 4),
#  ('maxspeed:advisory', 4),
#  ('goods', 4),
#  ('fixme:addr2', 4),
#  ('vegetables', 4),
#  ('lane', 4),
#  ('name:gv', 4),
#  ('heritage:operator', 4),
#  ('note2', 3),
#  ('source:amenity', 3),
#  ('cycleway:otherside:width', 3),
#  ('ref:nuts:3', 3),
#  ('fuel:lpg', 3),
#  ('name:ja', 3),
#  ('substance', 3),
#  ('fenced', 3),
#  ('recycling:wood', 3),
#  ('upload_tag', 3),
#  ('sculptor', 3),
#  ('name:fi', 3),
#  ('number_of', 3),
#  ('bus_stop_ref', 3),
#  ('bus:lanes:forward', 3),
#  ('crossing_type', 3),
#  ('todo', 3),
#  ('bus_bay', 3),
#  ('caravans', 3),
#  ('landuse_1', 3),
#  ('construction_date', 3),
#  ('railway:historic', 3),
#  ('destination:ref:lanes', 3),
#  ('station', 3),
#  ('service:bicycle:pump', 3),
#  ('communication:mobile_phone', 3),
#  ('disused:website', 3),
#  ('name:zu', 3),
#  ('royal', 3),
#  ('occupier', 3),
#  ('fimxe:nsl', 3),
#  ('genus:en', 3),
#  ('marching_step', 3),
#  ('name:cs', 3),
#  ('contact:fax', 3),
#  ('signed:ref', 3),
#  ('art', 3),
#  ('official_name', 3),
#  ('official_ref', 3),
#  ('faces', 3),
#  ('addr:name', 3),
#  ('name:cy', 3),
#  ('tunnel:short_name', 3),
#  ('country', 3),
#  ('note:maxheight', 3),
#  ('source:ref:nuts:3', 3),
#  ('residential', 3),
#  ('max_level', 3),
#  ('cycle', 3),
#  ('note:alt_name', 3),
#  ('source:outline', 3),
#  ('transformer', 3),
#  ('unsigned', 3),
#  ('parking:condition:both', 3),
#  ('amenity_1', 3),
#  ('duration', 3),
#  ('min_level', 3),
#  ('repair', 3),
#  ('source:maxheight', 3),
#  ('ramp:wheelchair', 3),
#  ('name:ga', 3),
#  ('bearing', 3),
#  ('runway', 3),
#  ('building:name', 3),
#  ('traffic_sign', 3),
#  ('recycling:paper_packaging', 3),
#  ('min_age', 3),
#  ('depth', 3),
#  ('source:landuse', 2),
#  ('anglican', 2),
#  ('maxweight:comment', 2),
#  ('Business', 2),
#  ('name:ko', 2),
#  ('recycling:mobile_phones', 2),
#  ('garden', 2),
#  ('canoe', 2),
#  ('street', 2),
#  ('fireplace', 2),
#  ('gravitystorm:todo', 2),
#  ('sign', 2),
#  ('busway', 2),
#  ('former_name', 2),
#  ('recycling:engine_oil', 2),
#  ('service:bicycle:retail', 2),
#  ('massage', 2),
#  ('diameter', 2),
#  ('name_left', 2),
#  ('drinkable', 2),
#  ('cat', 2),
#  ('subject:wikipedia', 2),
#  ('monitoring:weather', 2),
#  ('animal', 2),
#  ('ramp:luggage', 2),
#  ('name:fa', 2),
#  ('scout', 2),
#  ('source:busway', 2),
#  ('artwork', 2),
#  ('payment:cash', 2),
#  ('source:position', 2),
#  ('source:housename', 2),
#  ('bridge:start_date', 2),
#  ('recycling:electrical_appliances', 2),
#  ('addr:door', 2),
#  ('busway:left', 2),
#  ('ncn_milepost', 2),
#  ('service:bicycle:repair', 2),
#  ('artist:wikipedia', 2),
#  ('real_cider', 2),
#  ('training', 2),
#  ('unisex', 2),
#  ('name:source', 2),
#  ('radar_transponder', 2),
#  ('name:tr', 2),
#  ('name:hi', 2),
#  ('internal_diameter', 2),
#  ('heritage:ref', 2),
#  ('name:hr', 2),
#  ('toilets:scheme', 2),
#  ('architect', 2),
#  ('service:bicycle:chain_tool', 2),
#  ('construction_end_expected', 2),
#  ('ref_name', 2),
#  ('alt_name:ru', 2),
#  ('day_on', 2),
#  ('bar', 2),
#  ('note:location_code', 2),
#  ('name:nl', 2),
#  ('is_in:iso_3166_2', 2),
#  ('use_status', 2),
#  ('psv:lanes:forward', 2),
#  ('recycling:hardcore', 2),
#  ('day_off', 2),
#  ('name:pt', 2),
#  ('alcohol', 2),
#  ('disused:phone', 2),
#  ('shop:vacant', 2),
#  ('name_right', 2),
#  ('payment:mastercard', 2),
#  ('borough', 2),
#  ('source:maxwidth', 2),
#  ('tt_ref', 2),
#  ('rail', 2),
#  ('old_short_name', 2),
#  ('artist:website', 2),
#  ('building_1', 2),
#  ('text_color', 2),
#  ('source:rooms', 2),
#  ('last_collection', 2),
#  ('source_ref:network', 2),
#  ('headway', 2),
#  ('fuel:octane_98', 2),
#  ('recycling:textiles', 2),
#  ('name:right', 2),
#  ('payment:visa', 2),
#  ('lanes:right', 2),
#  ('contractor', 2),
#  ('ownership', 2),
#  ('icn_ref', 2),
#  ('gate:type', 2),
#  ('outdoor', 2),
#  ('abandoned:aeroway', 2),
#  ('lcn_ref_2', 2),
#  ('hour_off', 2),
#  ('fixme:2', 2),
#  ('rental', 2),
#  ('name:da', 2),
#  ('former_amenity', 2),
#  ('place_of_worship', 2),
#  ('wheelchair:note', 2),
#  ('fishing', 2),
#  ('exit', 2),
#  ('area:aeroway', 2),
#  ('ref:nuts:1', 2),
#  ('cycleway:otherside', 2),
#  ('parking:condition:both:maxstay', 2),
#  ('plant:output:electricity', 2),
#  ('landcover', 2),
#  ('fixme:addr1', 2),
#  ('old_fhrs:id', 2),
#  ('rcn', 2),
#  ('phonetic:en', 2),
#  ('dance:teaching', 2),
#  ('count', 2),
#  ('books', 2),
#  ('monument', 2),
#  ('highlight', 2),
#  ('source:comment', 2),
#  ('taxon:en', 2),
#  ('ref:nuts:2', 2),
#  ('disused:office', 2),
#  ('location_code', 2),
#  ('waste_type', 2),
#  ('note_2', 2),
#  ('recycling:beverage_cartons', 2),
#  ('addr:county', 2),
#  ('reservation', 2),
#  ('hour_on', 2),
#  ('disused:cuisine', 2),
#  ('age', 2),
#  ('name:bridge', 2),
#  ('mail:franked', 1),
#  ('ale', 1),
#  ('nursery', 1),
#  ('barbecue', 1),
#  ('bing', 1),
#  ('abandoned:man_made', 1),
#  ('network:train', 1),
#  ('note1', 1),
#  ('automated', 1),
#  ('charity', 1),
#  ('playground', 1),
#  ('brand:website', 1),
#  ('ele:msl', 1),
#  ('barrier:note', 1),
#  ('uic_ref', 1),
#  ('disabled:description', 1),
#  ('watch_repair', 1),
#  ('source:designarion', 1),
#  ('midlevels', 1),
#  ('cutline', 1),
#  ('capacity:car', 1),
#  ('toilets:male', 1),
#  ('meadow', 1),
#  ('martial_art', 1),
#  ('name:szl', 1),
#  ('disused:operator', 1),
#  ('driving_side', 1),
#  ('machines', 1),
#  ('name:fy', 1),
#  ('barrier:rfid', 1),
#  ('fuel:HGV_diesel', 1),
#  ('role:dep_levels', 1),
#  ('sameday', 1),
#  ('public', 1),
#  ('demolished:leisure', 1),
#  ('men', 1),
#  ('destination:ref:to', 1),
#  ('name:br', 1),
#  ('hours', 1),
#  ('maxwidth:bus', 1),
#  ('engraving', 1),
#  ('passengers', 1),
#  ('microbrewery', 1),
#  ('source:1', 1),
#  ('opening_hours:phone', 1),
#  ('microbrewery:note', 1),
#  ('bakery:cuisine', 1),
#  ('capacity:standard', 1),
#  ('heliport', 1),
#  ('community:en', 1),
#  ('role:dep_link_up', 1),
#  ('charge', 1),
#  ('oyster_ticket_stop', 1),
#  ('motorcycle:lanes:forward', 1),
#  ('Ken', 1),
#  ('tower:construction', 1),
#  ('operator:uk', 1),
#  ('recording:automated', 1),
#  ('ref:icao', 1),
#  ('capacity:women', 1),
#  ('maxgcweightrating:hgv:conditional', 1),
#  ('railway:interlaced', 1),
#  ('operator:lux', 1),
#  ('doityourself', 1),
#  ('disused:toilets', 1),
#  ('ref_no', 1),
#  ('obstacle', 1),
#  ('island', 1),
#  ('caution', 1),
#  ('historic:denomination', 1),
#  ('attribution', 1),
#  ('ref:whc', 1),
#  ('tag', 1),
#  ('award:michelin', 1),
#  ('box_type', 1),
#  ('spa', 1),
#  ('sloped_kerb', 1),
#  ('disused:opening_hours', 1),
#  ('place_name', 1),
#  ('wheelchair:description:en', 1),
#  ('viewpoint', 1),
#  ('parking:condition:both:default', 1),
#  ('man_made:disused', 1),
#  ('source:cuisine', 1),
#  ('depot:type', 1),
#  ('operator:nl', 1),
#  ('answer', 1),
#  ('gate', 1),
#  ('whc:criteria', 1),
#  ('product', 1),
#  ('iata', 1),
#  ('alt_name_2', 1),
#  ('acess', 1),
#  ('hazard', 1),
#  ('maxaxleload', 1),
#  ('shooting', 1),
#  ('light:colour', 1),
#  ('date', 1),
#  ('rcn_name', 1),
#  ('cost:coffee', 1),
#  ('swimming_pool', 1),
#  ('destination:symbol', 1),
#  ('is_administered_by', 1),
#  ('access:foot', 1),
#  ('winniedepooh', 1),
#  ('beacon:type', 1),
#  ('arivac:typetxt', 1),
#  ('lanes:psv:right', 1),
#  ('motor_vehicle:conditional', 1),
#  ('recycling:aluminium', 1),
#  ('name:tzl', 1),
#  ('ele:source', 1),
#  ('coach', 1),
#  ('school:gender', 1),
#  ('fryup', 1),
#  ('addr:locality', 1),
#  ('artisan', 1),
#  ('capacity:long', 1),
#  ('name:el', 1),
#  ('inscription:2', 1),
#  ('recycling:electrical_items', 1),
#  ('shop:disused', 1),
#  ('accomodation', 1),
#  ('source:bridge_name', 1),
#  ('development', 1),
#  ('role:dep_link_down', 1),
#  ('waste_disposal', 1),
#  ('ref:fgkz', 1),
#  ('name_1', 1),
#  ('moped', 1),
#  ('name:ar', 1),
#  ('shop_1', 1),
#  ('wpt_symbol', 1),
#  ('sponsor', 1),
#  ('source:embankment', 1),
#  ('year', 1),
#  ('event', 1),
#  ('post_box:mounting', 1),
#  ('railway:signal:position', 1),
#  ('bus:lanes:backward', 1),
#  ('sms', 1),
#  ('health', 1),
#  ('name:sl', 1),
#  ('name:sk', 1),
#  ('mobile', 1),
#  ('sauna', 1),
#  ('source:barrier', 1),
#  ('is_in_postal', 1),
#  ('role:station_el_s_access', 1),
#  ('heritage:website', 1),
#  ('roundabout', 1),
#  ('right:name', 1),
#  ('maxheight:physical', 1),
#  ('addr:city_1', 1),
#  ('is_in:county', 1),
#  ('dogs', 1),
#  ('role:dep_hall', 1),
#  ('ref:wmo', 1),
#  ('source:lit', 1),
#  ('disused:toilets:access', 1),
#  ('distance', 1),
#  ('affiliation', 1),
#  ('capacity:coach', 1),
#  ('socket:type2', 1),
#  ('cost', 1),
#  ('wikipedia:de', 1),
#  ('role:main_ways', 1),
#  ('mtb:scale:imba', 1),
#  ('parking:condition:both:time_interval', 1),
#  ('disused:tourism', 1),
#  ('parish_type', 1),
#  ('fuel:electricity', 1),
#  ('source:bing', 1),
#  ('socket:tesla_supercharger', 1),
#  ('art_supplies', 1),
#  ('recycling:garden_waste', 1),
#  ('specality', 1),
#  ('historic_building', 1),
#  ('source:image', 1),
#  ('power_supply', 1),
#  ('role:sat_link_up', 1),
#  ('recycling:printer_cartridges', 1),
#  ('old:addr:postcode', 1),
#  ('erected_by', 1),
#  ('tower_frequency', 1),
#  ('payment', 1),
#  ('historic:barrier', 1),
#  ('name:absent', 1),
#  ('cover', 1),
#  ('post_office:type', 1),
#  ('incomplete', 1),
#  ('network:subway', 1),
#  ('automatic_door', 1),
#  ('airmark', 1),
#  ('recording:manually', 1),
#  ('artwork_subject', 1),
#  ('proposed', 1),
#  ('not:amenity', 1),
#  ('school:type', 1),
#  ('access:source', 1),
#  ('shoulder', 1),
#  ('opening_hours:url', 1),
#  ('service:bicycle:cleaning', 1),
#  ('source:iata', 1),
#  ('craft_keg', 1),
#  ('access:lanes:backward', 1),
#  ('psv:lanes:backward', 1),
#  ('name:eo', 1),
#  ('old_religion', 1),
#  ('toilets:female', 1),
#  ('money_transfer', 1),
#  ('role:sat_link_down', 1),
#  ('incorrect_name', 1),
#  ('barrier:magnetic_stripe', 1),
#  ('source:steps', 1),
#  ('operator:be', 1),
#  ('railway:signal:main:form', 1),
#  ('carriage', 1),
#  ('opened', 1),
#  ('mapillary', 1),
#  ('source:housenumber', 1),
#  ('recycling:books', 1),
#  ('key', 1),
#  ('whc:inscription_date', 1),
#  ('to:en', 1),
#  ('operator:website', 1),
#  ('residence', 1),
#  ('disused:building', 1),
#  ('bridge:movable', 1),
#  ('comment', 1),
#  ('maxspeed:backward', 1),
#  ('recycling:small_appliances', 1),
#  ('parking:lane:left', 1),
#  ('recycling:electrical', 1),
#  ('recycling', 1),
#  ('community', 1),
#  ('LBRuTTreePreservationOrder', 1),
#  ('maxheight:bus', 1),
#  ('recycling:white_goods', 1),
#  ('currency:GBP', 1),
#  ('memorial_plaque:colour', 1),
#  ('payment:jcb', 1),
#  ('garden:type', 1),
#  ('disused:power', 1),
#  ('disused:ref', 1),
#  ('building:use:residential', 1),
#  ('fixme:3', 1),
#  ('building:use:retail', 1),
#  ('inscription:url', 1),
#  ('motorcycle:clothes', 1),
#  ('tesla:ref', 1),
#  ('toilets:position', 1),
#  ('evangelical', 1),
#  ('Bearing', 1),
#  ('bridge:ref', 1),
#  ('administrative', 1),
#  ('parking:for', 1),
#  ('source:not:name', 1),
#  ('name:et', 1),
#  ('name:vi', 1),
#  ('role:station_elevators', 1),
#  ('parish', 1),
#  ('butcher', 1),
#  ('openplaques_plaque', 1),
#  ('protection_title', 1),
#  ('railway:signal:direction', 1),
#  ('toll', 1),
#  ('garden:style', 1),
#  ('vacant', 1),
#  ('addr:housename:source', 1),
#  ('aircraft:type', 1),
#  ('landmark', 1),
#  ('recycling:bicycles', 1),
#  ('plaque', 1),
#  ('lanes:psv:backward:right', 1),
#  ('source:taxon', 1),
#  ('ball_games', 1),
#  ('marque', 1),
#  ('website2', 1),
#  ('name:ca', 1),
#  ('addr:postcode_1', 1),
#  ('source:surface', 1),
#  ('bollard', 1),
#  ('furniture', 1),
#  ('bdouble', 1),
#  ('bin', 1),
#  ('source:postal_code', 1),
#  ('maxwidth:imperial', 1),
#  ('check_date', 1),
#  ('thermometer', 1),
#  ('color', 1),
#  ('disused:pub', 1),
#  ('ifr', 1),
#  ('HE_ref', 1),
#  ('payments', 1),
#  ('disused:leisure', 1),
#  ('operating_hours', 1),
#  ('university', 1),
#  ('seating', 1),
#  ('source:addr:website', 1),
#  ('to:de', 1),
#  ('oneway:private', 1),
#  ('role:parking_link', 1),
#  ('litter', 1),
#  ('operator:fr', 1),
#  ('historic_name', 1),
#  ('tfl:ref', 1),
#  ('fee:amount', 1),
#  ('transport', 1),
#  ('undergound', 1),
#  ('not:addr:postcode', 1),
#  ('disused:drinking_water', 1),
#  ('contact:youtube', 1),
#  ('railway:signal:route', 1),
#  ('source:tunnel', 1),
#  ('role:t5link', 1),
#  ('variation', 1),
#  ('sport_1', 1),
#  ('tree_lined', 1),
#  ('source:waterway', 1),
#  ('taxon', 1),
#  ('drink:cider', 1),
#  ('payment:litecoin', 1),
#  ('road', 1),
#  ('internet_access:ssid', 1),
#  ('architect:wikipedia', 1),
#  ('thorntons', 1),
#  ('seamark:harbour:category', 1),
#  ('fixme:addr3', 1),
#  ('boat_rental', 1),
#  ('fixme:addr4', 1),
#  ('bicycle:conditional', 1),
#  ('conservation', 1),
#  ('year_of_construction', 1),
#  ('aerodrome', 1),
#  ('TODO', 1),
#  ('ditch', 1),
#  ('role:arr_link_down', 1),
#  ('removed', 1),
#  ('maxgcweightrating:hgv', 1),
#  ('service:bicycle:second_hand', 1),
#  ('name:old', 1),
#  ('recycling:computers', 1),
#  ('name:etymology:wikidata', 1),
#  ('building:architecture', 1),
#  ('source:shape', 1),
#  ('parking:condition', 1),
#  ('engineering', 1),
#  ('ScientificName', 1),
#  ('role:dep_upper', 1),
#  ('demolished:amenity', 1),
#  ('scuba_diving:divespot', 1),
#  ('community:gender', 1),
#  ('shoe_repair', 1),
#  ('fire', 1),
#  ('self_service', 1),
#  ('railway:signal:main', 1),
#  ('telephone_kiosk', 1),
#  ('tfl:reg', 1),
#  ('symbol', 1),
#  ('ref:AEFE', 1),
#  ('min_height', 1),
#  ('sport:scuba', 1),
#  ('aerodrome:type', 1),
#  ('beds', 1),
#  ('pet', 1),
#  ('left:name', 1),
#  ('not:name:fhrs', 1)]

# %% [markdown]
# A look at k = 'types' in tags - to see if they are overwriting any 'higher up' type labels.
#
# I can't see any that are.

# %%
#OSM_FILE = 'swlondon_sample.osm' 
OSM_FILE = 'swlondon.osm'


def is_tag_k_type(elem):
    return (elem.attrib['k'] == "type")


def audit(osmfile):
    osm_file = open(osmfile, "r")

    n=0
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        n+=1
        #if n>2000000: break
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter('tag'):
                if is_tag_k_type(tag):
                    print elem.attrib
                    for tag in elem.iter():
                        print tag.attrib
                        
    osm_file.close()
    return 







if __name__ == '__main__':
    #test()
    audit(OSM_FILE)
# Out:
# {'changeset': '40429617', 'uid': '4198936', 'timestamp': '2016-07-01T22:43:24Z', 'lon': '-0.2521358', 'version': '2', 'user': 'ccityplanner12', 'lat': '51.4728551', 'id': '298847546'}
# {'changeset': '40429617', 'uid': '4198936', 'timestamp': '2016-07-01T22:43:24Z', 'lon': '-0.2521358', 'version': '2', 'user': 'ccityplanner12', 'lat': '51.4728551', 'id': '298847546'}
# {'k': 'description', 'v': 'This is a private house which was once inhabited by the composer Gustav Holst.'}
# {'k': 'historic', 'v': 'memorial'}
# {'k': 'name', 'v': "Holst's House"}
# {'k': 'type', 'v': 'Blue Plaque'}
# {'changeset': '1705558', 'uid': '7630', 'timestamp': '2009-07-01T23:15:05Z', 'lon': '-0.3885019', 'version': '1', 'user': 'LivingWithDragons', 'lat': '51.4047157', 'id': '432011061'}
# {'changeset': '1705558', 'uid': '7630', 'timestamp': '2009-07-01T23:15:05Z', 'lon': '-0.3885019', 'version': '1', 'user': 'LivingWithDragons', 'lat': '51.4047157', 'id': '432011061'}
# {'k': 'description', 'v': 'Moved 2m North in June 1999'}
# {'k': 'highway', 'v': 'milestone'}
# {'k': 'name', 'v': '4&25V1C1, CAP 42'}
# {'k': 'ref', 'v': '42'}
# {'k': 'type', 'v': 'coal_post'}
# {'changeset': '8046626', 'uid': '221923', 'timestamp': '2011-05-04T08:14:01Z', 'lon': '-0.2553622', 'version': '2', 'user': 'michaelinredhill', 'lat': '51.3501257', 'id': '1031188612'}
# {'changeset': '8046626', 'uid': '221923', 'timestamp': '2011-05-04T08:14:01Z', 'lon': '-0.2553622', 'version': '2', 'user': 'michaelinredhill', 'lat': '51.3501257', 'id': '1031188612'}
# {'k': 'Business', 'v': 'Bytes Software Services'}
# {'k': 'type', 'v': 'Software Licensing'}
# {'changeset': '43179253', 'uid': '24119', 'timestamp': '2016-10-25T23:40:57Z', 'lon': '-0.4665061', 'version': '3', 'user': 'Mauls', 'lat': '51.4872426', 'id': '1257657885'}
# {'changeset': '43179253', 'uid': '24119', 'timestamp': '2016-10-25T23:40:57Z', 'lon': '-0.4665061', 'version': '3', 'user': 'Mauls', 'lat': '51.4872426', 'id': '1257657885'}
# {'k': 'aeroway', 'v': 'navigationaid'}
# {'k': 'name', 'v': 'London VOR'}
# {'k': 'operator', 'v': 'UK National Air Traffic Services'}
# {'k': 'ref', 'v': 'LON'}
# {'k': 'type', 'v': 'VOR/DME'}
# {'changeset': '35940070', 'uid': '352985', 'timestamp': '2015-12-14T08:38:48Z', 'lon': '-0.2342761', 'version': '2', 'user': 'ecatmur', 'lat': '51.4517046', 'id': '3889002022'}
# {'changeset': '35940070', 'uid': '352985', 'timestamp': '2015-12-14T08:38:48Z', 'lon': '-0.2342761', 'version': '2', 'user': 'ecatmur', 'lat': '51.4517046', 'id': '3889002022'}
# {'k': 'highway', 'v': 'crossing'}
# {'k': 'type', 'v': 'zebra'}
# {'changeset': '36328491', 'uid': '7630', 'timestamp': '2016-01-02T22:36:36Z', 'lon': '-0.4135109', 'version': '1', 'user': 'LivingWithDragons', 'lat': '51.4154479', 'id': '3924464348'}
# {'changeset': '36328491', 'uid': '7630', 'timestamp': '2016-01-02T22:36:36Z', 'lon': '-0.4135109', 'version': '1', 'user': 'LivingWithDragons', 'lat': '51.4154479', 'id': '3924464348'}
# {'k': 'amenity', 'v': 'bicycle_parking'}
# {'k': 'capacity', 'v': '12'}
# {'k': 'type', 'v': 'wheel_benders'}
# {'changeset': '48326555', 'uid': '352985', 'timestamp': '2017-05-02T07:44:53Z', 'lon': '-0.3062846', 'version': '4', 'user': 'ecatmur', 'lat': '51.4598540', 'id': '4317396125'}
# {'changeset': '48326555', 'uid': '352985', 'timestamp': '2017-05-02T07:44:53Z', 'lon': '-0.3062846', 'version': '4', 'user': 'ecatmur', 'lat': '51.4598540', 'id': '4317396125'}
# {'k': 'amenity', 'v': 'bicycle_parking'}
# {'k': 'capacity', 'v': '16'}
# {'k': 'covered', 'v': 'no'}
# {'k': 'type', 'v': 'stands'}
# {'changeset': '29570216', 'uid': '508', 'timestamp': '2015-03-18T14:20:28Z', 'version': '5', 'user': 'Welshie', 'id': '24409280'}
# {'changeset': '29570216', 'uid': '508', 'timestamp': '2015-03-18T14:20:28Z', 'version': '5', 'user': 'Welshie', 'id': '24409280'}
# {'ref': '33039238'}
# {'ref': '264989040'}
# {'ref': '32849762'}
# {'k': 'access', 'v': 'permissive'}
# {'k': 'highway', 'v': 'residential'}
# {'k': 'name', 'v': 'Rosebery Avenue'}
# {'k': 'type', 'v': 'unsurfaced'}
# {'changeset': '49627425', 'uid': '2445224', 'timestamp': '2017-06-18T06:06:39Z', 'version': '9', 'user': 'rowers2', 'id': '25553616'}
# {'changeset': '49627425', 'uid': '2445224', 'timestamp': '2017-06-18T06:06:39Z', 'version': '9', 'user': 'rowers2', 'id': '25553616'}
# {'ref': '278523376'}
# {'ref': '278523520'}
# {'ref': '278523534'}
# {'ref': '278523373'}
# {'ref': '278523374'}
# {'ref': '3416287131'}
# {'ref': '278523375'}
# {'ref': '278523376'}
# {'k': 'amenity', 'v': 'parking'}
# {'k': 'type', 'v': 'surface'}
# {'changeset': '43759938', 'uid': '118262', 'timestamp': '2016-11-18T10:13:39Z', 'version': '7', 'user': 'Wynndale', 'id': '25568954'}
# {'changeset': '43759938', 'uid': '118262', 'timestamp': '2016-11-18T10:13:39Z', 'version': '7', 'user': 'Wynndale', 'id': '25568954'}
# {'ref': '278707654'}
# {'ref': '278707656'}
# {'ref': '278707657'}
# {'ref': '278707658'}
# {'ref': '278707659'}
# {'ref': '278707660'}
# {'ref': '3393584685'}
# {'ref': '211801929'}
# {'ref': '278707691'}
# {'ref': '298001787'}
# {'ref': '3393584679'}
# {'ref': '3393585498'}
# {'ref': '3393585499'}
# {'ref': '278707652'}
# {'ref': '278707654'}
# {'k': 'addr:postcode', 'v': 'TW12 3HD'}
# {'k': 'addr:street', 'v': 'Hanworth Road'}
# {'k': 'amenity', 'v': 'school'}
# {'k': 'fee', 'v': 'yes'}
# {'k': 'fhrs:id', 'v': '352981'}
# {'k': 'gender', 'v': 'male'}
# {'k': 'isced:level', 'v': '2'}
# {'k': 'name', 'v': 'Hampton School'}
# {'k': 'school', 'v': 'private'}
# {'k': 'source:addr', 'v': 'FHRS Open Data'}
# {'k': 'type', 'v': 'secondary'}
# {'k': 'website', 'v': 'http://www.hamptonschool.org.uk/'}
# {'changeset': '44021953', 'uid': '118262', 'timestamp': '2016-11-28T23:26:38Z', 'version': '6', 'user': 'Wynndale', 'id': '25568955'}
# {'changeset': '44021953', 'uid': '118262', 'timestamp': '2016-11-28T23:26:38Z', 'version': '6', 'user': 'Wynndale', 'id': '25568955'}
# {'ref': '278707666'}
# {'ref': '278707667'}
# {'ref': '3393585494'}
# {'ref': '3393585493'}
# {'ref': '3393584692'}
# {'ref': '3393584691'}
# {'ref': '566732574'}
# {'ref': '566732648'}
# {'ref': '566732638'}
# {'ref': '566732625'}
# {'ref': '566732616'}
# {'ref': '278707677'}
# {'ref': '3393584689'}
# {'ref': '278707700'}
# {'ref': '3393584685'}
# {'ref': '278707660'}
# {'ref': '278707659'}
# {'ref': '278707678'}
# {'ref': '278707666'}
# {'k': 'addr:housenumber', 'v': '102'}
# {'k': 'addr:postcode', 'v': 'TW12 3HF'}
# {'k': 'addr:street', 'v': 'Hanworth Road'}
# {'k': 'amenity', 'v': 'school'}
# {'k': 'fee', 'v': 'yes'}
# {'k': 'fhrs:id', 'v': '353688'}
# {'k': 'gender', 'v': 'female'}
# {'k': 'isced:level', 'v': '2'}
# {'k': 'name', 'v': 'The Lady Eleanor Holles School'}
# {'k': 'school', 'v': 'private'}
# {'k': 'source:addr', 'v': 'FHRS Open Data'}
# {'k': 'type', 'v': 'secondary'}
# {'k': 'website', 'v': 'http://www.lehs.org.uk/'}
# {'changeset': '21084104', 'uid': '872282', 'timestamp': '2014-03-13T15:15:27Z', 'version': '11', 'user': 'rusholme', 'id': '31348488'}
# {'changeset': '21084104', 'uid': '872282', 'timestamp': '2014-03-13T15:15:27Z', 'version': '11', 'user': 'rusholme', 'id': '31348488'}
# {'ref': '1257704328'}
# {'ref': '1945892724'}
# {'ref': '1257704317'}
# {'ref': '1945892731'}
# {'ref': '1257704314'}
# {'ref': '1945892727'}
# {'ref': '1257704311'}
# {'ref': '1945892729'}
# {'ref': '1257704319'}
# {'ref': '2715594324'}
# {'ref': '1945892723'}
# {'ref': '1257704329'}
# {'ref': '1945892728'}
# {'ref': '1257704321'}
# {'ref': '1945892726'}
# {'ref': '1257704312'}
# {'ref': '1945892721'}
# {'ref': '1257704315'}
# {'ref': '1945892730'}
# {'ref': '1257704328'}
# {'k': 'aeroway', 'v': 'navigationaid'}
# {'k': 'man_made', 'v': 'tower'}
# {'k': 'name', 'v': 'Ockham VOR/DME'}
# {'k': 'operator', 'v': 'UK National Air Traffic Services'}
# {'k': 'ref', 'v': 'OCK'}
# {'k': 'type', 'v': 'VOR/DME'}
# {'changeset': '32295730', 'uid': '618726', 'timestamp': '2015-06-29T22:27:08Z', 'version': '5', 'user': 'Pgd81', 'id': '35824619'}
# {'changeset': '32295730', 'uid': '618726', 'timestamp': '2015-06-29T22:27:08Z', 'version': '5', 'user': 'Pgd81', 'id': '35824619'}
# {'ref': '418825673'}
# {'ref': '418825674'}
# {'ref': '418825676'}
# {'ref': '418825677'}
# {'ref': '3625958017'}
# {'ref': '418825679'}
# {'ref': '418825680'}
# {'ref': '3625957954'}
# {'ref': '418825681'}
# {'ref': '2377275628'}
# {'ref': '1583910876'}
# {'ref': '3625957944'}
# {'ref': '1583910879'}
# {'ref': '418825684'}
# {'ref': '418825685'}
# {'ref': '418825686'}
# {'ref': '418825673'}
# {'k': 'building', 'v': 'yes'}
# {'k': 'name', 'v': 'Merton Bus Garage'}
# {'k': 'operator', 'v': 'Go-Ahead London'}
# {'k': 'tfl:ref', 'v': 'AL'}
# {'k': 'type', 'v': 'bus'}
# {'changeset': '4491419', 'uid': '6035', 'timestamp': '2010-04-21T22:10:43Z', 'version': '1', 'user': 'Sorbus_x_kewensis', 'id': '56046726'}
# {'changeset': '4491419', 'uid': '6035', 'timestamp': '2010-04-21T22:10:43Z', 'version': '1', 'user': 'Sorbus_x_kewensis', 'id': '56046726'}
# {'ref': '703504888'}
# {'ref': '703504889'}
# {'ref': '703504890'}
# {'ref': '703504891'}
# {'ref': '703504888'}
# {'k': 'building', 'v': 'yes'}
# {'k': 'name', 'v': 'Kew Cricket Club'}
# {'k': 'type', 'v': 'pavilion'}
# {'changeset': '32983952', 'uid': '181135', 'timestamp': '2015-07-30T15:35:55Z', 'version': '3', 'user': 'Manu1400', 'id': '57836783'}
# {'changeset': '32983952', 'uid': '181135', 'timestamp': '2015-07-30T15:35:55Z', 'version': '3', 'user': 'Manu1400', 'id': '57836783'}
# {'ref': '717553843'}
# {'ref': '717553844'}
# {'k': 'man_made', 'v': 'pipeline'}
# {'k': 'type', 'v': 'gas'}
# {'changeset': '47245678', 'uid': '322039', 'timestamp': '2017-03-29T01:28:36Z', 'version': '2', 'user': 'MacLondon', 'id': '188617701'}
# {'changeset': '47245678', 'uid': '322039', 'timestamp': '2017-03-29T01:28:36Z', 'version': '2', 'user': 'MacLondon', 'id': '188617701'}
# {'ref': '1992386333'}
# {'ref': '1992386332'}
# {'ref': '1992386329'}
# {'ref': '1992386331'}
# {'ref': '1992386326'}
# {'ref': '1992386334'}
# {'ref': '1992386335'}
# {'ref': '1992386330'}
# {'ref': '641804747'}
# {'ref': '1992386327'}
# {'ref': '641804758'}
# {'ref': '1992386328'}
# {'ref': '4760914663'}
# {'ref': '4760914657'}
# {'ref': '4760914665'}
# {'ref': '1992386333'}
# {'k': 'amenity', 'v': 'hospital'}
# {'k': 'emergency', 'v': 'yes'}
# {'k': 'name', 'v': 'Charing Cross Hospital'}
# {'k': 'source', 'v': 'Local knowledge'}
# {'k': 'type', 'v': 'general acute hospital'}
# {'changeset': '16864756', 'uid': '30525', 'timestamp': '2013-07-07T19:15:04Z', 'version': '1', 'user': 'The Maarssen Mapper', 'id': '229094650'}
# {'changeset': '16864756', 'uid': '30525', 'timestamp': '2013-07-07T19:15:04Z', 'version': '1', 'user': 'The Maarssen Mapper', 'id': '229094650'}
# {'ref': '2377301489'}
# {'ref': '2377301483'}
# {'ref': '2377301481'}
# {'ref': '2377301487'}
# {'ref': '2377301482'}
# {'ref': '2377301486'}
# {'ref': '2377301489'}
# {'k': 'building', 'v': 'yes'}
# {'k': 'landuse', 'v': 'depot'}
# {'k': 'name', 'v': 'Wandsworth Bus Garage'}
# {'k': 'operator', 'v': 'Arriva Original Sightseeing'}
# {'k': 'tfl:reg', 'v': 'WD'}
# {'k': 'type', 'v': 'bus'}
# {'changeset': '17324828', 'uid': '327499', 'timestamp': '2013-08-12T23:04:44Z', 'version': '1', 'user': 'Skyguy', 'id': '233323458'}
# {'changeset': '17324828', 'uid': '327499', 'timestamp': '2013-08-12T23:04:44Z', 'version': '1', 'user': 'Skyguy', 'id': '233323458'}
# {'ref': '922471734'}
# {'ref': '2417176116'}
# {'k': 'man_made', 'v': 'pipeline'}
# {'k': 'type', 'v': 'drain'}
# {'changeset': '17338442', 'uid': '327499', 'timestamp': '2013-08-13T23:00:25Z', 'version': '1', 'user': 'Skyguy', 'id': '233449335'}
# {'changeset': '17338442', 'uid': '327499', 'timestamp': '2013-08-13T23:00:25Z', 'version': '1', 'user': 'Skyguy', 'id': '233449335'}
# {'ref': '16365944'}
# {'ref': '2418363590'}
# {'k': 'man_made', 'v': 'pipeline'}
# {'k': 'type', 'v': 'drain'}
# {'changeset': '17338442', 'uid': '327499', 'timestamp': '2013-08-13T23:00:25Z', 'version': '1', 'user': 'Skyguy', 'id': '233449336'}
# {'changeset': '17338442', 'uid': '327499', 'timestamp': '2013-08-13T23:00:25Z', 'version': '1', 'user': 'Skyguy', 'id': '233449336'}
# {'ref': '2418363636'}
# {'ref': '2418363637'}
# {'k': 'man_made', 'v': 'pipeline'}
# {'k': 'type', 'v': 'drain'}
# {'changeset': '21129214', 'uid': '38588', 'timestamp': '2014-03-16T04:32:18Z', 'version': '3', 'user': 'mentor', 'id': '235363840'}
# {'changeset': '21129214', 'uid': '38588', 'timestamp': '2014-03-16T04:32:18Z', 'version': '3', 'user': 'mentor', 'id': '235363840'}
# {'ref': '2434311629'}
# {'ref': '2434311634'}
# {'ref': '2434311637'}
# {'ref': '2434311639'}
# {'ref': '2434311641'}
# {'ref': '2434311688'}
# {'ref': '2434311676'}
# {'ref': '2434311640'}
# {'ref': '2434311653'}
# {'ref': '2434311606'}
# {'ref': '2434311586'}
# {'ref': '2434311604'}
# {'ref': '2434311610'}
# {'ref': '2434311562'}
# {'ref': '2434311556'}
# {'ref': '2434311603'}
# {'ref': '2434311647'}
# {'ref': '2434311686'}
# {'ref': '2434311695'}
# {'ref': '2434311611'}
# {'ref': '2434311674'}
# {'ref': '2434311672'}
# {'ref': '2434311669'}
# {'ref': '2434311671'}
# {'ref': '2434311608'}
# {'ref': '2434311704'}
# {'ref': '2434311559'}
# {'ref': '2434311701'}
# {'ref': '2434311693'}
# {'ref': '2434311703'}
# {'ref': '2434311582'}
# {'ref': '2434311645'}
# {'ref': '2434311652'}
# {'ref': '2434311629'}
# {'k': 'building', 'v': 'yes'}
# {'k': 'name', 'v': "Queen Elizabeth's Foundation (Independent) Living Services"}
# {'k': 'type', 'v': 'multipolygon'}
# {'changeset': '18643724', 'uid': '352985', 'timestamp': '2013-10-31T22:29:31Z', 'version': '1', 'user': 'ecatmur', 'id': '244229657'}
# {'changeset': '18643724', 'uid': '352985', 'timestamp': '2013-10-31T22:29:31Z', 'version': '1', 'user': 'ecatmur', 'id': '244229657'}
# {'ref': '2515664758'}
# {'ref': '2515664757'}
# {'k': 'embankment', 'v': 'yes'}
# {'k': 'man_made', 'v': 'embankment'}
# {'k': 'type', 'v': 'ha-ha'}
# {'changeset': '18643724', 'uid': '352985', 'timestamp': '2013-10-31T22:29:31Z', 'version': '1', 'user': 'ecatmur', 'id': '244229660'}
# {'changeset': '18643724', 'uid': '352985', 'timestamp': '2013-10-31T22:29:31Z', 'version': '1', 'user': 'ecatmur', 'id': '244229660'}
# {'ref': '2515664759'}
# {'ref': '2515664760'}
# {'k': 'embankment', 'v': 'yes'}
# {'k': 'man_made', 'v': 'embankment'}
# {'k': 'type', 'v': 'ha-ha'}
# {'changeset': '50130367', 'uid': '24119', 'timestamp': '2017-07-08T12:02:00Z', 'version': '4', 'user': 'Mauls', 'id': '505413175'}
# {'changeset': '50130367', 'uid': '24119', 'timestamp': '2017-07-08T12:02:00Z', 'version': '4', 'user': 'Mauls', 'id': '505413175'}
# {'ref': '4616889105'}
# {'ref': '4953734916'}
# {'ref': '4953734910'}
# {'ref': '4953734836'}
# {'ref': '4953734859'}
# {'ref': '4953734861'}
# {'ref': '4953734890'}
# {'ref': '4953734891'}
# {'ref': '4953734893'}
# {'ref': '4953734902'}
# {'ref': '4953734907'}
# {'ref': '4953734911'}
# {'ref': '4953735024'}
# {'ref': '4953734825'}
# {'ref': '4953734854'}
# {'ref': '4953734855'}
# {'ref': '4953732607'}
# {'ref': '4953734879'}
# {'ref': '4953734881'}
# {'ref': '4953734892'}
# {'ref': '4953734827'}
# {'ref': '4953735025'}
# {'ref': '4953732592'}
# {'ref': '2511162663'}
# {'ref': '2511162675'}
# {'ref': '1544838691'}
# {'ref': '25658483'}
# {'ref': '1544838720'}
# {'ref': '4953542002'}
# {'ref': '1544838722'}
# {'ref': '2511162669'}
# {'ref': '2511162667'}
# {'ref': '1544838693'}
# {'ref': '2511162668'}
# {'ref': '16363272'}
# {'ref': '2511162670'}
# {'ref': '2511162674'}
# {'ref': '2511162683'}
# {'ref': '2511162684'}
# {'ref': '2511162682'}
# {'ref': '16363276'}
# {'ref': '4953536309'}
# {'ref': '4953536315'}
# {'ref': '16363277'}
# {'ref': '4953541783'}
# {'ref': '4953536310'}
# {'ref': '4953541784'}
# {'ref': '4953536306'}
# {'ref': '4953541993'}
# {'ref': '4953541952'}
# {'ref': '4953541797'}
# {'ref': '4953541970'}
# {'ref': '4953541816'}
# {'ref': '4953541950'}
# {'ref': '4953541756'}
# {'ref': '4953541956'}
# {'ref': '4953541938'}
# {'ref': '4953541953'}
# {'ref': '4953541940'}
# {'ref': '4953536305'}
# {'ref': '16363282'}
# {'ref': '4953541944'}
# {'ref': '4953735035'}
# {'ref': '4953735057'}
# {'ref': '4953734906'}
# {'ref': '4953735053'}
# {'ref': '16363287'}
# {'ref': '16363288'}
# {'ref': '16363292'}
# {'ref': '4953541759'}
# {'ref': '4953541799'}
# {'ref': '4953541778'}
# {'ref': '4616889121'}
# {'ref': '4616889120'}
# {'ref': '4616889119'}
# {'ref': '4953541793'}
# {'ref': '3517134045'}
# {'ref': '3517134046'}
# {'ref': '3517134048'}
# {'ref': '3517134049'}
# {'ref': '3517134047'}
# {'ref': '3517174661'}
# {'ref': '3517174659'}
# {'ref': '3517174660'}
# {'ref': '3517174662'}
# {'ref': '3517134044'}
# {'ref': '3517173135'}
# {'ref': '3517173134'}
# {'ref': '3517173133'}
# {'ref': '3517173130'}
# {'ref': '3517173129'}
# {'ref': '3517173127'}
# {'ref': '3517173128'}
# {'ref': '3517173126'}
# {'ref': '3517172805'}
# {'ref': '2331223653'}
# {'ref': '3517172797'}
# {'ref': '3517172796'}
# {'ref': '2331223642'}
# {'ref': '3517172795'}
# {'ref': '4616889110'}
# {'ref': '4616889109'}
# {'ref': '4616889108'}
# {'ref': '4616889107'}
# {'ref': '4616889106'}
# {'ref': '4616889105'}
# {'k': 'area', 'v': 'yes'}
# {'k': 'natural', 'v': 'beach'}
# {'k': 'source', 'v': 'OS-OpenData_StreetView'}
# {'k': 'surface', 'v': 'sand'}
# {'k': 'tidal', 'v': 'yes'}
# {'k': 'type', 'v': 'mud'}

# %% [markdown]
# #### Looking at Postcodes

# %%
#OSM_FILE = 'swlondon_sample.osm' 
OSM_FILE = 'swlondon.osm'

code_ingroup_re = re.compile(r'^[a-zA-Z]', re.IGNORECASE)


expected = []


#splits  postcode into outgroup & ingroup, adds ingroups to a 'set' of ingroups for each outgroup
#adds count to occurances of outgroup

def audit_postcode(postcode_outgroups, postcodes, code):
    # test on ';' added to deal with postcode data point containing ';' separated list
    if ';' in code:
        code = code.split(';')[0]
    code_sep = code.split()
    code_outgroup = code_sep[0]
    postcode_outgroups[code_outgroup] +=1
    if len(code_sep) == 2:
            postcodes[code_sep[0]].add(code_sep[1])
            return
    # code below purely to deal with one example found of multiple(2) postcodes separated by ;
    if len(code_sep)>2:
        print 'still have code_sep >2', code_sep
        code_1 = code.split(';')[0]
        code_sep = code_1.split()
        code_outgroup = code_sep[0]
        postcode_outgroups[code_outgroup] +=1
        postcodes[code_sep[0]].add(code_sep[1])
        code_2 = code.split(';')[1]
        code_sep = code_2.split()
        code_outgroup = code_sep[0]
        postcode_outgroups[code_outgroup] +=1
        postcodes[code_sep[0]].add(code_sep[1])
        return
        

def is_postcode(elem):
    return (elem.attrib['k'] == "addr:postcode")


# audits postcodes
# counts outgroup occurances, and builds set of ingroups for each outgroup
def audit(osmfile):
    osm_file = open(osmfile, "r")
    postcodes = defaultdict(set)
    postcode_outgroups = defaultdict(int)
    n=0
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        n+=1
        #if n>200000: break
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter('tag'):
                if is_postcode(tag):
                    audit_postcode(postcode_outgroups,postcodes, tag.attrib['v'])
    osm_file.close()
    return postcode_outgroups, postcodes



if __name__ == '__main__':

    postcode_outgroups, postcodes = audit(OSM_FILE)

    
    print len(postcode_outgroups),'postcode outgroups in data (with counts of occurance) \n'
    pprint.pprint(sorted(postcode_outgroups.items()))
    
    # to print out the full 'sets' of ingroups for each outgroup
    #pprint.pprint(sorted(postcodes.items()))
# Out:
# 86 postcode outgroups in data (with counts of occurance)
#
# [('CR4', 44),
#  ('CR5', 4),
#  ('GU21', 7),
#  ('GU22', 12),
#  ('GU23', 142),
#  ('GU4', 6),
#  ('KT1', 90),
#  ('KT10', 35),
#  ('KT11', 43),
#  ('KT12', 31),
#  ('KT13', 149),
#  ('KT14', 9),
#  ('KT15', 20),
#  ('KT16', 83),
#  ('KT17', 22),
#  ('KT18', 13),
#  ('KT19', 284),
#  ('KT2', 76),
#  ('KT20', 18),
#  ('KT21', 29),
#  ('KT22', 75),
#  ('KT23', 7),
#  ('KT24', 11),
#  ('KT3', 64),
#  ('KT4', 21),
#  ('KT5', 6),
#  ('KT6', 97),
#  ('KT7', 6),
#  ('KT8', 29),
#  ('KT9', 25),
#  ('RH1', 2),
#  ('RH2', 1),
#  ('RH4', 1),
#  ('RH5', 1),
#  ('SL3', 2),
#  ('SM1', 54),
#  ('SM2', 21),
#  ('SM3', 12),
#  ('SM4', 29),
#  ('SM5', 15),
#  ('SM6', 28),
#  ('SM7', 11),
#  ('SW10', 28),
#  ('SW11', 693),
#  ('SW12', 50),
#  ('SW13', 141),
#  ('SW14', 220),
#  ('SW15', 221),
#  ('SW17', 103),
#  ('SW18', 186),
#  ('SW19', 501),
#  ('SW1W', 19),
#  ('SW1X', 2),
#  ('SW20', 805),
#  ('SW3', 167),
#  ('SW4', 12),
#  ('SW5', 73),
#  ('SW6', 158),
#  ('SW7', 25),
#  ('SW8', 16),
#  ('TW1', 186),
#  ('TW10', 467),
#  ('TW11', 77),
#  ('TW12', 137),
#  ('TW13', 13),
#  ('TW14', 37),
#  ('TW15', 20),
#  ('TW16', 11),
#  ('TW17', 8),
#  ('TW18', 26),
#  ('TW19', 9),
#  ('TW2', 153),
#  ('TW20', 10),
#  ('TW3', 8),
#  ('TW4', 5),
#  ('TW5', 14),
#  ('TW6', 14),
#  ('TW7', 28),
#  ('TW8', 46),
#  ('TW9', 299),
#  ('UB3', 2),
#  ('UB7', 6),
#  ('W14', 11),
#  ('W4', 33),
#  ('W5', 1),
#  ('W6', 29)]

# %%
# to print out the full 'sets' of ingroups for each outgroup
pprint.pprint(sorted(postcodes.items()))
# Out:
# [('CR4',
#   set(['1SD',
#        '1SF',
#        '1YG',
#        '2AJ',
#        '2DJ',
#        '2DZ',
#        '2HZ',
#        '2JA',
#        '2JD',
#        '2JS',
#        '2LF',
#        '2NT',
#        '2PF',
#        '3AA',
#        '3AF',
#        '3BE',
#        '3EB',
#        '3ED',
#        '3FH',
#        '3GD',
#        '3HD',
#        '3HG',
#        '3HS',
#        '3LA',
#        '3LD',
#        '3ND',
#        '3NH',
#        '3NN',
#        '3PQ',
#        '4BG',
#        '4BJ',
#        '4HB',
#        '4HR',
#        '4LA',
#        '4XU'])),
#  ('CR5', set(['3AL', '3LN', '3NP', '3QW'])),
#  ('GU21', set(['4YH', '5NL', '5QE', '5RF', '5SH', '5UB'])),
#  ('GU22', set(['8AR', '8AX', '8HA', '8SP', '9AL', '9DL', '9JX'])),
#  ('GU23',
#   set(['6AA',
#        '6AL',
#        '6BN',
#        '6EZ',
#        '6JQ',
#        '6JS',
#        '6JX',
#        '6JY',
#        '6JZ',
#        '6LE',
#        '6LJ',
#        '6LP',
#        '6LS',
#        '6NE',
#        '6QB',
#        '6QS',
#        '7BP',
#        '7BS',
#        '7EN',
#        '7ER',
#        '7ET',
#        '7EZ',
#        '7HP',
#        '7JL'])),
#  ('GU4', set(['7JU', '7LE', '7TE'])),
#  ('KT1',
#   set(['1BQ',
#        '1BU',
#        '1DJ',
#        '1EE',
#        '1EY',
#        '1HL',
#        '1HN',
#        '1HT',
#        '1JS',
#        '1JT',
#        '1LQ',
#        '1NP',
#        '1NR',
#        '1NU',
#        '1PE',
#        '1PY',
#        '1QN',
#        '1QP',
#        '1QT',
#        '1QY',
#        '1RB',
#        '1RP',
#        '1RW',
#        '1SF',
#        '1TG',
#        '1TP',
#        '1TR',
#        '1UJ',
#        '2EE',
#        '2HG',
#        '2HS',
#        '2HW',
#        '2JT',
#        '2PD',
#        '2PY',
#        '2QZ',
#        '2RF',
#        '2UL',
#        '3AR',
#        '3AY',
#        '3BB',
#        '3DY',
#        '3EG',
#        '3EQ',
#        '3EZ',
#        '3HE',
#        '3JB',
#        '3NG',
#        '3NQ',
#        '3PB',
#        '3RT',
#        '4AD',
#        '4AE',
#        '4AN',
#        '4AS',
#        '4AZ',
#        '4BA',
#        '4DA',
#        '4DB',
#        '4DG',
#        '4HQ'])),
#  ('KT10',
#   set(['0AQ',
#        '0BF',
#        '0LX',
#        '0LZ',
#        '0NB',
#        '0NG',
#        '0RQ',
#        '0SP',
#        '0SR',
#        '8LS',
#        '9AL',
#        '9DU',
#        '9EA',
#        '9EG',
#        '9LN',
#        '9QD',
#        '9QE',
#        '9RQ',
#        '9RT',
#        '9TL'])),
#  ('KT11',
#   set(['1AA',
#        '1AF',
#        '1AL',
#        '1DR',
#        '1EU',
#        '1EW',
#        '1HT',
#        '1HW',
#        '1NA',
#        '1NG',
#        '2AX',
#        '2ES',
#        '2LG',
#        '2LU',
#        '2QL',
#        '2SL',
#        '2SX',
#        '3AL',
#        '3AS',
#        '3BN',
#        '3DB',
#        '3DG',
#        '3DH',
#        '3DZ',
#        '3EG',
#        '3EZ',
#        '3LT',
#        '3LU',
#        '3NA',
#        '3PX'])),
#  ('KT12',
#   set(['1AD',
#        '1AF',
#        '1DA',
#        '1NU',
#        '1RR',
#        '1RZ',
#        '2EB',
#        '2ER',
#        '2JB',
#        '2JD',
#        '2JR',
#        '2PF',
#        '3JB',
#        '3LN',
#        '3LY',
#        '3PF',
#        '3PU',
#        '3QZ',
#        '4HL',
#        '4PQ',
#        '4RA',
#        '4SG',
#        '5AB',
#        '5HP'])),
#  ('KT13',
#   set(['0SL',
#        '0TS',
#        '0XF',
#        '0XP',
#        '8AA',
#        '8AB',
#        '8AE',
#        '8AH',
#        '8AX',
#        '8BB',
#        '8BL',
#        '8BS',
#        '8BY',
#        '8DA',
#        '8DD',
#        '8DE',
#        '8DG',
#        '8DH',
#        '8DJ',
#        '8DL',
#        '8DP',
#        '8DS',
#        '8DU',
#        '8DX',
#        '8ED',
#        '8HD',
#        '8LU',
#        '8NA',
#        '8NL',
#        '8RT',
#        '8RX',
#        '8TA',
#        '8TB',
#        '8TN',
#        '8TX',
#        '8UD',
#        '8UE',
#        '8XY',
#        '9DA',
#        '9DJ',
#        '9DL',
#        '9DT',
#        '9EA',
#        '9ET',
#        '9RU',
#        '9UE',
#        '9UG',
#        '9UJ',
#        '9UQ',
#        '9UT',
#        '9UW',
#        '9UX',
#        '9XF',
#        '9YA'])),
#  ('KT14', set(['6HS', '6LF', '7DU', '7EN', '7QH', '7QX', '7RA'])),
#  ('KT15',
#   set(['1EY',
#        '1JH',
#        '1RT',
#        '1SG',
#        '2AE',
#        '2AH',
#        '2BN',
#        '2BU',
#        '2DS',
#        '2DW',
#        '2EP',
#        '2QS',
#        '2SN'])),
#  ('KT16',
#   set(['0AJ',
#        '0AN',
#        '0HG',
#        '0LW',
#        '8AP',
#        '8AT',
#        '8BY',
#        '8HZ',
#        '8JZ',
#        '9AG',
#        '9AH',
#        '9AL',
#        '9AS',
#        '9BH',
#        '9BJ',
#        '9BL',
#        '9DG',
#        '9EN',
#        '9HR',
#        '9LN',
#        '9LP',
#        '9LT',
#        '9LY',
#        '9NN',
#        '9PA'])),
#  ('KT17',
#   set(['1AH',
#        '1BB',
#        '1DH',
#        '1EQ',
#        '1EY',
#        '1NL',
#        '1PE',
#        '1PG',
#        '1RE',
#        '1SN',
#        '1TF',
#        '1TS',
#        '2AY',
#        '4JJ',
#        '4JR',
#        '4NY',
#        '4QY',
#        '4RA'])),
#  ('KT18',
#   set(['5AG', '5BY', '5DB', '5HE', '5LJ', '5LQ', '7BB', '7PF', '7PJ', '7RG'])),
#  ('KT19',
#   set(['0DT',
#        '0DX',
#        '8AG',
#        '8BA',
#        '8BJ',
#        '8BT',
#        '8DA',
#        '8EF',
#        '8EH',
#        '8FA',
#        '8FF',
#        '8FJ',
#        '8FL',
#        '8FN',
#        '8FP',
#        '8FQ',
#        '8FR',
#        '8FS',
#        '8FT',
#        '8FW',
#        '8FX',
#        '8FY',
#        '8FZ',
#        '8GJ',
#        '8GL',
#        '8GN',
#        '8GP',
#        '8JY',
#        '8LX',
#        '8QB',
#        '8QG',
#        '8QJ',
#        '8RY',
#        '8SF',
#        '9AF',
#        '9BE',
#        '9TN'])),
#  ('KT2',
#   set(['5AU',
#        '5EB',
#        '5EE',
#        '5EN',
#        '5FJ',
#        '5JF',
#        '5JR',
#        '5NZ',
#        '5PE',
#        '5PL',
#        '5PU',
#        '5QG',
#        '5QU',
#        '5QX',
#        '5TT',
#        '5UL',
#        '6AP',
#        '6EN',
#        '6HG',
#        '6HT',
#        '6LN',
#        '6LQ',
#        '6PW',
#        '6QA',
#        '6QF',
#        '6QJ',
#        '6QL',
#        '6QS',
#        '6SE',
#        '7AU',
#        '7AZ',
#        '7NH',
#        '7NS',
#        '7NU',
#        '7PE',
#        '7PW',
#        '7PX',
#        '7QB',
#        '7RE'])),
#  ('KT20',
#   set(['5JG',
#        '5NZ',
#        '5QY',
#        '5QZ',
#        '6AH',
#        '6AJ',
#        '6DD',
#        '6DG',
#        '6DW',
#        '6HD',
#        '6RP',
#        '6UU',
#        '7EA',
#        '7ES',
#        '7RR',
#        '7RW',
#        '7TA'])),
#  ('KT21',
#   set(['1AA',
#        '1AL',
#        '1AW',
#        '1EA',
#        '1JG',
#        '1JX',
#        '1LD',
#        '2BA',
#        '2BE',
#        '2BQ',
#        '2DA',
#        '2RE'])),
#  ('KT22',
#   set(['0DP',
#        '0ET',
#        '0JE',
#        '0JN',
#        '0JP',
#        '0JR',
#        '0LB',
#        '0LE',
#        '0QJ',
#        '7BA',
#        '7BP',
#        '7PS',
#        '7RD',
#        '7SW',
#        '7TA',
#        '8',
#        '8AH',
#        '8AN',
#        '8AY',
#        '8BL',
#        '8BZ',
#        '8DP',
#        '8DW',
#        '8RY',
#        '9AA',
#        '9AL',
#        '9BL',
#        '9GZ',
#        '9HA',
#        '9HX',
#        '9JF',
#        '9JQ',
#        '9JX',
#        '9QJ',
#        '9QR',
#        '9RD'])),
#  ('KT23', set(['3ND', '3PP', '4AA', '4EN', '4JJ', '4LP', '4PT'])),
#  ('KT24', set(['5JP', '6JH', '6NS', '6QN', '6QP', '6QT', '6QX', '6RT'])),
#  ('KT3',
#   set(['3DN',
#        '3JU',
#        '3NW',
#        '3PU',
#        '3QY',
#        '3RN',
#        '3RZ',
#        '3TU',
#        '3TW',
#        '4BH',
#        '4BP',
#        '4BY',
#        '4DQ',
#        '4ES',
#        '4ET',
#        '4HE',
#        '4LT',
#        '4NA',
#        '4NL',
#        '4NY',
#        '4PA',
#        '4PH',
#        '4PJ',
#        '4PX',
#        '4QE',
#        '4RD',
#        '4TA',
#        '5DX',
#        '5PD',
#        '5PF',
#        '6JF',
#        '6JP',
#        '6NB',
#        '6NE',
#        '6NU'])),
#  ('KT4',
#   set(['7NB',
#        '7NL',
#        '7NR',
#        '7NT',
#        '7NW',
#        '7PX',
#        '7QB',
#        '7RA',
#        '8DR',
#        '8DS',
#        '8DY',
#        '8EB',
#        '8EG',
#        '8ES',
#        '8HL',
#        '8HT',
#        '8HX'])),
#  ('KT5', set(['8LS', '8QJ', '8QX', '8RA', '9AG'])),
#  ('KT6',
#   set(['4AG',
#        '4AW',
#        '4BN',
#        '4BX',
#        '4BY',
#        '4DJ',
#        '4DP',
#        '4EB',
#        '4ED',
#        '4EE',
#        '4HS',
#        '4JL',
#        '4JT',
#        '4JU',
#        '4JZ',
#        '4LQ',
#        '4NG',
#        '4NQ',
#        '4NR',
#        '4NS',
#        '4PE',
#        '4PJ',
#        '4QR',
#        '4RH',
#        '4RP',
#        '4RW',
#        '4SP',
#        '4TP',
#        '4TU',
#        '5AS',
#        '5AT',
#        '5BH',
#        '5DB',
#        '5DE',
#        '5ED',
#        '5EY',
#        '5LR',
#        '5LX',
#        '5NF',
#        '5NW',
#        '5PL',
#        '5PP',
#        '5PQ',
#        '5PR',
#        '5PT',
#        '6AW',
#        '6BZ',
#        '6EZ',
#        '6HA',
#        '6HL',
#        '6JX',
#        '6RJ',
#        '7AA',
#        '7DQ',
#        '7EL',
#        '7HL',
#        '7HR',
#        '7JB',
#        '7LQ'])),
#  ('KT7', set(['0AB', '0JA', '0LE', '0RY', '0SR'])),
#  ('KT8',
#   set(['0BE',
#        '0DL',
#        '0DP',
#        '0HP',
#        '0PF',
#        '0ST',
#        '1SE',
#        '2NA',
#        '2QF',
#        '2QG',
#        '2RG',
#        '9AU',
#        '9BN',
#        '9BP',
#        '9BS',
#        '9BY',
#        '9DD',
#        '9EU',
#        '9HA',
#        '9HT',
#        '9LE',
#        '9LF'])),
#  ('KT9',
#   set(['1AJ',
#        '1BD',
#        '1EL',
#        '1JE',
#        '1NU',
#        '1NY',
#        '1QL',
#        '1UF',
#        '1UG',
#        '2AJ',
#        '2AR',
#        '2BQ',
#        '2DH',
#        '2GY',
#        '2GZ',
#        '2JR',
#        '2JT',
#        '2LW',
#        '2NE',
#        '2NF',
#        '2NQ',
#        '2QL',
#        '2RN'])),
#  ('RH1', set(['3AZ', '3EA'])),
#  ('RH2', set(['0TD'])),
#  ('RH5', set(['6EW'])),
#  ('SL3', set(['0FF', '9PN'])),
#  ('SM1',
#   set(['1BB',
#        '1DD',
#        '1DE',
#        '1DF',
#        '1DJ',
#        '1DT',
#        '1DX',
#        '1DZ',
#        '1EZ',
#        '1HF',
#        '1HY',
#        '1JA',
#        '1JF',
#        '1LB',
#        '1LD',
#        '1LU',
#        '1PR',
#        '1QJ',
#        '1SH',
#        '1SN',
#        '2AX',
#        '2NA',
#        '4AS',
#        '4AW',
#        '4BX',
#        '4BY',
#        '4DA',
#        '4FF',
#        '4LG',
#        '4PJ',
#        '4PP',
#        '4QJ',
#        '4QL',
#        '4QP',
#        '4QW',
#        '4RQ'])),
#  ('SM2',
#   set(['5AD', '5BQ', '5DU', '5HD', '5TA', '6BS', '6LE', '7AJ', '7AT', '7DD'])),
#  ('SM3', set(['8AY', '8BH', '8BU', '8LN', '8QH', '8RW', '8SD', '9HE', '9PW'])),
#  ('SM4',
#   set(['4AW',
#        '4EE',
#        '4NY',
#        '4QU',
#        '4SJ',
#        '4SP',
#        '4SS',
#        '5AZ',
#        '5BE',
#        '5BL',
#        '5BN',
#        '5DX',
#        '5HT',
#        '5JD',
#        '5LN',
#        '5LT',
#        '5PH',
#        '5PJ',
#        '5PX',
#        '5QT',
#        '6BB',
#        '6BG',
#        '6BH',
#        '6HG'])),
#  ('SM5',
#   set(['1AA',
#        '1JJ',
#        '2HU',
#        '2NR',
#        '2TG',
#        '3BN',
#        '3JG',
#        '3LW',
#        '3NX',
#        '3PT',
#        '3RG',
#        '4BF',
#        '4DT',
#        '4HS'])),
#  ('SM6',
#   set(['0DD',
#        '0DW',
#        '0DZ',
#        '0EF',
#        '0EL',
#        '0EN',
#        '0EP',
#        '0HU',
#        '0HY',
#        '0JF',
#        '0NN'])),
#  ('SM7', set(['1RD', '2AJ', '2BQ', '2BW', '2NG', '2NZ', '2PH', '3DS', '3RA'])),
#  ('SW10',
#   set(['0AB',
#        '0AY',
#        '0EQ',
#        '0LR',
#        '0LU',
#        '0QB',
#        '0QH',
#        '0QS',
#        '0RS',
#        '0SZ',
#        '0XF',
#        '0XG',
#        '9HX',
#        '9JH',
#        '9NB',
#        '9NH',
#        '9PN',
#        '9PY',
#        '9PZ',
#        '9RY',
#        '9TW',
#        '9UJ',
#        '9UU',
#        '9UZ'])),
#  ('SW11',
#   set(['1BW',
#        '1DH',
#        '1DJ',
#        '1DY',
#        '1ED',
#        '1EE',
#        '1EG',
#        '1EH',
#        '1EJ',
#        '1EQ',
#        '1ER',
#        '1HG',
#        '1HH',
#        '1HN',
#        '1HS',
#        '1HT',
#        '1HW',
#        '1JA',
#        '1JB',
#        '1JG',
#        '1JJ',
#        '1JQ',
#        '1JW',
#        '1JX',
#        '1LE',
#        '1LJ',
#        '1LN',
#        '1LP',
#        '1LS',
#        '1LW',
#        '1LX',
#        '1NG',
#        '1NJ',
#        '1NP',
#        '1NT',
#        '1NX',
#        '1NZ',
#        '1PA',
#        '1PW',
#        '1PX',
#        '1RU',
#        '1SA',
#        '1SF',
#        '1SJ',
#        '1SL',
#        '1SW',
#        '1SY',
#        '1SZ',
#        '1TD',
#        '1TH',
#        '1TN',
#        '1TQ',
#        '1TT',
#        '2',
#        '2AA',
#        '2AL',
#        '2AS',
#        '2BU',
#        '2BW',
#        '2DB',
#        '2HB',
#        '2JE',
#        '2JU',
#        '2JZ',
#        '2LH',
#        '2LJ',
#        '2LW',
#        '2LX',
#        '2NL',
#        '2NP',
#        '2NU',
#        '2NY',
#        '2PD',
#        '2PE',
#        '2PF',
#        '2PG',
#        '2PH',
#        '2PL',
#        '2QP',
#        '2TD',
#        '2TH',
#        '3',
#        '3AA',
#        '3AG',
#        '3AT',
#        '3AU',
#        '3AW',
#        '3BA',
#        '3BE',
#        '3BH',
#        '3BJ',
#        '3BL',
#        '3BN',
#        '3BP',
#        '3BS',
#        '3BT',
#        '3BU',
#        '3BW',
#        '3BX',
#        '3BY',
#        '3DQ',
#        '3HD',
#        '3HE',
#        '3HX',
#        '3JR',
#        '3JS',
#        '3NA',
#        '3NE',
#        '3PF',
#        '3PH',
#        '3QA',
#        '3QU',
#        '3RA',
#        '3RR',
#        '3SJ',
#        '3SU',
#        '3TS',
#        '3UW',
#        '3YW',
#        '4AY',
#        '4DX',
#        '4JE',
#        '4JP',
#        '4LG',
#        '4LR',
#        '4LS',
#        '4LU',
#        '4LW',
#        '4LX',
#        '4LY',
#        '4NA',
#        '4ND',
#        '4NE',
#        '4NF',
#        '4NJ',
#        '4NP',
#        '5AP',
#        '5AU',
#        '5DT',
#        '5EG',
#        '5EN',
#        '5EQ',
#        '5HD',
#        '5NN',
#        '5PN',
#        '5QH',
#        '5QJ',
#        '5QL',
#        '5QN',
#        '5QR',
#        '5QW',
#        '5RD',
#        '5RH',
#        '5RL',
#        '5RN',
#        '5RQ',
#        '5RW',
#        '5SL',
#        '5SQ',
#        '5TQ',
#        '5UW',
#        '6AG',
#        '6AQ',
#        '6BF',
#        '6EL',
#        '6HG',
#        '6JX',
#        '6LR',
#        '6LW',
#        '6NP',
#        '6PJ',
#        '6PL',
#        '6PR',
#        '6PS',
#        '6PX',
#        '6QB',
#        '6QE',
#        '6QF',
#        '6QL',
#        '6QN',
#        '6QP',
#        '6QU',
#        '6QW',
#        '6QY',
#        '6QZ',
#        '6RD',
#        '6RE',
#        '6RW',
#        '6RX',
#        '6RY',
#        '6SA',
#        '6SD',
#        '6SE',
#        '6SF'])),
#  ('SW12',
#   set(['8EN',
#        '8JA',
#        '8JE',
#        '8JL',
#        '8NA',
#        '8NR',
#        '8NX',
#        '8PN',
#        '8PP',
#        '8QJ',
#        '8QX',
#        '8RQ',
#        '8RS',
#        '8SY',
#        '8TE',
#        '9AA',
#        '9AG',
#        '9AU',
#        '9AZ',
#        '9BE',
#        '9BN',
#        '9BP',
#        '9BS',
#        '9BW',
#        '9ET',
#        '9EY',
#        '9EZ',
#        '9RG',
#        '9SG',
#        '9SS',
#        '9SY'])),
#  ('SW13',
#   set(['0AP',
#        '0BE',
#        '0DB',
#        '0DG',
#        '0JP',
#        '0NE',
#        '0NR',
#        '0NY',
#        '0PQ',
#        '0PW',
#        '0PY',
#        '0PZ',
#        '8EL',
#        '9AE',
#        '9DH',
#        '9DW',
#        '9ED',
#        '9ER',
#        '9ET',
#        '9EW',
#        '9HE',
#        '9HJ',
#        '9HQ',
#        '9HR',
#        '9JS',
#        '9JT',
#        '9LB',
#        '9LD',
#        '9LW',
#        '9NR',
#        '9PY',
#        '9QE',
#        '9QF',
#        '9QG',
#        '9QL',
#        '9QN',
#        '9RU'])),
#  ('SW14',
#   set(['7AF',
#        '7DE',
#        '7ED',
#        '7EH',
#        '7ET',
#        '7EW',
#        '7EX',
#        '7EZ',
#        '7HJ',
#        '7JE',
#        '7JG',
#        '7JN',
#        '7JR',
#        '7JT',
#        '7JU',
#        '7NQ',
#        '7NX',
#        '7PJ',
#        '7PR',
#        '7PS',
#        '7PU',
#        '7QR',
#        '7RT',
#        '8AB',
#        '8AD',
#        '8AE',
#        '8AG',
#        '8AH',
#        '8AN',
#        '8AR',
#        '8AW',
#        '8DS',
#        '8ED',
#        '8ER',
#        '8HE',
#        '8HY',
#        '8JN',
#        '8LF',
#        '8LP',
#        '8LR',
#        '8LW',
#        '8NH',
#        '8PR',
#        '8QN',
#        '8QR',
#        '8QS',
#        '8QT',
#        '8RG',
#        '8TA'])),
#  ('SW15',
#   set(['1AW',
#        '1BA',
#        '1BW',
#        '1DD',
#        '1EJ',
#        '1ET',
#        '1EU',
#        '1HJ',
#        '1HL',
#        '1JN',
#        '1JT',
#        '1LB',
#        '1NL',
#        '1NT',
#        '1PN',
#        '1RB',
#        '1RG',
#        '1RR',
#        '1RS',
#        '1RT',
#        '1SL',
#        '1SP',
#        '1SQ',
#        '1SS',
#        '1SU',
#        '1TW',
#        '2AY',
#        '2BD',
#        '2BZ',
#        '2DA',
#        '2DE',
#        '2DJ',
#        '2DN',
#        '2DP',
#        '2DR',
#        '2DS',
#        '2ED',
#        '2HD',
#        '2JX',
#        '2LQ',
#        '2LW',
#        '2NA',
#        '2NE',
#        '2NQ',
#        '2PA',
#        '2PG',
#        '2PT',
#        '2PU',
#        '2QD',
#        '2QS',
#        '2RA',
#        '2RB',
#        '2RD',
#        '2RN',
#        '2RX',
#        '2SD',
#        '2SH',
#        '2SP',
#        '2SR',
#        '2SU',
#        '2SW',
#        '2TD',
#        '2TX',
#        '2UE',
#        '2UQ',
#        '2UT',
#        '2YB',
#        '3BB',
#        '3BD',
#        '3DG',
#        '3DT',
#        '3DX',
#        '3EQ',
#        '3HA',
#        '3JN',
#        '3JW',
#        '3LD',
#        '3NG',
#        '3NT',
#        '3PS',
#        '3PW',
#        '3QL',
#        '3SA',
#        '3SW',
#        '3SX',
#        '3TU',
#        '4EU',
#        '4HL',
#        '4JZ',
#        '4LB',
#        '4LD',
#        '4LJ',
#        '4PD',
#        '5DH',
#        '5FH',
#        '5JJ',
#        '5LE',
#        '5LG',
#        '5LL',
#        '5LQ',
#        '5NX',
#        '5PN',
#        '5PY',
#        '5QJ',
#        '5RL',
#        '5RS',
#        '5RT',
#        '6BA',
#        '6BH',
#        '6BW',
#        '6EH',
#        '6JP',
#        '6PY',
#        '6SE',
#        '6SG',
#        '6SJ',
#        '6SP',
#        '6TD',
#        '6TL',
#        '6XA'])),
#  ('SW17',
#   set(['0AQ',
#        '0AY',
#        '0BW',
#        '0DN',
#        '0DS',
#        '0DZ',
#        '0ES',
#        '0HB',
#        '0LW',
#        '0NP',
#        '0NY',
#        '0PB',
#        '0PD',
#        '0PF',
#        '0PG',
#        '0QT',
#        '0RE',
#        '0RG',
#        '0SF',
#        '0SN',
#        '0SP',
#        '0SY',
#        '0TQ',
#        '6AT',
#        '6AW',
#        '7AA',
#        '7AW',
#        '7BA',
#        '7BD',
#        '7BQ',
#        '7BW',
#        '7DF',
#        '7DJ',
#        '7EB',
#        '7EF',
#        '7EG',
#        '7HL',
#        '7HR',
#        '7HT',
#        '7PG',
#        '7PP',
#        '7RE',
#        '7SD',
#        '7TJ',
#        '7TS',
#        '8AN',
#        '8BH',
#        '8BS',
#        '8DS',
#        '8HE',
#        '8HQ',
#        '8PP',
#        '8QD',
#        '8SG',
#        '9EH',
#        '9HW',
#        '9JR',
#        '9NA',
#        '9ND',
#        '9NG',
#        '9NH',
#        '9NT',
#        '9PA',
#        '9PE',
#        '9PF',
#        '9PP',
#        '9SA',
#        '9TJ'])),
#  ('SW18',
#   set(['1AA',
#        '1AE',
#        '1AL',
#        '1DE',
#        '1DX',
#        '1DY',
#        '1DZ',
#        '1EG',
#        '1EZ',
#        '1FQ',
#        '1GL',
#        '1GN',
#        '1HR',
#        '1HW',
#        '1HX',
#        '1HY',
#        '1LP',
#        '1NN',
#        '1NP',
#        '1PZ',
#        '1QG',
#        '1RB',
#        '1RE',
#        '1RU',
#        '1RX',
#        '1SP',
#        '1SS',
#        '1TA',
#        '1TB',
#        '1TF',
#        '1TG',
#        '1TH',
#        '1TN',
#        '1TP',
#        '1TQ',
#        '1TS',
#        '1TX',
#        '2DN',
#        '2EN',
#        '2HF',
#        '2HT',
#        '2HZ',
#        '2LP',
#        '2LR',
#        '2PP',
#        '2PQ',
#        '2PT',
#        '2QB',
#        '2QE',
#        '2RT',
#        '2SA',
#        '2SL',
#        '2SS',
#        '3AF',
#        '3NB',
#        '3NY',
#        '3QG',
#        '3QQ',
#        '3RG',
#        '3RT',
#        '3SX',
#        '3TB',
#        '4AD',
#        '4AW',
#        '4BE',
#        '4BX',
#        '4DA',
#        '4DD',
#        '4DJ',
#        '4DS',
#        '4DW',
#        '4DY',
#        '4EA',
#        '4ED',
#        '4EQ',
#        '4ES',
#        '4GA',
#        '4GP',
#        '4HJ',
#        '4HL',
#        '4HN',
#        '4HP',
#        '4HY',
#        '4JB',
#        '4JE',
#        '4JJ',
#        '4JP',
#        '4JS',
#        '4LB',
#        '4LD',
#        '4QA',
#        '4QB',
#        '4SL',
#        '4SR',
#        '4ST',
#        '4SU',
#        '4SW',
#        '4TF',
#        '4TG',
#        '4TQ',
#        '4UR',
#        '5EF',
#        '5JL',
#        '5JP',
#        '5JR',
#        '5JS',
#        '5JU',
#        '5LD',
#        '5LN',
#        '5LS',
#        '5LT',
#        '5NW',
#        '5QL',
#        '5RE',
#        '5RJ',
#        '5RL',
#        '5SQ',
#        '5ST',
#        '5SW',
#        '5TR',
#        '5TU'])),
#  ('SW19',
#   set(['1AR',
#        '1AU',
#        '1AW',
#        '1BN',
#        '1BU',
#        '1DD',
#        '1DE',
#        '1DF',
#        '1EJ',
#        '1EP',
#        '1EQ',
#        '1EW',
#        '1HH',
#        '1HL',
#        '1JN',
#        '1JQ',
#        '1JX',
#        '1JZ',
#        '1LY',
#        '1NE',
#        '1NL',
#        '1NU',
#        '1PP',
#        '1PR',
#        '1PS',
#        '1QB',
#        '1QD',
#        '1QE',
#        '1QG',
#        '1QJ',
#        '1QL',
#        '1QN',
#        '1QT',
#        '1QU',
#        '1RE',
#        '1RF',
#        '1RH',
#        '1RQ',
#        '1RX',
#        '1RY',
#        '1SB',
#        '1SD',
#        '1YG',
#        '2BH',
#        '2BJ',
#        '2BN',
#        '2DX',
#        '2DY',
#        '2EA',
#        '2EN',
#        '2HJ',
#        '2HR',
#        '2JE',
#        '2JF',
#        '2JL',
#        '2JY',
#        '2NT',
#        '2NX',
#        '2NY',
#        '2PP',
#        '2RD',
#        '2RE',
#        '2RF',
#        '2TY',
#        '3BH',
#        '3BJ',
#        '3BL',
#        '3BP',
#        '3EF',
#        '3HJ',
#        '3JZ',
#        '3NW',
#        '3QA',
#        '3RU',
#        '3SG',
#        '3SH',
#        '3TA',
#        '3XD',
#        '4AB',
#        '4BB',
#        '4BH',
#        '4BL',
#        '4BP',
#        '4DA',
#        '4DD',
#        '4DH',
#        '4DL',
#        '4DP',
#        '4DR',
#        '4EE',
#        '4EF',
#        '4EZ',
#        '4HB',
#        '4HD',
#        '4HW',
#        '4HX',
#        '4HY',
#        '4HZ',
#        '4JS',
#        '4JZ',
#        '4LB',
#        '4LD',
#        '4LE',
#        '4LF',
#        '4LH',
#        '4LJ',
#        '4LL',
#        '4LP',
#        '4LQ',
#        '4LR',
#        '4LS',
#        '4LT',
#        '4LU',
#        '4LW',
#        '4NP',
#        '4NS',
#        '4NZ',
#        '4QN',
#        '4QT',
#        '4QW',
#        '4RJ',
#        '4RQ',
#        '4SS',
#        '4ST',
#        '4SU',
#        '4TG',
#        '4TT',
#        '4UE',
#        '4UN',
#        '4UW',
#        '5AU',
#        '5AX',
#        '5BA',
#        '5BY',
#        '5DL',
#        '5DQ',
#        '5DW',
#        '5DX',
#        '5EA',
#        '5EE',
#        '5EG',
#        '5JP',
#        '5LJ',
#        '5LN',
#        '5LW',
#        '5NQ',
#        '5NX',
#        '5UA',
#        '6AD',
#        '6DA',
#        '6HR',
#        '6JB',
#        '6JP',
#        '6LN',
#        '6LP',
#        '6LR',
#        '6NL',
#        '6NW',
#        '6QT',
#        '6RW',
#        '7AF',
#        '7BA',
#        '7BB',
#        '7BD',
#        '7BP',
#        '7EP',
#        '7HB',
#        '7HR',
#        '7JD',
#        '7JP',
#        '7JY',
#        '7JZ',
#        '7NA',
#        '7NB',
#        '7ND',
#        '7NE',
#        '7NF',
#        '7NH',
#        '7NL',
#        '7NN',
#        '7NS',
#        '7NU',
#        '7NW',
#        '7PA',
#        '7QU',
#        '7QW',
#        '8AA',
#        '8AB',
#        '8AD',
#        '8AE',
#        '8AQ',
#        '8AR',
#        '8BZ',
#        '8DR',
#        '8DS',
#        '8EF',
#        '8EJ',
#        '8HQ',
#        '8JH',
#        '8LA',
#        '8LD',
#        '8LR',
#        '8LX',
#        '8ND',
#        '8NG',
#        '8PF',
#        '8PU',
#        '8QN',
#        '8RA',
#        '8SB',
#        '8YA',
#        '8YB',
#        '8YE'])),
#  ('SW1W',
#   set(['8AH',
#        '8AQ',
#        '8BP',
#        '8DA',
#        '8JF',
#        '8LP',
#        '8NA',
#        '8PH',
#        '8SH',
#        '8UN',
#        '9BA',
#        '9PA',
#        '9QD',
#        '9QJ',
#        '9TP'])),
#  ('SW1X', set(['9DE', '9DQ'])),
#  ('SW20',
#   set(['0AA',
#        '0BP',
#        '0BU',
#        '0BW',
#        '0BZ',
#        '0DE',
#        '0EG',
#        '0ET',
#        '0JB',
#        '0JL',
#        '0JT',
#        '0JY',
#        '0LA',
#        '0LL',
#        '0LR',
#        '0LW',
#        '0NA',
#        '0SQ',
#        '0SX',
#        '0TL',
#        '8AH',
#        '8BA',
#        '8BB',
#        '8BD',
#        '8BE',
#        '8BF',
#        '8BG',
#        '8BH',
#        '8BJ',
#        '8BL',
#        '8BN',
#        '8BP',
#        '8BQ',
#        '8BS',
#        '8BT',
#        '8BW',
#        '8DA',
#        '8DN',
#        '8DR',
#        '8EL',
#        '8HF',
#        '8HR',
#        '8JL',
#        '8JN',
#        '8JX',
#        '8LD',
#        '8LR',
#        '8ND',
#        '8QY',
#        '8RE',
#        '8SA',
#        '8TE',
#        '9AN',
#        '9DB',
#        '9DL',
#        '9JZ',
#        '9NS'])),
#  ('SW3',
#   set(['2LS',
#        '2PP',
#        '2PR',
#        '2PU',
#        '2RZ',
#        '2SR',
#        '2TJ',
#        '3AP',
#        '3DH',
#        '3PB',
#        '3RA',
#        '3TW',
#        '4',
#        '4AJ',
#        '4HN',
#        '4LY',
#        '4NJ',
#        '4NT',
#        '4NX',
#        '4PL',
#        '4RY',
#        '4TW',
#        '4UD',
#        '4UT',
#        '4XB',
#        '5BS',
#        '5BY',
#        '5DE',
#        '5EP',
#        '5HL',
#        '5LS',
#        '5PL',
#        '5UH',
#        '5UR',
#        '5XP',
#        '6AH',
#        '6HR',
#        '6HS',
#        '6HU',
#        '6NB',
#        '6NJ',
#        '6NR',
#        '6PP',
#        '6PU',
#        '6PY'])),
#  ('SW4', set(['0AJ', '9AH', '9AN', '9RU', '9SA', '9SD', '9SP'])),
#  ('SW5',
#   set(['0AQ',
#        '0BE',
#        '0DJ',
#        '0EW',
#        '0PT',
#        '0PU',
#        '0QJ',
#        '0QT',
#        '0TH',
#        '9AD',
#        '9AH',
#        '9AN',
#        '9AS',
#        '9BA',
#        '9BQ',
#        '9DJ',
#        '9EB',
#        '9HB',
#        '9HR',
#        '9JA',
#        '9JF',
#        '9JT',
#        '9LS',
#        '9NB',
#        '9QJ',
#        '9QQ',
#        '9RL',
#        '9RQ',
#        '9UB',
#        '9UE'])),
#  ('SW6',
#   set(['1AA',
#        '1AX',
#        '1AZ',
#        '1BE',
#        '1BW',
#        '1BY',
#        '1EJ',
#        '1EP',
#        '1ES',
#        '1HD',
#        '1LX',
#        '1QP',
#        '1RX',
#        '1TB',
#        '1TL',
#        '1UD',
#        '1UE',
#        '2DU',
#        '2DZ',
#        '2EB',
#        '2ES',
#        '2GA',
#        '2GD',
#        '2HA',
#        '2NB',
#        '2PY',
#        '2TW',
#        '2UB',
#        '3AA',
#        '3BN',
#        '3DP',
#        '3ED',
#        '3JD',
#        '3JJ',
#        '3LF',
#        '3LQ',
#        '3PA',
#        '3QA',
#        '4EW',
#        '4HH',
#        '4HW',
#        '4LJ',
#        '4LY',
#        '4RB',
#        '4RD',
#        '4RE',
#        '4RF',
#        '4RN',
#        '4SE',
#        '4SG',
#        '4SS',
#        '4UL',
#        '4UN',
#        '5',
#        '5BT',
#        '5HA',
#        '5HP',
#        '5NH',
#        '5NJ',
#        '5NL',
#        '5NT',
#        '5NX',
#        '5PA',
#        '5RX',
#        '5SA',
#        '5UA',
#        '5UL',
#        '5UQ',
#        '6AW',
#        '6ED',
#        '6EE',
#        '6EG',
#        '6HB',
#        '6HH',
#        '7AU',
#        '7DU',
#        '7EU',
#        '7LW',
#        '7PP',
#        '7QY',
#        '7QZ',
#        '7RU',
#        '7ST'])),
#  ('SW7',
#   set(['2ND',
#        '3BH',
#        '3BJ',
#        '3DY',
#        '3ES',
#        '3EX',
#        '3HZ',
#        '3LE',
#        '3LQ',
#        '3RN',
#        '4DN',
#        '4LT',
#        '4QB',
#        '4QH',
#        '4TE',
#        '5AB',
#        '5AG',
#        '5AQ',
#        '5JX',
#        '5QX'])),
#  ('SW8', set(['3JL', '3JW', '3PH', '3RE', '3RH', '3RX', '3RY', '3SB'])),
#  ('TW1',
#   set(['1AQ',
#        '1EE',
#        '1LF',
#        '1NJ',
#        '1RG',
#        '2AR',
#        '2DX',
#        '2EF',
#        '2EJ',
#        '2JQ',
#        '2LH',
#        '2LJ',
#        '2NH',
#        '2NL',
#        '2NP',
#        '2PD',
#        '2PG',
#        '2TY',
#        '3AB',
#        '3AW',
#        '3BA',
#        '3BB',
#        '3BL',
#        '3BZ',
#        '3DN',
#        '3DT',
#        '3DU',
#        '3DX',
#        '3DY',
#        '3EN',
#        '3HE',
#        '3JT',
#        '3JZ',
#        '3LD',
#        '3LJ',
#        '3NJ',
#        '3NR',
#        '3QS',
#        '3RJ',
#        '3RR',
#        '3RY',
#        '3SD',
#        '3SG',
#        '3SH',
#        '3SL',
#        '3SN',
#        '3SU',
#        '3SX',
#        '3SZ',
#        '4AF',
#        '4AG',
#        '4AW',
#        '4BN',
#        '4BW',
#        '4BX',
#        '4BZ',
#        '4DB',
#        '4EA',
#        '4EU',
#        '4EZ',
#        '4JR',
#        '4LT',
#        '4QG',
#        '4QJ',
#        '4RB',
#        '4SX',
#        '4TQ'])),
#  ('TW10',
#   set(['5AA',
#        '5HR',
#        '5HX',
#        '5LA',
#        '5LF',
#        '6AQ',
#        '6AW',
#        '6DF',
#        '6DX',
#        '6EG',
#        '6ES',
#        '6HN',
#        '6HW',
#        '6HY',
#        '6JJ',
#        '6NE',
#        '6NH',
#        '6PN',
#        '6PP',
#        '6QX',
#        '6RE',
#        '6RN',
#        '6RP',
#        '6RW',
#        '6SD',
#        '6SE',
#        '6TH',
#        '6UA',
#        '6UB',
#        '6UH',
#        '6UJ',
#        '6UQ',
#        '6UT',
#        '6UW',
#        '6UX',
#        '6UY',
#        '6UZ',
#        '7AA',
#        '7AD',
#        '7AH',
#        '7AS',
#        '7DB',
#        '7ED',
#        '7HN',
#        '7HR',
#        '7HT',
#        '7HW',
#        '7JE',
#        '7JF',
#        '7LJ',
#        '7NF',
#        '7NL',
#        '7NN',
#        '7NR',
#        '7NY',
#        '7PJ',
#        '7PL',
#        '7RX',
#        '7TS',
#        '7UA',
#        '7UE'])),
#  ('TW11',
#   set(['0AB',
#        '0AU',
#        '0BB',
#        '0EL',
#        '0EQ',
#        '0HB',
#        '0JE',
#        '0JL',
#        '0JZ',
#        '0LY',
#        '0SP',
#        '8ET',
#        '8HA',
#        '8HG',
#        '8HU',
#        '8LA',
#        '8LX',
#        '8PF',
#        '8PJ',
#        '8PS',
#        '8QY',
#        '8QZ',
#        '8RF',
#        '8RW',
#        '8SF',
#        '8UD',
#        '8UE',
#        '9AA',
#        '9AD',
#        '9AL',
#        '9AS',
#        '9BS',
#        '9JD',
#        '9JF',
#        '9NN',
#        '9NR',
#        '9NU',
#        '9PE',
#        '9PJ',
#        '9QY',
#        '9QZ',
#        '9RP'])),
#  ('TW12',
#   set(['1AQ',
#        '1AW',
#        '1EG',
#        '1HB',
#        '1HW',
#        '1JG',
#        '1JN',
#        '1JQ',
#        '1JT',
#        '1JW',
#        '1JY',
#        '1NH',
#        '1NJ',
#        '1NL',
#        '1NS',
#        '1NT',
#        '1NY',
#        '1NZ',
#        '1PD',
#        '1QU',
#        '2AL',
#        '2AP',
#        '2AX',
#        '2BJ',
#        '2BX',
#        '2DX',
#        '2EA',
#        '2HA',
#        '2HD',
#        '2HP',
#        '2HQ',
#        '2HZ',
#        '2JA',
#        '2JH',
#        '2JN',
#        '2JW',
#        '2LA',
#        '2LJ',
#        '2LP',
#        '2NS',
#        '2SA',
#        '2SJ',
#        '2ST',
#        '2TH',
#        '2UQ',
#        '3AJ',
#        '3DH',
#        '3HB',
#        '3HD',
#        '3HF',
#        '3HX',
#        '3LT',
#        '3NR',
#        '3PE',
#        '3RA',
#        '3RN',
#        '3YH'])),
#  ('TW13',
#   set(['4AE',
#        '4PR',
#        '6EZ',
#        '6HB',
#        '6NH',
#        '6XH',
#        '7AB',
#        '7AH',
#        '7EA',
#        '7NW',
#        '7WB'])),
#  ('TW14', set(['0PR', '0RN', '0SL', '8', '8LT', '8NU', '9BP', '9NT', '9QT'])),
#  ('TW15', set(['1AH', '1RY', '2BW', '2DG', '2HZ', '2PE', '2QN', '2UT'])),
#  ('TW16',
#   set(['5AD',
#        '5BL',
#        '5DE',
#        '5EA',
#        '5HS',
#        '5LE',
#        '6PG',
#        '6QL',
#        '7AZ',
#        '7BB',
#        '7LB'])),
#  ('TW17', set(['0EE', '8AN', '8LX', '8SG', '9AB', '9AU', '9JZ', '9NT'])),
#  ('TW18',
#   set(['1AJ',
#        '1DT',
#        '1EP',
#        '1SS',
#        '1XB',
#        '2AP',
#        '2BT',
#        '2EF',
#        '2PD',
#        '3AP',
#        '3HJ',
#        '3JB',
#        '3JD',
#        '3JN',
#        '4EE',
#        '4EP',
#        '4LY',
#        '4PD',
#        '4PJ',
#        '4QX',
#        '4SD',
#        '4SJ',
#        '4SU',
#        '4WB',
#        '4XX'])),
#  ('TW19', set(['5NN', '6AQ', '6BJ', '6HA', '7BG', '7DB', '7HU', '7LZ'])),
#  ('TW2',
#   set(['5AA',
#        '5AB',
#        '5AG',
#        '5AH',
#        '5AL',
#        '5AN',
#        '5AR',
#        '5AT',
#        '5AW',
#        '5AY',
#        '5BB',
#        '5BG',
#        '5BH',
#        '5DJ',
#        '5EG',
#        '5EL',
#        '5JA',
#        '5JD',
#        '5JW',
#        '5LH',
#        '5NG',
#        '5NJ',
#        '5NP',
#        '5NQ',
#        '5NX',
#        '5PE',
#        '5PG',
#        '5QA',
#        '5QB',
#        '5QE',
#        '5QL',
#        '5QR',
#        '5QS',
#        '5SD',
#        '5TS',
#        '5TU',
#        '6EN',
#        '6JW',
#        '6LF',
#        '6LS',
#        '6PH',
#        '6PY',
#        '6QS',
#        '6QW',
#        '6RB',
#        '7AH',
#        '7BA',
#        '7BB',
#        '7BU',
#        '7BZ',
#        '7DE',
#        '7DT',
#        '7DU',
#        '7DY',
#        '7EX',
#        '7LB',
#        '7LT'])),
#  ('TW20', set(['8TE', '8UE', '9EX', '9FB', '9HE', '9HZ', '9LX', '9UR'])),
#  ('TW3', set(['1ES', '1NX', '1PA', '3ET', '3HW', '3JS', '3LN', '3UA'])),
#  ('TW4', set(['5NP', '6BL', '6JR', '7HW'])),
#  ('TW5',
#   set(['0BD', '0BT', '0BU', '0LF', '9QB', '9QE', '9QQ', '9TL', '9TW', '9TY'])),
#  ('TW6',
#   set(['1BP',
#        '1EW',
#        '1QG',
#        '2AP',
#        '2AU',
#        '2GW',
#        '2SQ',
#        '2UA',
#        '3AF',
#        '3FE',
#        '3JF'])),
#  ('TW7',
#   set(['4BZ',
#        '4LW',
#        '4NB',
#        '4QG',
#        '4RB',
#        '5BD',
#        '5BE',
#        '5NA',
#        '5NZ',
#        '5QE',
#        '6DB',
#        '6GD',
#        '6GE',
#        '6GG',
#        '6GH',
#        '6GJ',
#        '6GL',
#        '6GN',
#        '6GP',
#        '6GS',
#        '6GU',
#        '6NA',
#        '6SQ',
#        '7EU'])),
#  ('TW8',
#   set(['0AX',
#        '0BD',
#        '0BE',
#        '0BJ',
#        '0BW',
#        '0DE',
#        '0DQ',
#        '0DU',
#        '0EB',
#        '0EN',
#        '0EW',
#        '0FJ',
#        '0GT',
#        '0GU',
#        '0GW',
#        '0GX',
#        '0HU',
#        '0HX',
#        '0HY',
#        '0JG',
#        '0JJ',
#        '0NT',
#        '8AQ',
#        '8DW',
#        '8EW',
#        '8JF',
#        '8JG',
#        '8JW',
#        '8LZ',
#        '9DE',
#        '9DF',
#        '9DN',
#        '9DU',
#        '9DZ',
#        '9JF',
#        '9NY'])),
#  ('TW9',
#   set(['1AB',
#        '1AD',
#        '1AE',
#        '1AR',
#        '1AS',
#        '1AW',
#        '1BP',
#        '1DH',
#        '1DJ',
#        '1DN',
#        '1DT',
#        '1DY',
#        '1DZ',
#        '1EA',
#        '1EH',
#        '1EJ',
#        '1EU',
#        '1EZ',
#        '1HE',
#        '1HH',
#        '1HJ',
#        '1HP',
#        '1HU',
#        '1HY',
#        '1JL',
#        '1JS',
#        '1JY',
#        '1LX',
#        '1LZ',
#        '1ND',
#        '1NU',
#        '1PX',
#        '1QJ',
#        '1QQ',
#        '1QW',
#        '1RE',
#        '1RJ',
#        '1RW',
#        '1RX',
#        '1SX',
#        '1TH',
#        '1TJ',
#        '1TN',
#        '1TQ',
#        '1TW',
#        '1UF',
#        '1UG',
#        '1UY',
#        '1YJ',
#        '2AA',
#        '2AN',
#        '2AU',
#        '2AW',
#        '2EW',
#        '2HP',
#        '2JZ',
#        '2LL',
#        '2LN',
#        '2NA',
#        '2ND',
#        '2NQ',
#        '2PE',
#        '2PN',
#        '2PQ',
#        '2RA',
#        '2RG',
#        '2SB',
#        '2SF',
#        '2SS',
#        '3AB',
#        '3AF',
#        '3AH',
#        '3AP',
#        '3BZ',
#        '3DF',
#        '3DU',
#        '3HJ',
#        '3HQ',
#        '3HS',
#        '3JU',
#        '3JX',
#        '3JY',
#        '3LG',
#        '3LL',
#        '3LQ',
#        '3NG',
#        '3PS',
#        '3PT',
#        '3PZ',
#        '3QB',
#        '3QD',
#        '3QF',
#        '4AA',
#        '4AD',
#        '4DU',
#        '4EA',
#        '4EL',
#        '4EN',
#        '4ES',
#        '4HF',
#        '4HJ',
#        '4LE',
#        '4LQ',
#        '4LT',
#        '4QN',
#        '4QT'])),
#  ('UB3', set(['4LQ', '5AL'])),
#  ('UB7', set(['0DH', '0EE', '0JE', '0JH', '0LQ', '0NA'])),
#  ('W14', set(['0RH', '8NJ', '8PB', '8UJ', '9EP', '9ES', '9SA', '9SX'])),
#  ('W4',
#   set(['1PD',
#        '1PJ',
#        '1PR',
#        '1QN',
#        '1QP',
#        '1RG',
#        '1SY',
#        '2DR',
#        '2DT',
#        '2DU',
#        '2PD',
#        '3DT',
#        '3JN',
#        '3JP',
#        '3JY',
#        '4HH',
#        '4JU',
#        '4LZ',
#        '4PH',
#        '5PY',
#        '5RG',
#        '5RY',
#        '5TA',
#        '5TE',
#        '5UT'])),
#  ('W6',
#   set(['0JB',
#        '0JD',
#        '0PZ',
#        '7BY',
#        '7JP',
#        '7NL',
#        '8BJ',
#        '8DA',
#        '8DR',
#        '8HJ',
#        '8NL',
#        '8QT',
#        '8RB',
#        '8RN',
#        '9BP',
#        '9DJ',
#        '9HW',
#        '9PA',
#        '9PH',
#        '9QH',
#        '9RS',
#        '9TA',
#        '9YD']))]

# %%
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

OSM_FILE = 'swlondon_sample.osm' 
#OSM_FILE = 'swlondon.osm'

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

#SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']



# CLEANUP FUNCTIONS BELOW:








# A function to shape the tags and add to the relevant dict objects.
# Used for both nodes and way tags - as treatment is the same.
# Takes list of desired tag fields (from NODE_TAGS_FIELDS)
# For id (an attrb from parent node or way and NOT in tag), parent node / way id is returned
# for 'key' checks if: 
#                      a PROBLEMCHARS match, and ignores / drops
#                      a LOWER_COLON match and splits, extracts / sets type (see rules above) 
#                                        and returns rest as key
#                       (NOTE - type is 'regular' if no other found)


def shape_tags(element, id_number, tag_attr_fields = NODE_TAGS_FIELDS,
                   problem_chars=PROBLEMCHARS, lower_colon=LOWER_COLON,
                   default_tag_type='regular'):
    tag_dict={}
    for field in tag_attr_fields:
        if field == 'id':
            tag_dict[field]= id_number
        elif field == 'key':
            tag_dict['type'] = default_tag_type
            if problem_chars.search(element.attrib['k']):
                print 'IGNORING A TAG - PROBLEM CHARS', element.attrib['k']
            elif lower_colon.search(element.attrib['k']):
                split_k =  element.attrib['k'].split(':')
                tag_dict['type'] = split_k[0]
                tag_dict[field] = ':'.join(split_k[1:])

            else:
                tag_dict[field]= element.attrib['k']
        elif field == 'value':
            tag_dict[field]= element.attrib['v']
      
    return tag_dict




def shape_way_nodes(element, id_number, position, way_node_fields=WAY_NODES_FIELDS):
    way_node_dict = {}
    for field in way_node_fields:
        if field == 'id':
            way_node_dict[field]= id_number
        elif field == 'position':
            way_node_dict[field]= position
        elif field == 'node_id':
            way_node_dict[field]= element.attrib['ref']
    return way_node_dict
            


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    if element.tag == 'node':
        for field in node_attr_fields:
            node_attribs[field]= element.attrib[field]
            id_number = element.attrib['id']
        for tag in element.iter('tag'):
            tags.append(shape_tags(tag, id_number))            
        return {'node': node_attribs, 'node_tags': tags}
        
    elif element.tag == 'way':
        for field in way_attr_fields:
            way_attribs[field]= element.attrib[field]
            id_number = element.attrib['id']        
        for tag in element.iter('tag'):
            tags.append(shape_tags(tag, id_number))
        position = 0
        for way_node in element.iter('nd'):
            way_nodes.append(shape_way_nodes(way_node, id_number, position))
            position += 1     
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()





def process_map_simple(file_in, validate):
    #validator = cerberus.Validator()
    n=0
    for element in get_element(file_in, tags=('node', 'way')):
            n+=1
            if n>200: break
            el = shape_element(element)
            pprint.pprint (el)
            print '\n'
            #if el:
            #    if validate is True:
            #        validate_element(el, validator)

                    
if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map_simple(OSM_FILE, validate=False)
# Out:
# {'node': {'changeset': '43286497',
#           'id': '109642',
#           'lat': '51.4835856',
#           'lon': '-0.1673611',
#           'timestamp': '2016-10-30T16:09:18Z',
#           'uid': '322039',
#           'user': 'MacLondon',
#           'version': '10'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '36747072',
#           'id': '109656',
#           'lat': '51.4884895',
#           'lon': '-0.1893827',
#           'timestamp': '2016-01-22T20:02:16Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '16703076',
#           'id': '109896',
#           'lat': '51.4907726',
#           'lon': '-0.2132303',
#           'timestamp': '2013-06-25T18:13:57Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '8'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '24802132',
#           'id': '109917',
#           'lat': '51.4872140',
#           'lon': '-0.2546853',
#           'timestamp': '2014-08-17T08:46:16Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9737651',
#           'id': '109932',
#           'lat': '51.4887490',
#           'lon': '-0.2749039',
#           'timestamp': '2011-11-04T11:39:18Z',
#           'uid': '73548',
#           'user': 'Richard Holland',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '29587584',
#           'id': '195052',
#           'lat': '51.4569509',
#           'lon': '-0.2055632',
#           'timestamp': '2015-03-19T09:14:52Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '25270199',
#           'id': '197988',
#           'lat': '51.4801432',
#           'lon': '-0.1716084',
#           'timestamp': '2014-09-06T16:30:58Z',
#           'uid': '855535',
#           'user': "L'le Tom",
#           'version': '7'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '6560',
#           'id': '198010',
#           'lat': '51.4791321',
#           'lon': '-0.1877327',
#           'timestamp': '2007-04-04T22:28:24Z',
#           'uid': '4049',
#           'user': 'randomjunk',
#           'version': '1'},
#  'node_tags': [{'id': '198010',
#                 'key': 'created_by',
#                 'type': 'regular',
#                 'value': 'YahooApplet 1.0'}]}
#
#
# {'node': {'changeset': '13371869',
#           'id': '198037',
#           'lat': '51.4889128',
#           'lon': '-0.1651368',
#           'timestamp': '2012-10-05T11:40:47Z',
#           'uid': '900987',
#           'user': 'Metanautics fixes',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7753181',
#           'id': '198050',
#           'lat': '51.4822802',
#           'lon': '-0.1794487',
#           'timestamp': '2011-04-03T11:53:29Z',
#           'uid': '40196',
#           'user': 'pfr',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '19364048',
#           'id': '202218',
#           'lat': '51.4928010',
#           'lon': '-0.4098970',
#           'timestamp': '2013-12-09T18:40:22Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '1896074',
#           'id': '202250',
#           'lat': '51.4775681',
#           'lon': '-0.4038471',
#           'timestamp': '2009-07-21T16:14:21Z',
#           'uid': '28024',
#           'user': 'dbisping',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13848551',
#           'id': '202270',
#           'lat': '51.4641358',
#           'lon': '-0.4132605',
#           'timestamp': '2012-11-12T16:43:40Z',
#           'uid': '607695',
#           'user': 'cwood500',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '36344918',
#           'id': '202295',
#           'lat': '51.4460749',
#           'lon': '-0.4099512',
#           'timestamp': '2016-01-03T18:50:40Z',
#           'uid': '5541',
#           'user': 'Ian Haylock',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7920451',
#           'id': '202322',
#           'lat': '51.4246498',
#           'lon': '-0.4066406',
#           'timestamp': '2011-04-20T21:11:23Z',
#           'uid': '4951',
#           'user': 'PeterEastern',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '428308',
#           'id': '202393',
#           'lat': '51.3967690',
#           'lon': '-0.5023238',
#           'timestamp': '2009-02-14T18:59:34Z',
#           'uid': '7511',
#           'user': 'retselkim',
#           'version': '10'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '45237829',
#           'id': '202412',
#           'lat': '51.3949380',
#           'lon': '-0.5341419',
#           'timestamp': '2017-01-17T09:32:14Z',
#           'uid': '2773866',
#           'user': 'kreuzschnabel',
#           'version': '10'},
#  'node_tags': [{'id': '202412',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'motorway_junction'},
#                {'id': '202412',
#                 'key': 'name',
#                 'type': 'regular',
#                 'value': 'Thorpe Interchange'},
#                {'id': '202412',
#                 'key': 'ref',
#                 'type': 'regular',
#                 'value': '12'}]}
#
#
# {'node': {'changeset': '6305836',
#           'id': '202447',
#           'lat': '51.4001650',
#           'lon': '-0.5393650',
#           'timestamp': '2010-11-06T20:12:22Z',
#           'uid': '1337',
#           'user': 'OJW',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9953183',
#           'id': '202482',
#           'lat': '51.3755148',
#           'lon': '-0.5084731',
#           'timestamp': '2011-11-26T09:30:46Z',
#           'uid': '28024',
#           'user': 'dbisping',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '38924937',
#           'id': '202503',
#           'lat': '51.3614046',
#           'lon': '-0.4984932',
#           'timestamp': '2016-04-27T16:03:59Z',
#           'uid': '104856',
#           'user': 'chexum',
#           'version': '17'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '12300440',
#           'id': '202518',
#           'lat': '51.3247266',
#           'lon': '-0.4656847',
#           'timestamp': '2012-07-18T22:26:02Z',
#           'uid': '61216',
#           'user': 'UniEagle',
#           'version': '8'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '34047273',
#           'id': '202567',
#           'lat': '51.2761923',
#           'lon': '-0.5217125',
#           'timestamp': '2015-09-15T19:11:20Z',
#           'uid': '5541',
#           'user': 'Ian Haylock',
#           'version': '11'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '542978',
#           'id': '202802',
#           'lat': '51.3099675',
#           'lon': '-0.3822343',
#           'timestamp': '2008-01-05T10:12:02Z',
#           'uid': '6809',
#           'user': 'TimSC_Data_CC0_To_Andy_Allan',
#           'version': '28'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '254662',
#           'id': '202812',
#           'lat': '51.3150804',
#           'lon': '-0.3345125',
#           'timestamp': '2009-02-07T01:47:29Z',
#           'uid': '94941',
#           'user': 'marcworca',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '542978',
#           'id': '202823',
#           'lat': '51.2960745',
#           'lon': '-0.3112008',
#           'timestamp': '2008-01-05T09:52:02Z',
#           'uid': '6809',
#           'user': 'TimSC_Data_CC0_To_Andy_Allan',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '542978',
#           'id': '202836',
#           'lat': '51.2792234',
#           'lon': '-0.2621894',
#           'timestamp': '2008-01-05T09:42:56Z',
#           'uid': '6809',
#           'user': 'TimSC_Data_CC0_To_Andy_Allan',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '542978',
#           'id': '202916',
#           'lat': '51.2598107',
#           'lon': '-0.1923633',
#           'timestamp': '2008-01-05T09:34:49Z',
#           'uid': '6809',
#           'user': 'TimSC_Data_CC0_To_Andy_Allan',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '15609341',
#           'id': '205481',
#           'lat': '51.4926319',
#           'lon': '-0.4946045',
#           'timestamp': '2013-04-04T15:38:44Z',
#           'uid': '178626',
#           'user': 'Rovastar',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '15609341',
#           'id': '205512',
#           'lat': '51.4937642',
#           'lon': '-0.4972221',
#           'timestamp': '2013-04-04T15:38:44Z',
#           'uid': '178626',
#           'user': 'Rovastar',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '21263289',
#           'id': '205529',
#           'lat': '51.4708907',
#           'lon': '-0.5061260',
#           'timestamp': '2014-03-23T12:48:33Z',
#           'uid': '178626',
#           'user': 'Rovastar',
#           'version': '15'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '21263289',
#           'id': '205923',
#           'lat': '51.4606747',
#           'lon': '-0.5166970',
#           'timestamp': '2014-03-23T12:48:33Z',
#           'uid': '178626',
#           'user': 'Rovastar',
#           'version': '16'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '26630287',
#           'id': '205962',
#           'lat': '51.4439821',
#           'lon': '-0.5281523',
#           'timestamp': '2014-11-07T22:13:45Z',
#           'uid': '125259',
#           'user': 'abc26324',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '8095058',
#           'id': '206008',
#           'lat': '51.4351475',
#           'lon': '-0.5362876',
#           'timestamp': '2011-05-09T18:14:25Z',
#           'uid': '125259',
#           'user': 'abc26324',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13798953',
#           'id': '218563',
#           'lat': '51.4923405',
#           'lon': '-0.5431254',
#           'timestamp': '2012-11-08T16:02:26Z',
#           'uid': '243152',
#           'user': 'ChinnorBoy',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13798953',
#           'id': '218574',
#           'lat': '51.4927793',
#           'lon': '-0.5357871',
#           'timestamp': '2012-11-08T16:14:11Z',
#           'uid': '243152',
#           'user': 'ChinnorBoy',
#           'version': '9'},
#  'node_tags': [{'id': '218574',
#                 'key': 'exit_to',
#                 'type': 'regular',
#                 'value': '(M3) The South West,A4 Langley,B470 Eton'},
#                {'id': '218574',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'motorway_junction'},
#                {'id': '218574',
#                 'key': 'layer',
#                 'type': 'regular',
#                 'value': '3'},
#                {'id': '218574',
#                 'key': 'name',
#                 'type': 'regular',
#                 'value': 'Langley Roundabout'},
#                {'id': '218574',
#                 'key': 'ref',
#                 'type': 'regular',
#                 'value': '5'}]}
#
#
# {'node': {'changeset': '9156392',
#           'id': '223513',
#           'lat': '51.4894806',
#           'lon': '-0.3979162',
#           'timestamp': '2011-08-29T11:19:30Z',
#           'uid': '136860',
#           'user': 'indigomc',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9737506',
#           'id': '223527',
#           'lat': '51.4881603',
#           'lon': '-0.3820989',
#           'timestamp': '2011-11-04T11:18:50Z',
#           'uid': '73548',
#           'user': 'Richard Holland',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9156392',
#           'id': '223537',
#           'lat': '51.4940292',
#           'lon': '-0.3561969',
#           'timestamp': '2011-08-29T11:19:28Z',
#           'uid': '136860',
#           'user': 'indigomc',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '28370924',
#           'id': '225167',
#           'lat': '51.4937271',
#           'lon': '-0.3404603',
#           'timestamp': '2015-01-24T12:25:42Z',
#           'uid': '1388075',
#           'user': 'Jonga',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '15641172',
#           'id': '225184',
#           'lat': '51.4914312',
#           'lon': '-0.3018817',
#           'timestamp': '2013-04-07T15:00:07Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13297260',
#           'id': '276556',
#           'lat': '51.4938478',
#           'lon': '-0.1786320',
#           'timestamp': '2012-09-29T14:25:47Z',
#           'uid': '900987',
#           'user': 'Metanautics fixes',
#           'version': '5'},
#  'node_tags': [{'id': '276556',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'traffic_signals'}]}
#
#
# {'node': {'changeset': '21225769',
#           'id': '284045',
#           'lat': '51.3799662',
#           'lon': '-0.4925842',
#           'timestamp': '2014-03-21T11:35:36Z',
#           'uid': '1974064',
#           'user': 'cityeditor1000',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '1236722',
#           'id': '284061',
#           'lat': '51.3781058',
#           'lon': '-0.4973671',
#           'timestamp': '2009-05-18T14:07:43Z',
#           'uid': '28024',
#           'user': 'dbisping',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '35667792',
#           'id': '284096',
#           'lat': '51.3298650',
#           'lon': '-0.4407452',
#           'timestamp': '2015-11-30T15:16:03Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '7'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10405844',
#           'id': '284128',
#           'lat': '51.3676725',
#           'lon': '-0.3771921',
#           'timestamp': '2012-01-16T07:00:33Z',
#           'uid': '232621',
#           'user': 'vnjones',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '22723757',
#           'id': '284804',
#           'lat': '51.3339032',
#           'lon': '-0.5455467',
#           'timestamp': '2014-06-03T21:42:25Z',
#           'uid': '1974064',
#           'user': 'cityeditor1000',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '34004792',
#           'id': '287278',
#           'lat': '51.4340049',
#           'lon': '-0.5160354',
#           'timestamp': '2015-09-13T17:32:35Z',
#           'uid': '5541',
#           'user': 'Ian Haylock',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '44053922',
#           'id': '287402',
#           'lat': '51.4368145',
#           'lon': '-0.5008787',
#           'timestamp': '2016-11-30T08:25:20Z',
#           'uid': '873940',
#           'user': 'Mike Baggaley',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '33999899',
#           'id': '287420',
#           'lat': '51.4350015',
#           'lon': '-0.5088023',
#           'timestamp': '2015-09-13T13:30:57Z',
#           'uid': '5541',
#           'user': 'Ian Haylock',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '17597033',
#           'id': '287606',
#           'lat': '51.4812893',
#           'lon': '-0.4197075',
#           'timestamp': '2013-08-30T22:43:04Z',
#           'uid': '445666',
#           'user': 'SomePlaceMapperCT',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '376323',
#           'id': '287621',
#           'lat': '51.4807479',
#           'lon': '-0.4600149',
#           'timestamp': '2007-12-20T01:57:58Z',
#           'uid': '12671',
#           'user': 'sladen',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13844418',
#           'id': '287639',
#           'lat': '51.4793977',
#           'lon': '-0.4521385',
#           'timestamp': '2012-11-12T10:40:58Z',
#           'uid': '607695',
#           'user': 'cwood500',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '14169873',
#           'id': '287738',
#           'lat': '51.4901800',
#           'lon': '-0.4538698',
#           'timestamp': '2012-12-06T00:01:13Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '24907347',
#           'id': '287824',
#           'lat': '51.4486436',
#           'lon': '-0.4474940',
#           'timestamp': '2014-08-21T12:07:26Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '21225769',
#           'id': '288710',
#           'lat': '51.3744601',
#           'lon': '-0.4821988',
#           'timestamp': '2014-03-21T11:35:35Z',
#           'uid': '1974064',
#           'user': 'cityeditor1000',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '317122',
#           'id': '292113',
#           'lat': '51.3438422',
#           'lon': '-0.4008476',
#           'timestamp': '2008-03-13T20:09:57Z',
#           'uid': '6809',
#           'user': 'TimSC_Data_CC0_To_Andy_Allan',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '6489901',
#           'id': '292133',
#           'lat': '51.3492663',
#           'lon': '-0.3595946',
#           'timestamp': '2010-11-29T21:12:17Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '6486170',
#           'id': '292163',
#           'lat': '51.3497068',
#           'lon': '-0.3364488',
#           'timestamp': '2010-11-29T12:52:31Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '6495713',
#           'id': '292180',
#           'lat': '51.3562060',
#           'lon': '-0.3227356',
#           'timestamp': '2010-11-30T16:35:50Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9983085',
#           'id': '292191',
#           'lat': '51.3643284',
#           'lon': '-0.3190803',
#           'timestamp': '2011-11-28T22:29:46Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9442872',
#           'id': '292236',
#           'lat': '51.3753187',
#           'lon': '-0.3107960',
#           'timestamp': '2011-10-01T14:27:52Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '26593518',
#           'id': '292260',
#           'lat': '51.3747567',
#           'lon': '-0.2860199',
#           'timestamp': '2014-11-06T14:06:56Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '8334285',
#           'id': '292290',
#           'lat': '51.3863151',
#           'lon': '-0.2732882',
#           'timestamp': '2011-06-03T21:30:40Z',
#           'uid': '8335',
#           'user': 'UrSuS',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10915447',
#           'id': '292315',
#           'lat': '51.3956407',
#           'lon': '-0.2499010',
#           'timestamp': '2012-03-09T01:28:41Z',
#           'uid': '577089',
#           'user': 'JodaStephen',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10175810',
#           'id': '292352',
#           'lat': '51.4094475',
#           'lon': '-0.2446544',
#           'timestamp': '2011-12-21T22:08:07Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '27197657',
#           'id': '292381',
#           'lat': '51.4252032',
#           'lon': '-0.2551305',
#           'timestamp': '2014-12-03T11:15:09Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '33064958',
#           'id': '292398',
#           'lat': '51.4367211',
#           'lon': '-0.2548203',
#           'timestamp': '2015-08-03T09:51:09Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '33064958',
#           'id': '292411',
#           'lat': '51.4361499',
#           'lon': '-0.2553668',
#           'timestamp': '2015-08-03T09:51:10Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '17175747',
#           'id': '292423',
#           'lat': '51.4410187',
#           'lon': '-0.2439018',
#           'timestamp': '2013-08-01T07:42:54Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '29296756',
#           'id': '292446',
#           'lat': '51.4488296',
#           'lon': '-0.2218137',
#           'timestamp': '2015-03-06T19:54:01Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '36650792',
#           'id': '292459',
#           'lat': '51.4505020',
#           'lon': '-0.2185373',
#           'timestamp': '2016-01-18T08:26:09Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '29587584',
#           'id': '292473',
#           'lat': '51.4567587',
#           'lon': '-0.2042931',
#           'timestamp': '2015-03-19T09:14:52Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '189146',
#           'id': '292486',
#           'lat': '51.4582759',
#           'lon': '-0.1965439',
#           'timestamp': '2007-01-06T11:14:35Z',
#           'uid': '4049',
#           'user': 'randomjunk',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '22302004',
#           'id': '292501',
#           'lat': '51.4591094',
#           'lon': '-0.1909844',
#           'timestamp': '2014-05-12T22:26:39Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '18524568',
#           'id': '292513',
#           'lat': '51.4618768',
#           'lon': '-0.1858318',
#           'timestamp': '2013-10-24T18:36:12Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '17839492',
#           'id': '292524',
#           'lat': '51.4624600',
#           'lon': '-0.1846809',
#           'timestamp': '2013-09-14T20:30:53Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '535585',
#           'id': '292575',
#           'lat': '51.4756994',
#           'lon': '-0.1730585',
#           'timestamp': '2007-09-29T14:03:10Z',
#           'uid': '4049',
#           'user': 'randomjunk',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10175642',
#           'id': '292608',
#           'lat': '51.4297454',
#           'lon': '-0.2675723',
#           'timestamp': '2011-12-21T21:43:25Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '3979479',
#           'id': '292630',
#           'lat': '51.4211655',
#           'lon': '-0.2863507',
#           'timestamp': '2010-02-26T11:52:38Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '102620',
#           'id': '292662',
#           'lat': '51.4158708',
#           'lon': '-0.2882785',
#           'timestamp': '2007-06-19T08:30:27Z',
#           'uid': '1337',
#           'user': 'OJW',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '99384',
#           'id': '292678',
#           'lat': '51.4184499',
#           'lon': '-0.2971435',
#           'timestamp': '2007-06-17T16:27:36Z',
#           'uid': '1337',
#           'user': 'OJW',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7468245',
#           'id': '292693',
#           'lat': '51.4121704',
#           'lon': '-0.3008552',
#           'timestamp': '2011-03-05T22:01:27Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '12433260',
#           'id': '292710',
#           'lat': '51.4104693',
#           'lon': '-0.3007651',
#           'timestamp': '2012-07-22T13:51:18Z',
#           'uid': '118262',
#           'user': 'Wynndale',
#           'version': '18'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '12433260',
#           'id': '292730',
#           'lat': '51.4080002',
#           'lon': '-0.3023109',
#           'timestamp': '2012-07-22T13:51:18Z',
#           'uid': '118262',
#           'user': 'Wynndale',
#           'version': '7'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '12433260',
#           'id': '292743',
#           'lat': '51.4076574',
#           'lon': '-0.3070784',
#           'timestamp': '2012-07-22T13:51:19Z',
#           'uid': '118262',
#           'user': 'Wynndale',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '29090782',
#           'id': '293525',
#           'lat': '51.4726748',
#           'lon': '-0.2004943',
#           'timestamp': '2015-02-25T12:44:01Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': [{'id': '293525',
#                 'key': 'crossing',
#                 'type': 'regular',
#                 'value': 'traffic_signals'},
#                {'id': '293525',
#                 'key': 'crossing_ref',
#                 'type': 'regular',
#                 'value': 'pelican'},
#                {'id': '293525',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'traffic_signals'}]}
#
#
# {'node': {'changeset': '26993429',
#           'id': '293565',
#           'lat': '51.4757363',
#           'lon': '-0.2056714',
#           'timestamp': '2014-11-24T11:09:19Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '33818969',
#           'id': '293730',
#           'lat': '51.4131461',
#           'lon': '-0.3683184',
#           'timestamp': '2015-09-05T17:52:14Z',
#           'uid': '5541',
#           'user': 'Ian Haylock',
#           'version': '7'},
#  'node_tags': [{'id': '293730',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'traffic_signals'}]}
#
#
# {'node': {'changeset': '10805665',
#           'id': '293900',
#           'lat': '51.3411163',
#           'lon': '-0.3981895',
#           'timestamp': '2012-02-27T05:47:29Z',
#           'uid': '501777',
#           'user': 'Zorac',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '35469634',
#           'id': '293927',
#           'lat': '51.3337283',
#           'lon': '-0.4129599',
#           'timestamp': '2015-11-20T19:50:46Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '21176223',
#           'id': '294527',
#           'lat': '51.4756844',
#           'lon': '-0.3954327',
#           'timestamp': '2014-03-18T15:17:29Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '16572612',
#           'id': '294604',
#           'lat': '51.4779581',
#           'lon': '-0.3726972',
#           'timestamp': '2013-06-16T09:09:05Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '18796585',
#           'id': '294875',
#           'lat': '51.4857587',
#           'lon': '-0.3196933',
#           'timestamp': '2013-11-09T10:31:00Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '21315168',
#           'id': '294912',
#           'lat': '51.4911457',
#           'lon': '-0.3040418',
#           'timestamp': '2014-03-25T23:08:03Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '15640511',
#           'id': '294950',
#           'lat': '51.4927927',
#           'lon': '-0.2877471',
#           'timestamp': '2013-04-07T14:05:28Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '14'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '24764323',
#           'id': '295257',
#           'lat': '51.4924987',
#           'lon': '-0.2843320',
#           'timestamp': '2014-08-15T10:48:18Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '12'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9291992',
#           'id': '295330',
#           'lat': '51.4881873',
#           'lon': '-0.2874631',
#           'timestamp': '2011-09-13T18:44:06Z',
#           'uid': '81732',
#           'user': 'zahilb',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '8499807',
#           'id': '295412',
#           'lat': '51.4742162',
#           'lon': '-0.2922891',
#           'timestamp': '2011-06-20T22:09:32Z',
#           'uid': '6035',
#           'user': 'Sorbus_x_kewensis',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9449694',
#           'id': '295475',
#           'lat': '51.4651535',
#           'lon': '-0.2979095',
#           'timestamp': '2011-10-02T10:55:03Z',
#           'uid': '28024',
#           'user': 'dbisping',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '11722829',
#           'id': '295507',
#           'lat': '51.4649941',
#           'lon': '-0.2990695',
#           'timestamp': '2012-05-28T06:23:07Z',
#           'uid': '61216',
#           'user': 'UniEagle',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '27372701',
#           'id': '295536',
#           'lat': '51.4646555',
#           'lon': '-0.3044941',
#           'timestamp': '2014-12-10T09:11:57Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '7'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '11730046',
#           'id': '295618',
#           'lat': '51.4579892',
#           'lon': '-0.3184818',
#           'timestamp': '2012-05-28T18:36:37Z',
#           'uid': '131236',
#           'user': 'duncaninnes',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '16384724',
#           'id': '295669',
#           'lat': '51.4570987',
#           'lon': '-0.3239868',
#           'timestamp': '2013-06-01T23:24:06Z',
#           'uid': '1174735',
#           'user': 'markptompsett',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10977719',
#           'id': '295696',
#           'lat': '51.4547431',
#           'lon': '-0.3333614',
#           'timestamp': '2012-03-14T13:15:22Z',
#           'uid': '84263',
#           'user': 'Robert Whittaker',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10330387',
#           'id': '295740',
#           'lat': '51.4537746',
#           'lon': '-0.3389145',
#           'timestamp': '2012-01-08T11:50:49Z',
#           'uid': '118262',
#           'user': 'Wynndale',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '3044822',
#           'id': '295752',
#           'lat': '51.4523689',
#           'lon': '-0.3444313',
#           'timestamp': '2009-11-05T23:50:23Z',
#           'uid': '31795',
#           'user': 'SomePlaceMapper',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '182589',
#           'id': '295769',
#           'lat': '51.4463102',
#           'lon': '-0.3579783',
#           'timestamp': '2008-02-23T02:34:13Z',
#           'uid': '1295',
#           'user': 'robert',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '32146090',
#           'id': '295783',
#           'lat': '51.4423893',
#           'lon': '-0.3648811',
#           'timestamp': '2015-06-22T19:12:26Z',
#           'uid': '67515',
#           'user': 'threefoursixninefour',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '32140783',
#           'id': '295796',
#           'lat': '51.4416534',
#           'lon': '-0.3647138',
#           'timestamp': '2015-06-22T15:03:36Z',
#           'uid': '67515',
#           'user': 'threefoursixninefour',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '182589',
#           'id': '295837',
#           'lat': '51.4350368',
#           'lon': '-0.3850716',
#           'timestamp': '2008-02-23T01:05:55Z',
#           'uid': '1295',
#           'user': 'robert',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '33927855',
#           'id': '295994',
#           'lat': '51.4692354',
#           'lon': '-0.2760098',
#           'timestamp': '2015-09-10T09:14:42Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '8359855',
#           'id': '296038',
#           'lat': '51.4799667',
#           'lon': '-0.2601429',
#           'timestamp': '2011-06-06T12:36:07Z',
#           'uid': '160386',
#           'user': 'Jono Graham',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '15584285',
#           'id': '296094',
#           'lat': '51.4876405',
#           'lon': '-0.2519306',
#           'timestamp': '2013-04-02T17:13:43Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '11029446',
#           'id': '296120',
#           'lat': '51.4887955',
#           'lon': '-0.2483405',
#           'timestamp': '2012-03-19T13:08:37Z',
#           'uid': '4115',
#           'user': 'Andy Allan',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9737573',
#           'id': '296156',
#           'lat': '51.4882574',
#           'lon': '-0.2727982',
#           'timestamp': '2011-11-04T11:22:43Z',
#           'uid': '73548',
#           'user': 'Richard Holland',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '27283563',
#           'id': '296190',
#           'lat': '51.4051525',
#           'lon': '-0.3414268',
#           'timestamp': '2014-12-06T06:15:34Z',
#           'uid': '1974064',
#           'user': 'cityeditor1000',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '17418223',
#           'id': '296204',
#           'lat': '51.4045441',
#           'lon': '-0.3413371',
#           'timestamp': '2013-08-19T21:26:53Z',
#           'uid': '327499',
#           'user': 'Skyguy',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '36012986',
#           'id': '296220',
#           'lat': '51.4106027',
#           'lon': '-0.3132876',
#           'timestamp': '2015-12-17T16:42:24Z',
#           'uid': '5541',
#           'user': 'Ian Haylock',
#           'version': '12'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '36101415',
#           'id': '296233',
#           'lat': '51.4112934',
#           'lon': '-0.3097807',
#           'timestamp': '2015-12-22T09:51:56Z',
#           'uid': '2068507',
#           'user': 'Daveymorrisuk',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '31137998',
#           'id': '296247',
#           'lat': '51.4114025',
#           'lon': '-0.3072602',
#           'timestamp': '2015-05-14T12:11:55Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '10'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7468245',
#           'id': '296260',
#           'lat': '51.4128721',
#           'lon': '-0.3045902',
#           'timestamp': '2011-03-05T22:01:38Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '27079020',
#           'id': '296276',
#           'lat': '51.4123854',
#           'lon': '-0.3010727',
#           'timestamp': '2014-11-27T22:27:49Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '8'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7847747',
#           'id': '296305',
#           'lat': '51.4130709',
#           'lon': '-0.3055921',
#           'timestamp': '2011-04-12T23:04:31Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '12341203',
#           'id': '296328',
#           'lat': '51.4089766',
#           'lon': '-0.3062863',
#           'timestamp': '2012-07-19T17:06:50Z',
#           'uid': '577089',
#           'user': 'JodaStephen',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '48417086',
#           'id': '296340',
#           'lat': '51.4006390',
#           'lon': '-0.2952216',
#           'timestamp': '2017-05-05T07:47:20Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '23125648',
#           'id': '296354',
#           'lat': '51.4079456',
#           'lon': '-0.2950846',
#           'timestamp': '2014-06-24T15:54:43Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '48'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '14231354',
#           'id': '296378',
#           'lat': '51.4014680',
#           'lon': '-0.2679339',
#           'timestamp': '2012-12-10T21:09:48Z',
#           'uid': '158204',
#           'user': 'EmlynSquare',
#           'version': '21'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '39243947',
#           'id': '296395',
#           'lat': '51.3983217',
#           'lon': '-0.2554987',
#           'timestamp': '2016-05-11T14:41:49Z',
#           'uid': '4115',
#           'user': 'Andy Allan',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9464463',
#           'id': '296441',
#           'lat': '51.3942112',
#           'lon': '-0.2537138',
#           'timestamp': '2011-10-03T20:34:12Z',
#           'uid': '28024',
#           'user': 'dbisping',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '34799320',
#           'id': '297255',
#           'lat': '51.4289578',
#           'lon': '-0.3069551',
#           'timestamp': '2015-10-22T13:19:09Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '17'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9874569',
#           'id': '297304',
#           'lat': '51.4372646',
#           'lon': '-0.3044987',
#           'timestamp': '2011-11-19T16:32:14Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10244817',
#           'id': '297456',
#           'lat': '51.4541352',
#           'lon': '-0.2998140',
#           'timestamp': '2011-12-30T12:48:56Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '11720729',
#           'id': '297494',
#           'lat': '51.4582351',
#           'lon': '-0.3055096',
#           'timestamp': '2012-05-27T21:58:01Z',
#           'uid': '61216',
#           'user': 'UniEagle',
#           'version': '10'},
#  'node_tags': [{'id': '297494',
#                 'key': 'direction',
#                 'type': 'regular',
#                 'value': 'clockwise'},
#                {'id': '297494',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'mini_roundabout'}]}
#
#
# {'node': {'changeset': '8711364',
#           'id': '297579',
#           'lat': '51.4540187',
#           'lon': '-0.3129165',
#           'timestamp': '2011-07-13T10:51:18Z',
#           'uid': '131236',
#           'user': 'duncaninnes',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '11762334',
#           'id': '297640',
#           'lat': '51.4545127',
#           'lon': '-0.3184674',
#           'timestamp': '2012-05-31T21:19:10Z',
#           'uid': '131236',
#           'user': 'duncaninnes',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9098535',
#           'id': '297700',
#           'lat': '51.4477738',
#           'lon': '-0.3263779',
#           'timestamp': '2011-08-22T21:18:07Z',
#           'uid': '131236',
#           'user': 'duncaninnes',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13924774',
#           'id': '297725',
#           'lat': '51.4429346',
#           'lon': '-0.3310464',
#           'timestamp': '2012-11-18T21:27:32Z',
#           'uid': '120011',
#           'user': 'Miguelicus',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9875185',
#           'id': '297742',
#           'lat': '51.4363141',
#           'lon': '-0.3307618',
#           'timestamp': '2011-11-19T17:28:34Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '33149658',
#           'id': '297861',
#           'lat': '51.4135228',
#           'lon': '-0.3117882',
#           'timestamp': '2015-08-06T09:04:04Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13275470',
#           'id': '298046',
#           'lat': '51.4630605',
#           'lon': '-0.1654427',
#           'timestamp': '2012-09-27T18:04:02Z',
#           'uid': '246',
#           'user': 'moyogo',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '17858778',
#           'id': '298077',
#           'lat': '51.4679440',
#           'lon': '-0.1504680',
#           'timestamp': '2013-09-15T22:02:26Z',
#           'uid': '855535',
#           'user': "L'le Tom",
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '32330207',
#           'id': '298411',
#           'lat': '51.4496922',
#           'lon': '-0.3303866',
#           'timestamp': '2015-07-01T12:05:09Z',
#           'uid': '67515',
#           'user': 'threefoursixninefour',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '22953913',
#           'id': '298431',
#           'lat': '51.4417867',
#           'lon': '-0.3445740',
#           'timestamp': '2014-06-15T23:14:09Z',
#           'uid': '2125266',
#           'user': 'Rumfield',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '32140783',
#           'id': '298456',
#           'lat': '51.4393434',
#           'lon': '-0.3614062',
#           'timestamp': '2015-06-22T15:03:36Z',
#           'uid': '67515',
#           'user': 'threefoursixninefour',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '557173',
#           'id': '298470',
#           'lat': '51.4380797',
#           'lon': '-0.3680084',
#           'timestamp': '2009-04-15T18:30:33Z',
#           'uid': '7630',
#           'user': 'LivingWithDragons',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '663912',
#           'id': '298505',
#           'lat': '51.4310431',
#           'lon': '-0.3638922',
#           'timestamp': '2008-09-18T23:25:34Z',
#           'uid': '7630',
#           'user': 'LivingWithDragons',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7649107',
#           'id': '298553',
#           'lat': '51.4269537',
#           'lon': '-0.3558077',
#           'timestamp': '2011-03-23T19:02:38Z',
#           'uid': '118262',
#           'user': 'Wynndale',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13589806',
#           'id': '298576',
#           'lat': '51.4271100',
#           'lon': '-0.3439502',
#           'timestamp': '2012-10-22T08:36:09Z',
#           'uid': '989584',
#           'user': 'AndyKnott',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '9875227',
#           'id': '298615',
#           'lat': '51.4287032',
#           'lon': '-0.3243983',
#           'timestamp': '2011-11-19T17:33:22Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '23023840',
#           'id': '299144',
#           'lat': '51.4486603',
#           'lon': '-0.2232465',
#           'timestamp': '2014-06-19T12:56:39Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '35940019',
#           'id': '299163',
#           'lat': '51.4543107',
#           'lon': '-0.2200405',
#           'timestamp': '2015-12-14T08:35:39Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '42219332',
#           'id': '299179',
#           'lat': '51.4612200',
#           'lon': '-0.2187505',
#           'timestamp': '2016-09-17T03:49:58Z',
#           'uid': '2046159',
#           'user': '@LS@',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '26937508',
#           'id': '299201',
#           'lat': '51.4689550',
#           'lon': '-0.2105706',
#           'timestamp': '2014-11-21T21:07:57Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '22664789',
#           'id': '299216',
#           'lat': '51.4719967',
#           'lon': '-0.2103961',
#           'timestamp': '2014-05-31T23:21:10Z',
#           'uid': '37137',
#           'user': 'Derick Rethans',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7774418',
#           'id': '299232',
#           'lat': '51.4768443',
#           'lon': '-0.2110348',
#           'timestamp': '2011-04-05T12:30:43Z',
#           'uid': '40196',
#           'user': 'pfr',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7136993',
#           'id': '299252',
#           'lat': '51.4849906',
#           'lon': '-0.2200828',
#           'timestamp': '2011-01-30T17:35:38Z',
#           'uid': '23768',
#           'user': 'tko',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '49869682',
#           'id': '299270',
#           'lat': '51.4884724',
#           'lon': '-0.2248454',
#           'timestamp': '2017-06-27T18:11:52Z',
#           'uid': '24119',
#           'user': 'Mauls',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '24307313',
#           'id': '299294',
#           'lat': '51.4499134',
#           'lon': '-0.2409924',
#           'timestamp': '2014-07-23T09:11:21Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10243833',
#           'id': '299313',
#           'lat': '51.4560400',
#           'lon': '-0.2429097',
#           'timestamp': '2011-12-30T10:47:26Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '30231009',
#           'id': '299326',
#           'lat': '51.4652498',
#           'lon': '-0.2438004',
#           'timestamp': '2015-04-15T09:19:49Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '5'},
#  'node_tags': [{'id': '299326',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'traffic_signals'}]}
#
#
# {'node': {'changeset': '40429617',
#           'id': '299359',
#           'lat': '51.4714900',
#           'lon': '-0.2464342',
#           'timestamp': '2016-07-01T22:43:24Z',
#           'uid': '4198936',
#           'user': 'ccityplanner12',
#           'version': '5'},
#  'node_tags': [{'id': '299359',
#                 'key': 'crossing',
#                 'type': 'regular',
#                 'value': 'zebra'},
#                {'id': '299359',
#                 'key': 'crossing_ref',
#                 'type': 'regular',
#                 'value': 'zebra'},
#                {'id': '299359',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'crossing'},
#                {'id': '299359',
#                 'key': 'sloped_curb',
#                 'type': 'regular',
#                 'value': 'yes'},
#                {'id': '299359',
#                 'key': 'tactile_paving',
#                 'type': 'regular',
#                 'value': 'yes'}]}
#
#
# {'node': {'changeset': '151199',
#           'id': '299401',
#           'lat': '51.4771411',
#           'lon': '-0.2384766',
#           'timestamp': '2006-11-05T19:04:11Z',
#           'uid': '4049',
#           'user': 'randomjunk',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13458369',
#           'id': '299466',
#           'lat': '51.4912068',
#           'lon': '-0.2232434',
#           'timestamp': '2012-10-11T19:05:23Z',
#           'uid': '900987',
#           'user': 'Metanautics fixes',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '7221255',
#           'id': '299484',
#           'lat': '51.4930981',
#           'lon': '-0.2231799',
#           'timestamp': '2011-02-07T21:33:15Z',
#           'uid': '23768',
#           'user': 'tko',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '13458369',
#           'id': '299527',
#           'lat': '51.4930777',
#           'lon': '-0.2210985',
#           'timestamp': '2012-10-11T19:05:24Z',
#           'uid': '900987',
#           'user': 'Metanautics fixes',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10244962',
#           'id': '301686',
#           'lat': '51.4610635',
#           'lon': '-0.2978450',
#           'timestamp': '2011-12-30T13:04:06Z',
#           'uid': '16703',
#           'user': 'joelholdsworth',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '43807789',
#           'id': '301723',
#           'lat': '51.4647179',
#           'lon': '-0.2667062',
#           'timestamp': '2016-11-19T19:18:59Z',
#           'uid': '4198936',
#           'user': 'ccityplanner12',
#           'version': '2'},
#  'node_tags': [{'id': '301723',
#                 'key': 'name',
#                 'type': 'regular',
#                 'value': 'Milestone Green'}]}
#
#
# {'node': {'changeset': '36535818',
#           'id': '301757',
#           'lat': '51.4637647',
#           'lon': '-0.2492311',
#           'timestamp': '2016-01-12T19:08:19Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '36650728',
#           'id': '301779',
#           'lat': '51.4627263',
#           'lon': '-0.2243631',
#           'timestamp': '2016-01-18T08:21:21Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '31522214',
#           'id': '301810',
#           'lat': '51.4667172',
#           'lon': '-0.2362170',
#           'timestamp': '2015-05-28T07:15:12Z',
#           'uid': '352985',
#           'user': 'ecatmur',
#           'version': '4'},
#  'node_tags': [{'id': '301810',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'mini_roundabout'}]}
#
#
# {'node': {'changeset': '155610',
#           'id': '301837',
#           'lat': '51.4659112',
#           'lon': '-0.2534551',
#           'timestamp': '2006-11-19T19:48:43Z',
#           'uid': '4115',
#           'user': 'Andy Allan',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '11716749',
#           'id': '301898',
#           'lat': '51.4668536',
#           'lon': '-0.2881900',
#           'timestamp': '2012-05-27T15:22:07Z',
#           'uid': '131236',
#           'user': 'duncaninnes',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '47736858',
#           'id': '301945',
#           'lat': '51.4614262',
#           'lon': '-0.3086257',
#           'timestamp': '2017-04-13T09:48:04Z',
#           'uid': '5535664',
#           'user': 'FKorning',
#           'version': '5'},
#  'node_tags': [{'id': '301945',
#                 'key': 'district',
#                 'type': 'addr',
#                 'value': 'Greater London'},
#                {'id': '301945',
#                 'key': 'subdistrict',
#                 'type': 'addr',
#                 'value': 'Richmond upon Thames'},
#                {'id': '301945',
#                 'key': 'suburb',
#                 'type': 'addr',
#                 'value': 'Richmond'}]}
#
#
# {'node': {'changeset': '32138220',
#           'id': '301969',
#           'lat': '51.4381453',
#           'lon': '-0.3492201',
#           'timestamp': '2015-06-22T13:04:50Z',
#           'uid': '67515',
#           'user': 'threefoursixninefour',
#           'version': '5'},
#  'node_tags': [{'id': '301969',
#                 'key': 'crossing',
#                 'type': 'regular',
#                 'value': 'traffic_signals'},
#                {'id': '301969',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'crossing'}]}
#
#
# {'node': {'changeset': '11108994',
#           'id': '301995',
#           'lat': '51.4303262',
#           'lon': '-0.3451372',
#           'timestamp': '2012-03-26T18:40:08Z',
#           'uid': '118262',
#           'user': 'Wynndale',
#           'version': '6'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '192114',
#           'id': '302014',
#           'lat': '51.4331524',
#           'lon': '-0.3384611',
#           'timestamp': '2008-02-24T00:19:52Z',
#           'uid': '1295',
#           'user': 'robert',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '23211899',
#           'id': '302025',
#           'lat': '51.4388452',
#           'lon': '-0.3345434',
#           'timestamp': '2014-06-27T11:49:37Z',
#           'uid': '2100180',
#           'user': 'TimGo',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '4982345',
#           'id': '302038',
#           'lat': '51.4369472',
#           'lon': '-0.3785455',
#           'timestamp': '2010-06-13T19:54:11Z',
#           'uid': '118262',
#           'user': 'Wynndale',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '24366862',
#           'id': '302947',
#           'lat': '51.4554440',
#           'lon': '-0.4207839',
#           'timestamp': '2014-07-26T12:29:31Z',
#           'uid': '491515',
#           'user': 'robertogeb',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '552457',
#           'id': '302988',
#           'lat': '51.4688983',
#           'lon': '-0.4035230',
#           'timestamp': '2008-01-06T15:02:16Z',
#           'uid': '1993',
#           'user': 'marinheiro',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '27447299',
#           'id': '303011',
#           'lat': '51.4668339',
#           'lon': '-0.3708853',
#           'timestamp': '2014-12-13T17:59:47Z',
#           'uid': '1388075',
#           'user': 'Jonga',
#           'version': '2'},
#  'node_tags': [{'id': '303011',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'traffic_signals'}]}
#
#
# {'node': {'changeset': '21253586',
#           'id': '303024',
#           'lat': '51.4687752',
#           'lon': '-0.3718314',
#           'timestamp': '2014-03-22T21:57:41Z',
#           'uid': '1016290',
#           'user': 'Amaroussi',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '27447299',
#           'id': '303034',
#           'lat': '51.4636036',
#           'lon': '-0.3771657',
#           'timestamp': '2014-12-13T18:01:56Z',
#           'uid': '1388075',
#           'user': 'Jonga',
#           'version': '2'},
#  'node_tags': [{'id': '303034',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'mini_roundabout'}]}
#
#
# {'node': {'changeset': '27447299',
#           'id': '303065',
#           'lat': '51.4744598',
#           'lon': '-0.3653119',
#           'timestamp': '2014-12-13T18:24:06Z',
#           'uid': '1388075',
#           'user': 'Jonga',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '80787',
#           'id': '303082',
#           'lat': '51.4703131',
#           'lon': '-0.3483413',
#           'timestamp': '2008-10-05T00:54:46Z',
#           'uid': '1993',
#           'user': 'marinheiro',
#           'version': '3'},
#  'node_tags': [{'id': '303082',
#                 'key': 'direction',
#                 'type': 'regular',
#                 'value': 'clockwise'},
#                {'id': '303082',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'mini_roundabout'}]}
#
#
# {'node': {'changeset': '258487',
#           'id': '303095',
#           'lat': '51.4694065',
#           'lon': '-0.3285861',
#           'timestamp': '2007-08-27T23:32:19Z',
#           'uid': '3560',
#           'user': 'Firefishy',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '11066367',
#           'id': '303109',
#           'lat': '51.4707636',
#           'lon': '-0.3297299',
#           'timestamp': '2012-03-22T18:56:50Z',
#           'uid': '4115',
#           'user': 'Andy Allan',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '10128155',
#           'id': '303129',
#           'lat': '51.4752641',
#           'lon': '-0.3159675',
#           'timestamp': '2011-12-16T00:12:33Z',
#           'uid': '6035',
#           'user': 'Sorbus_x_kewensis',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '16384724',
#           'id': '303141',
#           'lat': '51.4718259',
#           'lon': '-0.3190718',
#           'timestamp': '2013-06-01T23:24:05Z',
#           'uid': '1174735',
#           'user': 'markptompsett',
#           'version': '2'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '15611618',
#           'id': '303151',
#           'lat': '51.4684100',
#           'lon': '-0.3241184',
#           'timestamp': '2013-04-04T19:07:43Z',
#           'uid': '445666',
#           'user': 'SomePlaceMapperCT',
#           'version': '4'},
#  'node_tags': [{'id': '303151',
#                 'key': 'direction',
#                 'type': 'regular',
#                 'value': 'clockwise'},
#                {'id': '303151',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'mini_roundabout'}]}
#
#
# {'node': {'changeset': '258487',
#           'id': '303162',
#           'lat': '51.4688698',
#           'lon': '-0.3279563',
#           'timestamp': '2007-08-27T23:10:42Z',
#           'uid': '3560',
#           'user': 'Firefishy',
#           'version': '1'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '261612',
#           'id': '303181',
#           'lat': '51.4605296',
#           'lon': '-0.3315629',
#           'timestamp': '2007-08-29T15:23:51Z',
#           'uid': '1993',
#           'user': 'marinheiro',
#           'version': '1'},
#  'node_tags': [{'id': '303181',
#                 'key': 'highway',
#                 'type': 'regular',
#                 'value': 'traffic_signals'}]}
#
#
# {'node': {'changeset': '700063',
#           'id': '303195',
#           'lat': '51.4595457',
#           'lon': '-0.3699652',
#           'timestamp': '2009-01-01T18:36:40Z',
#           'uid': '12503',
#           'user': 'Paul Todd',
#           'version': '3'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '700063',
#           'id': '303213',
#           'lat': '51.4527958',
#           'lon': '-0.3675594',
#           'timestamp': '2009-01-01T18:40:14Z',
#           'uid': '12503',
#           'user': 'Paul Todd',
#           'version': '8'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '21847088',
#           'id': '303237',
#           'lat': '51.4462251',
#           'lon': '-0.3835499',
#           'timestamp': '2014-04-21T19:39:10Z',
#           'uid': '37137',
#           'user': 'Derick Rethans',
#           'version': '5'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '21263289',
#           'id': '303291',
#           'lat': '51.4674549',
#           'lon': '-0.5094731',
#           'timestamp': '2014-03-23T12:48:34Z',
#           'uid': '178626',
#           'user': 'Rovastar',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '12296717',
#           'id': '303331',
#           'lat': '51.4835045',
#           'lon': '-0.4880207',
#           'timestamp': '2012-07-18T20:16:52Z',
#           'uid': '82820',
#           'user': 'Mark_S',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '48064572',
#           'id': '303367',
#           'lat': '51.4812508',
#           'lon': '-0.4553085',
#           'timestamp': '2017-04-23T16:03:25Z',
#           'uid': '9176',
#           'user': 'Maarten Deen',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '376323',
#           'id': '303379',
#           'lat': '51.4852163',
#           'lon': '-0.4536549',
#           'timestamp': '2007-12-20T02:06:40Z',
#           'uid': '12671',
#           'user': 'sladen',
#           'version': '4'},
#  'node_tags': []}
#
#
# {'node': {'changeset': '216662',
#           'id': '303403',
#           'lat': '51.4767247',
#           'lon': '-0.3243307',
#           'timestamp': '2007-08-15T18:52:27Z',
#           'uid': '1993',
#           'user': 'marinheiro',
#           'version': '1'},
#  'node_tags': []}
